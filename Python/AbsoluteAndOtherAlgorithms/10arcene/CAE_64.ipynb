# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io

from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.function.similarity_based import lap_score
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.function.sparse_learning_based.UDFS import udfs
from skfeature.utility.sparse_learning import feature_ranking
import time

from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def ETree(p_train_feature,p_train_label,p_test_feature,p_test_label,p_seed):
    clf = ExtraTreesClassifier(n_estimators=50, random_state=p_seed)
    
    # Training
    clf.fit(p_train_feature, p_train_label)
    
    # Training accuracy
    print('Training accuracy：',clf.score(p_train_feature, np.array(p_train_label)))
    print('Training accuracy：',accuracy_score(np.array(p_train_label),clf.predict(p_train_feature)))
    #print('Training accuracy：',np.sum(clf.predict(p_train_feature)==np.array(p_train_label))/p_train_label.shape[0])

    # Testing accuracy
    print('Testing accuracy：',clf.score(p_test_feature, np.array(p_test_label)))
    print('Testing accuracy：',accuracy_score(np.array(p_test_label),clf.predict(p_test_feature)))
    #print('Testing accuracy：',np.sum(clf.predict(p_test_feature)==np.array(p_test_label))/p_test_label.shape[0])

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')

# %% [markdown]
# # 2. Loading data

# %%
data_path="./Dataset/arcene.mat"
Data = scipy.io.loadmat(data_path)

data_arr=Data['X']
label_arr_=Data['Y'][:, 0]

label_arr=np.array([0 if label_arr_i<0 else label_arr_i for label_arr_i in label_arr_])

data_arr=MinMaxScaler(feature_range=(0,1)).fit_transform(data_arr)

C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(data_arr,label_arr,test_size=0.2,random_state=seed)

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape))
# Out:
# Shape of C_train_x: (160, 10000)
# Shape of C_train_y: (160,)
# Shape of C_test_x: (40, 10000)
# Shape of C_test_y: (40,)

# %%
key_feture_number=64

# %% [markdown]
# # 3. Model

# %%
def decoder(x):
    x = Dense(key_feture_number)(x)
    x = Dense(data_arr.shape[1])(x)
    return x

# %%
C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(data_arr,label_arr,test_size=0.2,random_state=seed)

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape))
# Out:
# Shape of C_train_x: (160, 10000)
# Shape of C_train_y: (160,)
# Shape of C_test_x: (40, 10000)
# Shape of C_test_y: (40,)

# %%
start = time.clock()

selector = ConcreteAutoencoderFeatureSelector(K = key_feture_number, output_function = decoder, num_epochs = 1000)
selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)

train_compressed_Data=data_arr[:, selector.get_support(indices=True)]

time_cost=time.clock() - start
write_to_csv(np.array([time_cost]),"./log/CAS_time"+str(key_feture_number)+".csv")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10000)             0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                640001
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 10000)             650000
# =================================================================
# Total params: 1,294,161
# Trainable params: 1,294,160
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 160 samples, validate on 40 samples
# Epoch 1/1000
# mean max of probabilities: 0.00010324632 - temperature 10.0
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0838 - val_loss: 0.0651
# Epoch 2/1000
# mean max of probabilities: 0.00010324631 - temperature 9.940314
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0527 - val_loss: 0.0474
# Epoch 3/1000
# mean max of probabilities: 0.00010324693 - temperature 9.880986
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0457 - val_loss: 0.0450
# Epoch 4/1000
# mean max of probabilities: 0.00010324671 - temperature 9.822011
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0438 - val_loss: 0.0446
# Epoch 5/1000
# mean max of probabilities: 0.00010324658 - temperature 9.763389
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0433 - val_loss: 0.0444
# Epoch 6/1000
# mean max of probabilities: 0.00010324739 - temperature 9.705116
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0431 - val_loss: 0.0441
# Epoch 7/1000
# mean max of probabilities: 0.000103248414 - temperature 9.647191
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0431 - val_loss: 0.0437
# Epoch 8/1000
# mean max of probabilities: 0.00010324952 - temperature 9.589611
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0429 - val_loss: 0.0441
# Epoch 9/1000
# mean max of probabilities: 0.000103250844 - temperature 9.532376
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0429 - val_loss: 0.0440
# Epoch 10/1000
# mean max of probabilities: 0.00010325212 - temperature 9.475481
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0430 - val_loss: 0.0436
# Epoch 11/1000
# mean max of probabilities: 0.000103253544 - temperature 9.418927
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0428 - val_loss: 0.0436
# Epoch 12/1000
# mean max of probabilities: 0.00010325557 - temperature 9.36271
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0429 - val_loss: 0.0440
# Epoch 13/1000
# mean max of probabilities: 0.00010325723 - temperature 9.3068285
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0427 - val_loss: 0.0436
# Epoch 14/1000
# mean max of probabilities: 0.00010325886 - temperature 9.251281
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0428 - val_loss: 0.0437
# Epoch 15/1000
# mean max of probabilities: 0.000103260485 - temperature 9.196063
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0427 - val_loss: 0.0435
# Epoch 16/1000
# mean max of probabilities: 0.00010326246 - temperature 9.141178
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0425 - val_loss: 0.0437
# Epoch 17/1000
# mean max of probabilities: 0.00010326429 - temperature 9.086616
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0425 - val_loss: 0.0435
# Epoch 18/1000
# mean max of probabilities: 0.00010326607 - temperature 9.032384
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0424 - val_loss: 0.0435
# Epoch 19/1000
# mean max of probabilities: 0.000103268474 - temperature 8.978478
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0425 - val_loss: 0.0432
# Epoch 20/1000
# mean max of probabilities: 0.000103270824 - temperature 8.924895
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0423 - val_loss: 0.0435
# Epoch 21/1000
# mean max of probabilities: 0.00010327396 - temperature 8.871623
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0423 - val_loss: 0.0434
# Epoch 22/1000
# mean max of probabilities: 0.00010327735 - temperature 8.818672
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0421 - val_loss: 0.0434
# Epoch 23/1000
# mean max of probabilities: 0.00010328129 - temperature 8.766038
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0421 - val_loss: 0.0430
# Epoch 24/1000
# mean max of probabilities: 0.000103285995 - temperature 8.713719
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0420 - val_loss: 0.0429
# Epoch 25/1000
# mean max of probabilities: 0.000103292245 - temperature 8.661711
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0420 - val_loss: 0.0431
# Epoch 26/1000
# mean max of probabilities: 0.00010329997 - temperature 8.610013
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0419 - val_loss: 0.0430
# Epoch 27/1000
# mean max of probabilities: 0.00010330914 - temperature 8.558624
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0418 - val_loss: 0.0428
# Epoch 28/1000
# mean max of probabilities: 0.00010331992 - temperature 8.507542
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0416 - val_loss: 0.0427
# Epoch 29/1000
# mean max of probabilities: 0.00010333285 - temperature 8.456765
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0416 - val_loss: 0.0427
# Epoch 30/1000
# mean max of probabilities: 0.00010334779 - temperature 8.40629
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0418 - val_loss: 0.0421
# Epoch 31/1000
# mean max of probabilities: 0.00010336533 - temperature 8.356117
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0411 - val_loss: 0.0428
# Epoch 32/1000
# mean max of probabilities: 0.00010338462 - temperature 8.306244
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0412 - val_loss: 0.0426
# Epoch 33/1000
# mean max of probabilities: 0.00010340594 - temperature 8.256668
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0411 - val_loss: 0.0419
# Epoch 34/1000
# mean max of probabilities: 0.00010343152 - temperature 8.207388
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0408 - val_loss: 0.0420
# Epoch 35/1000
# mean max of probabilities: 0.0001034586 - temperature 8.158402
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0406 - val_loss: 0.0417
# Epoch 36/1000
# mean max of probabilities: 0.00010348974 - temperature 8.109709
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0404 - val_loss: 0.0416
# Epoch 37/1000
# mean max of probabilities: 0.00010352426 - temperature 8.061306
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0402 - val_loss: 0.0416
# Epoch 38/1000
# mean max of probabilities: 0.000103562124 - temperature 8.013191
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0400 - val_loss: 0.0411
# Epoch 39/1000
# mean max of probabilities: 0.00010360347 - temperature 7.9653645
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0398 - val_loss: 0.0411
# Epoch 40/1000
# mean max of probabilities: 0.0001036494 - temperature 7.9178233
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0399 - val_loss: 0.0406
# Epoch 41/1000
# mean max of probabilities: 0.00010370083 - temperature 7.8705645
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0395 - val_loss: 0.0408
# Epoch 42/1000
# mean max of probabilities: 0.00010375668 - temperature 7.823588
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0391 - val_loss: 0.0405
# Epoch 43/1000
# mean max of probabilities: 0.000103814855 - temperature 7.7768927
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0389 - val_loss: 0.0403
# Epoch 44/1000
# mean max of probabilities: 0.00010387877 - temperature 7.730476
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0387 - val_loss: 0.0399
# Epoch 45/1000
# mean max of probabilities: 0.000103946266 - temperature 7.6843367
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0384 - val_loss: 0.0399
# Epoch 46/1000
# mean max of probabilities: 0.00010401741 - temperature 7.6384726
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0383 - val_loss: 0.0394
# Epoch 47/1000
# mean max of probabilities: 0.00010409405 - temperature 7.592882
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0380 - val_loss: 0.0392
# Epoch 48/1000
# mean max of probabilities: 0.00010417604 - temperature 7.5475636
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0377 - val_loss: 0.0393
# Epoch 49/1000
# mean max of probabilities: 0.000104260995 - temperature 7.5025163
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0377 - val_loss: 0.0398
# Epoch 50/1000
# mean max of probabilities: 0.00010434835 - temperature 7.4577374
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0374 - val_loss: 0.0389
# Epoch 51/1000
# mean max of probabilities: 0.00010443981 - temperature 7.4132257
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0374 - val_loss: 0.0383
# Epoch 52/1000
# mean max of probabilities: 0.00010453553 - temperature 7.36898
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0373 - val_loss: 0.0399
# Epoch 53/1000
# mean max of probabilities: 0.00010463763 - temperature 7.324998
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0373 - val_loss: 0.0383
# Epoch 54/1000
# mean max of probabilities: 0.00010473953 - temperature 7.281278
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0369 - val_loss: 0.0388
# Epoch 55/1000
# mean max of probabilities: 0.0001048432 - temperature 7.2378197
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0368 - val_loss: 0.0384
# Epoch 56/1000
# mean max of probabilities: 0.00010495221 - temperature 7.1946206
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0369 - val_loss: 0.0382
# Epoch 57/1000
# mean max of probabilities: 0.00010506515 - temperature 7.15168
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0365 - val_loss: 0.0383
# Epoch 58/1000
# mean max of probabilities: 0.00010518256 - temperature 7.108995
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0364 - val_loss: 0.0384
# Epoch 59/1000
# mean max of probabilities: 0.000105304265 - temperature 7.066565
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0363 - val_loss: 0.0387
# Epoch 60/1000
# mean max of probabilities: 0.00010542705 - temperature 7.0243883
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0366 - val_loss: 0.0392
# Epoch 61/1000
# mean max of probabilities: 0.00010555718 - temperature 6.982463
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0363 - val_loss: 0.0378
# Epoch 62/1000
# mean max of probabilities: 0.00010568577 - temperature 6.940788
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0363 - val_loss: 0.0376
# Epoch 63/1000
# mean max of probabilities: 0.00010582223 - temperature 6.8993616
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0363 - val_loss: 0.0379
# Epoch 64/1000
# mean max of probabilities: 0.00010596223 - temperature 6.8581824
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0362 - val_loss: 0.0388
# Epoch 65/1000
# mean max of probabilities: 0.00010610385 - temperature 6.8172503
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0363 - val_loss: 0.0376
# Epoch 66/1000
# mean max of probabilities: 0.00010624849 - temperature 6.776561
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0363 - val_loss: 0.0383
# Epoch 67/1000
# mean max of probabilities: 0.00010640295 - temperature 6.736113
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0364 - val_loss: 0.0391
# Epoch 68/1000
# mean max of probabilities: 0.000106552754 - temperature 6.695907
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0362 - val_loss: 0.0375
# Epoch 69/1000
# mean max of probabilities: 0.00010670211 - temperature 6.655943
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0361 - val_loss: 0.0386
# Epoch 70/1000
# mean max of probabilities: 0.000106867126 - temperature 6.6162167
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0361 - val_loss: 0.0379
# Epoch 71/1000
# mean max of probabilities: 0.000107025655 - temperature 6.576728
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0361 - val_loss: 0.0376
# Epoch 72/1000
# mean max of probabilities: 0.00010718462 - temperature 6.5374746
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0361 - val_loss: 0.0388
# Epoch 73/1000
# mean max of probabilities: 0.000107354674 - temperature 6.4984555
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0364 - val_loss: 0.0374
# Epoch 74/1000
# mean max of probabilities: 0.000107515356 - temperature 6.4596696
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0362 - val_loss: 0.0395
# Epoch 75/1000
# mean max of probabilities: 0.00010769857 - temperature 6.4211154
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0363 - val_loss: 0.0374
# Epoch 76/1000
# mean max of probabilities: 0.000107865686 - temperature 6.382791
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0360 - val_loss: 0.0386
# Epoch 77/1000
# mean max of probabilities: 0.000108046 - temperature 6.344695
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0359 - val_loss: 0.0376
# Epoch 78/1000
# mean max of probabilities: 0.00010822069 - temperature 6.3068266
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0359 - val_loss: 0.0385
# Epoch 79/1000
# mean max of probabilities: 0.00010839701 - temperature 6.2691846
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0359 - val_loss: 0.0376
# Epoch 80/1000
# mean max of probabilities: 0.00010857775 - temperature 6.2317667
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0359 - val_loss: 0.0379
# Epoch 81/1000
# mean max of probabilities: 0.000108761895 - temperature 6.1945724
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0359 - val_loss: 0.0375
# Epoch 82/1000
# mean max of probabilities: 0.00010894923 - temperature 6.1576
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0358 - val_loss: 0.0382
# Epoch 83/1000
# mean max of probabilities: 0.00010915183 - temperature 6.1208487
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0359 - val_loss: 0.0385
# Epoch 84/1000
# mean max of probabilities: 0.000109349916 - temperature 6.084316
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0358 - val_loss: 0.0377
# Epoch 85/1000
# mean max of probabilities: 0.00010955396 - temperature 6.0480013
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0357 - val_loss: 0.0383
# Epoch 86/1000
# mean max of probabilities: 0.00010975257 - temperature 6.0119033
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0358 - val_loss: 0.0382
# Epoch 87/1000
# mean max of probabilities: 0.00010995583 - temperature 5.976022
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0357 - val_loss: 0.0375
# Epoch 88/1000
# mean max of probabilities: 0.00011016673 - temperature 5.9403534
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0357 - val_loss: 0.0380
# Epoch 89/1000
# mean max of probabilities: 0.000110382025 - temperature 5.9048986
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0356 - val_loss: 0.0381
# Epoch 90/1000
# mean max of probabilities: 0.00011059936 - temperature 5.869655
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0357 - val_loss: 0.0382
# Epoch 91/1000
# mean max of probabilities: 0.00011081884 - temperature 5.8346214
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0357 - val_loss: 0.0378
# Epoch 92/1000
# mean max of probabilities: 0.00011103497 - temperature 5.7997975
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0358 - val_loss: 0.0375
# Epoch 93/1000
# mean max of probabilities: 0.00011126326 - temperature 5.765181
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0357 - val_loss: 0.0384
# Epoch 94/1000
# mean max of probabilities: 0.00011149344 - temperature 5.7307715
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0357 - val_loss: 0.0376
# Epoch 95/1000
# mean max of probabilities: 0.0001117198 - temperature 5.696567
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0356 - val_loss: 0.0382
# Epoch 96/1000
# mean max of probabilities: 0.000111949535 - temperature 5.662567
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0358 - val_loss: 0.0382
# Epoch 97/1000
# mean max of probabilities: 0.00011219095 - temperature 5.6287694
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0356 - val_loss: 0.0382
# Epoch 98/1000
# mean max of probabilities: 0.0001124305 - temperature 5.595173
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0355 - val_loss: 0.0374
# Epoch 99/1000
# mean max of probabilities: 0.00011267084 - temperature 5.561778
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0355 - val_loss: 0.0377
# Epoch 100/1000
# mean max of probabilities: 0.00011291638 - temperature 5.5285826
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0356 - val_loss: 0.0373
# Epoch 101/1000
# mean max of probabilities: 0.00011315295 - temperature 5.4955854
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0357 - val_loss: 0.0380
# Epoch 102/1000
# mean max of probabilities: 0.000113415124 - temperature 5.462785
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0356 - val_loss: 0.0379
# Epoch 103/1000
# mean max of probabilities: 0.00011367258 - temperature 5.43018
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0356 - val_loss: 0.0374
# Epoch 104/1000
# mean max of probabilities: 0.00011392804 - temperature 5.39777
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0355 - val_loss: 0.0387
# Epoch 105/1000
# mean max of probabilities: 0.00011419201 - temperature 5.365553
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0356 - val_loss: 0.0375
# Epoch 106/1000
# mean max of probabilities: 0.00011444951 - temperature 5.3335285
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0356 - val_loss: 0.0379
# Epoch 107/1000
# mean max of probabilities: 0.00011472343 - temperature 5.301695
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0355 - val_loss: 0.0378
# Epoch 108/1000
# mean max of probabilities: 0.000114987895 - temperature 5.2700515
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0354 - val_loss: 0.0373
# Epoch 109/1000
# mean max of probabilities: 0.00011525898 - temperature 5.2385964
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0354 - val_loss: 0.0376
# Epoch 110/1000
# mean max of probabilities: 0.00011553802 - temperature 5.2073293
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0358 - val_loss: 0.0372
# Epoch 111/1000
# mean max of probabilities: 0.000115812465 - temperature 5.1762495
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0355 - val_loss: 0.0380
# Epoch 112/1000
# mean max of probabilities: 0.00011610256 - temperature 5.145355
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0354 - val_loss: 0.0372
# Epoch 113/1000
# mean max of probabilities: 0.00011638198 - temperature 5.114645
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0354 - val_loss: 0.0380
# Epoch 114/1000
# mean max of probabilities: 0.00011667698 - temperature 5.084118
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0354 - val_loss: 0.0373
# Epoch 115/1000
# mean max of probabilities: 0.000116977375 - temperature 5.0537734
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0356 - val_loss: 0.0383
# Epoch 116/1000
# mean max of probabilities: 0.000117280375 - temperature 5.02361
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0355 - val_loss: 0.0376
# Epoch 117/1000
# mean max of probabilities: 0.00011757554 - temperature 4.9936266
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0353 - val_loss: 0.0382
# Epoch 118/1000
# mean max of probabilities: 0.00011789505 - temperature 4.9638224
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0354 - val_loss: 0.0377
# Epoch 119/1000
# mean max of probabilities: 0.00011819413 - temperature 4.9341955
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0352 - val_loss: 0.0376
# Epoch 120/1000
# mean max of probabilities: 0.0001184958 - temperature 4.9047456
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0351 - val_loss: 0.0373
# Epoch 121/1000
# mean max of probabilities: 0.000118815224 - temperature 4.8754716
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0352 - val_loss: 0.0379
# Epoch 122/1000
# mean max of probabilities: 0.000119141296 - temperature 4.8463726
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0353 - val_loss: 0.0372
# Epoch 123/1000
# mean max of probabilities: 0.00011946295 - temperature 4.8174467
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0354 - val_loss: 0.0376
# Epoch 124/1000
# mean max of probabilities: 0.00011979464 - temperature 4.7886934
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0352 - val_loss: 0.0373
# Epoch 125/1000
# mean max of probabilities: 0.00012012512 - temperature 4.760113
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0351 - val_loss: 0.0374
# Epoch 126/1000
# mean max of probabilities: 0.00012046886 - temperature 4.7317014
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0351 - val_loss: 0.0375
# Epoch 127/1000
# mean max of probabilities: 0.000120807425 - temperature 4.7034607
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0352 - val_loss: 0.0370
# Epoch 128/1000
# mean max of probabilities: 0.00012114438 - temperature 4.6753883
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0352 - val_loss: 0.0373
# Epoch 129/1000
# mean max of probabilities: 0.00012149886 - temperature 4.6474833
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0350 - val_loss: 0.0372
# Epoch 130/1000
# mean max of probabilities: 0.00012186068 - temperature 4.6197443
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0350 - val_loss: 0.0371
# Epoch 131/1000
# mean max of probabilities: 0.00012223398 - temperature 4.5921717
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0350 - val_loss: 0.0368
# Epoch 132/1000
# mean max of probabilities: 0.00012259466 - temperature 4.564763
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0355 - val_loss: 0.0372
# Epoch 133/1000
# mean max of probabilities: 0.00012297796 - temperature 4.537519
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0352 - val_loss: 0.0370
# Epoch 134/1000
# mean max of probabilities: 0.00012335814 - temperature 4.510436
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0348 - val_loss: 0.0375
# Epoch 135/1000
# mean max of probabilities: 0.00012373902 - temperature 4.4835143
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0347 - val_loss: 0.0368
# Epoch 136/1000
# mean max of probabilities: 0.00012412145 - temperature 4.4567537
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0348 - val_loss: 0.0376
# Epoch 137/1000
# mean max of probabilities: 0.00012452673 - temperature 4.4301543
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0348 - val_loss: 0.0366
# Epoch 138/1000
# mean max of probabilities: 0.00012492246 - temperature 4.4037127
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0347 - val_loss: 0.0372
# Epoch 139/1000
# mean max of probabilities: 0.00012533178 - temperature 4.3774295
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0346 - val_loss: 0.0367
# Epoch 140/1000
# mean max of probabilities: 0.00012576152 - temperature 4.351302
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0347 - val_loss: 0.0368
# Epoch 141/1000
# mean max of probabilities: 0.00012619546 - temperature 4.325331
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0346 - val_loss: 0.0368
# Epoch 142/1000
# mean max of probabilities: 0.0001266136 - temperature 4.2995152
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0346 - val_loss: 0.0372
# Epoch 143/1000
# mean max of probabilities: 0.00012704241 - temperature 4.273854
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0344 - val_loss: 0.0366
# Epoch 144/1000
# mean max of probabilities: 0.00012747859 - temperature 4.248345
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0345 - val_loss: 0.0365
# Epoch 145/1000
# mean max of probabilities: 0.00012791474 - temperature 4.2229886
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0344 - val_loss: 0.0370
# Epoch 146/1000
# mean max of probabilities: 0.0001283667 - temperature 4.1977835
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0344 - val_loss: 0.0373
# Epoch 147/1000
# mean max of probabilities: 0.0001288302 - temperature 4.172729
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0343 - val_loss: 0.0363
# Epoch 148/1000
# mean max of probabilities: 0.0001292824 - temperature 4.147824
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0343 - val_loss: 0.0365
# Epoch 149/1000
# mean max of probabilities: 0.00012975183 - temperature 4.1230674
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0344 - val_loss: 0.0363
# Epoch 150/1000
# mean max of probabilities: 0.0001302085 - temperature 4.098459
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0342 - val_loss: 0.0363
# Epoch 151/1000
# mean max of probabilities: 0.00013067965 - temperature 4.073997
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0342 - val_loss: 0.0369
# Epoch 152/1000
# mean max of probabilities: 0.0001311618 - temperature 4.049681
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0341 - val_loss: 0.0360
# Epoch 153/1000
# mean max of probabilities: 0.00013163697 - temperature 4.025511
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0339 - val_loss: 0.0367
# Epoch 154/1000
# mean max of probabilities: 0.00013212729 - temperature 4.0014844
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0340 - val_loss: 0.0365
# Epoch 155/1000
# mean max of probabilities: 0.000132618 - temperature 3.9776015
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0341 - val_loss: 0.0367
# Epoch 156/1000
# mean max of probabilities: 0.0001331203 - temperature 3.953861
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0342 - val_loss: 0.0366
# Epoch 157/1000
# mean max of probabilities: 0.00013364505 - temperature 3.9302626
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0340 - val_loss: 0.0359
# Epoch 158/1000
# mean max of probabilities: 0.0001341497 - temperature 3.906805
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0338 - val_loss: 0.0364
# Epoch 159/1000
# mean max of probabilities: 0.0001346659 - temperature 3.8834872
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0336 - val_loss: 0.0358
# Epoch 160/1000
# mean max of probabilities: 0.00013519835 - temperature 3.8603084
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0336 - val_loss: 0.0363
# Epoch 161/1000
# mean max of probabilities: 0.0001357567 - temperature 3.837268
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0335 - val_loss: 0.0356
# Epoch 162/1000
# mean max of probabilities: 0.0001362989 - temperature 3.8143651
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0334 - val_loss: 0.0359
# Epoch 163/1000
# mean max of probabilities: 0.00013683073 - temperature 3.791599
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0333 - val_loss: 0.0357
# Epoch 164/1000
# mean max of probabilities: 0.00013738412 - temperature 3.7689688
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0332 - val_loss: 0.0357
# Epoch 165/1000
# mean max of probabilities: 0.00013794482 - temperature 3.7464738
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0331 - val_loss: 0.0354
# Epoch 166/1000
# mean max of probabilities: 0.0001385168 - temperature 3.724113
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0331 - val_loss: 0.0355
# Epoch 167/1000
# mean max of probabilities: 0.00013911143 - temperature 3.7018855
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0331 - val_loss: 0.0356
# Epoch 168/1000
# mean max of probabilities: 0.00013968511 - temperature 3.679791
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0330 - val_loss: 0.0354
# Epoch 169/1000
# mean max of probabilities: 0.00014027592 - temperature 3.6578279
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0330 - val_loss: 0.0355
# Epoch 170/1000
# mean max of probabilities: 0.00014087462 - temperature 3.6359959
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0327 - val_loss: 0.0350
# Epoch 171/1000
# mean max of probabilities: 0.00014148881 - temperature 3.6142943
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0327 - val_loss: 0.0347
# Epoch 172/1000
# mean max of probabilities: 0.00014212015 - temperature 3.5927222
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0326 - val_loss: 0.0351
# Epoch 173/1000
# mean max of probabilities: 0.00014275803 - temperature 3.571279
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0324 - val_loss: 0.0351
# Epoch 174/1000
# mean max of probabilities: 0.00014339125 - temperature 3.549964
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0324 - val_loss: 0.0343
# Epoch 175/1000
# mean max of probabilities: 0.00014404909 - temperature 3.528776
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0321 - val_loss: 0.0347
# Epoch 176/1000
# mean max of probabilities: 0.00014468371 - temperature 3.507714
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0324 - val_loss: 0.0340
# Epoch 177/1000
# mean max of probabilities: 0.00014536903 - temperature 3.4867785
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0323 - val_loss: 0.0352
# Epoch 178/1000
# mean max of probabilities: 0.0001460402 - temperature 3.4659677
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0320 - val_loss: 0.0339
# Epoch 179/1000
# mean max of probabilities: 0.00014670672 - temperature 3.445281
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0320 - val_loss: 0.0343
# Epoch 180/1000
# mean max of probabilities: 0.00014736802 - temperature 3.424718
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0316 - val_loss: 0.0338
# Epoch 181/1000
# mean max of probabilities: 0.00014804737 - temperature 3.404277
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0315 - val_loss: 0.0341
# Epoch 182/1000
# mean max of probabilities: 0.00014875236 - temperature 3.3839583
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0313 - val_loss: 0.0338
# Epoch 183/1000
# mean max of probabilities: 0.0001494496 - temperature 3.3637624
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0311 - val_loss: 0.0336
# Epoch 184/1000
# mean max of probabilities: 0.00015014775 - temperature 3.3436856
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0311 - val_loss: 0.0336
# Epoch 185/1000
# mean max of probabilities: 0.00015085982 - temperature 3.3237283
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0311 - val_loss: 0.0337
# Epoch 186/1000
# mean max of probabilities: 0.00015159385 - temperature 3.3038907
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0307 - val_loss: 0.0332
# Epoch 187/1000
# mean max of probabilities: 0.0001523305 - temperature 3.2841713
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0307 - val_loss: 0.0331
# Epoch 188/1000
# mean max of probabilities: 0.00015303299 - temperature 3.2645695
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0330
# Epoch 189/1000
# mean max of probabilities: 0.00015377061 - temperature 3.245085
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.0329
# Epoch 190/1000
# mean max of probabilities: 0.00015448878 - temperature 3.2257168
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0302 - val_loss: 0.0328
# Epoch 191/1000
# mean max of probabilities: 0.00015523485 - temperature 3.206464
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0301 - val_loss: 0.0321
# Epoch 192/1000
# mean max of probabilities: 0.00015597182 - temperature 3.1873262
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0299 - val_loss: 0.0321
# Epoch 193/1000
# mean max of probabilities: 0.00015669115 - temperature 3.1683025
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0297 - val_loss: 0.0321
# Epoch 194/1000
# mean max of probabilities: 0.00015742719 - temperature 3.1493926
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0294 - val_loss: 0.0320
# Epoch 195/1000
# mean max of probabilities: 0.0001581683 - temperature 3.1305954
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0293 - val_loss: 0.0314
# Epoch 196/1000
# mean max of probabilities: 0.00015882895 - temperature 3.1119103
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0293 - val_loss: 0.0317
# Epoch 197/1000
# mean max of probabilities: 0.00015956794 - temperature 3.0933368
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0288 - val_loss: 0.0314
# Epoch 198/1000
# mean max of probabilities: 0.00016029223 - temperature 3.0748744
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0288 - val_loss: 0.0312
# Epoch 199/1000
# mean max of probabilities: 0.00016099113 - temperature 3.056522
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0286 - val_loss: 0.0309
# Epoch 200/1000
# mean max of probabilities: 0.00016170787 - temperature 3.038279
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0284 - val_loss: 0.0309
# Epoch 201/1000
# mean max of probabilities: 0.00016237397 - temperature 3.020145
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0281 - val_loss: 0.0305
# Epoch 202/1000
# mean max of probabilities: 0.00016301064 - temperature 3.0021193
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0280 - val_loss: 0.0305
# Epoch 203/1000
# mean max of probabilities: 0.00016364804 - temperature 2.9842014
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0279 - val_loss: 0.0301
# Epoch 204/1000
# mean max of probabilities: 0.00016427868 - temperature 2.9663901
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0277 - val_loss: 0.0300
# Epoch 205/1000
# mean max of probabilities: 0.00016492134 - temperature 2.9486852
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0276 - val_loss: 0.0310
# Epoch 206/1000
# mean max of probabilities: 0.00016556581 - temperature 2.9310858
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0275 - val_loss: 0.0300
# Epoch 207/1000
# mean max of probabilities: 0.0001661541 - temperature 2.9135914
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0272 - val_loss: 0.0298
# Epoch 208/1000
# mean max of probabilities: 0.00016670255 - temperature 2.8962016
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0271 - val_loss: 0.0293
# Epoch 209/1000
# mean max of probabilities: 0.00016724961 - temperature 2.8789155
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0270 - val_loss: 0.0294
# Epoch 210/1000
# mean max of probabilities: 0.00016779453 - temperature 2.8617325
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0269 - val_loss: 0.0295
# Epoch 211/1000
# mean max of probabilities: 0.00016830306 - temperature 2.8446522
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0269 - val_loss: 0.0294
# Epoch 212/1000
# mean max of probabilities: 0.0001687705 - temperature 2.8276742
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0269 - val_loss: 0.0292
# Epoch 213/1000
# mean max of probabilities: 0.00016923962 - temperature 2.810797
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0267 - val_loss: 0.0290
# Epoch 214/1000
# mean max of probabilities: 0.00016964694 - temperature 2.7940204
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0266 - val_loss: 0.0290
# Epoch 215/1000
# mean max of probabilities: 0.00017004018 - temperature 2.7773445
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0265 - val_loss: 0.0290
# Epoch 216/1000
# mean max of probabilities: 0.0001704042 - temperature 2.760768
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0264 - val_loss: 0.0288
# Epoch 217/1000
# mean max of probabilities: 0.00017073273 - temperature 2.74429
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0264 - val_loss: 0.0288
# Epoch 218/1000
# mean max of probabilities: 0.00017106993 - temperature 2.727911
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0263 - val_loss: 0.0287
# Epoch 219/1000
# mean max of probabilities: 0.00017137671 - temperature 2.7116294
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0262 - val_loss: 0.0288
# Epoch 220/1000
# mean max of probabilities: 0.00017165516 - temperature 2.6954448
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0263 - val_loss: 0.0286
# Epoch 221/1000
# mean max of probabilities: 0.00017188594 - temperature 2.6793568
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0262 - val_loss: 0.0287
# Epoch 222/1000
# mean max of probabilities: 0.00017210138 - temperature 2.6633651
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0262 - val_loss: 0.0287
# Epoch 223/1000
# mean max of probabilities: 0.00017229441 - temperature 2.6474688
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0262 - val_loss: 0.0286
# Epoch 224/1000
# mean max of probabilities: 0.00017246907 - temperature 2.6316674
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0261 - val_loss: 0.0285
# Epoch 225/1000
# mean max of probabilities: 0.00017261293 - temperature 2.6159604
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0261 - val_loss: 0.0285
# Epoch 226/1000
# mean max of probabilities: 0.00017273599 - temperature 2.600347
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0262 - val_loss: 0.0287
# Epoch 227/1000
# mean max of probabilities: 0.0001728682 - temperature 2.5848267
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0261 - val_loss: 0.0285
# Epoch 228/1000
# mean max of probabilities: 0.00017298078 - temperature 2.569399
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0261 - val_loss: 0.0284
# Epoch 229/1000
# mean max of probabilities: 0.00017309205 - temperature 2.5540636
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 230/1000
# mean max of probabilities: 0.00017318223 - temperature 2.5388196
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0260 - val_loss: 0.0286
# Epoch 231/1000
# mean max of probabilities: 0.00017324455 - temperature 2.5236669
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0260 - val_loss: 0.0286
# Epoch 232/1000
# mean max of probabilities: 0.00017329757 - temperature 2.5086043
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0260 - val_loss: 0.0283
# Epoch 233/1000
# mean max of probabilities: 0.00017334495 - temperature 2.4936316
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0285
# Epoch 234/1000
# mean max of probabilities: 0.00017336811 - temperature 2.4787483
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 235/1000
# mean max of probabilities: 0.00017337847 - temperature 2.4639542
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 236/1000
# mean max of probabilities: 0.0001733946 - temperature 2.4492478
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 237/1000
# mean max of probabilities: 0.00017342952 - temperature 2.4346297
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0260 - val_loss: 0.0285
# Epoch 238/1000
# mean max of probabilities: 0.00017345019 - temperature 2.4200985
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0260 - val_loss: 0.0285
# Epoch 239/1000
# mean max of probabilities: 0.00017346707 - temperature 2.4056542
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0260 - val_loss: 0.0285
# Epoch 240/1000
# mean max of probabilities: 0.0001734645 - temperature 2.391296
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0260 - val_loss: 0.0287
# Epoch 241/1000
# mean max of probabilities: 0.00017345691 - temperature 2.3770237
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 242/1000
# mean max of probabilities: 0.00017347545 - temperature 2.3628364
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0260 - val_loss: 0.0285
# Epoch 243/1000
# mean max of probabilities: 0.00017347772 - temperature 2.3487337
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0259 - val_loss: 0.0284
# Epoch 244/1000
# mean max of probabilities: 0.000173479 - temperature 2.3347154
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 245/1000
# mean max of probabilities: 0.00017350391 - temperature 2.3207805
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0283
# Epoch 246/1000
# mean max of probabilities: 0.00017351095 - temperature 2.306929
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0283
# Epoch 247/1000
# mean max of probabilities: 0.00017352498 - temperature 2.2931604
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0285
# Epoch 248/1000
# mean max of probabilities: 0.00017349803 - temperature 2.2794733
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 249/1000
# mean max of probabilities: 0.00017345906 - temperature 2.2658682
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0259 - val_loss: 0.0284
# Epoch 250/1000
# mean max of probabilities: 0.00017347434 - temperature 2.2523453
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0283
# Epoch 251/1000
# mean max of probabilities: 0.00017349867 - temperature 2.238903
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 252/1000
# mean max of probabilities: 0.0001734893 - temperature 2.2255414
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 253/1000
# mean max of probabilities: 0.00017345969 - temperature 2.2122571
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 254/1000
# mean max of probabilities: 0.0001734724 - temperature 2.1990535
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0260 - val_loss: 0.0283
# Epoch 255/1000
# mean max of probabilities: 0.00017348897 - temperature 2.185928
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0259 - val_loss: 0.0283
# Epoch 256/1000
# mean max of probabilities: 0.00017350377 - temperature 2.1728814
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0259 - val_loss: 0.0283
# Epoch 257/1000
# mean max of probabilities: 0.00017352575 - temperature 2.1599126
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0260 - val_loss: 0.0282
# Epoch 258/1000
# mean max of probabilities: 0.00017350857 - temperature 2.147021
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0259 - val_loss: 0.0282
# Epoch 259/1000
# mean max of probabilities: 0.00017356357 - temperature 2.1342065
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0259 - val_loss: 0.0282
# Epoch 260/1000
# mean max of probabilities: 0.00017362364 - temperature 2.1214688
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0259 - val_loss: 0.0282
# Epoch 261/1000
# mean max of probabilities: 0.00017360468 - temperature 2.1088066
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0259 - val_loss: 0.0283
# Epoch 262/1000
# mean max of probabilities: 0.0001736549 - temperature 2.0962203
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0259 - val_loss: 0.0282
# Epoch 263/1000
# mean max of probabilities: 0.000173696 - temperature 2.0837092
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0261 - val_loss: 0.0284
# Epoch 264/1000
# mean max of probabilities: 0.00017373214 - temperature 2.0712726
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0288
# Epoch 265/1000
# mean max of probabilities: 0.00017382782 - temperature 2.0589101
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0260 - val_loss: 0.0282
# Epoch 266/1000
# mean max of probabilities: 0.00017393086 - temperature 2.0466216
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0259 - val_loss: 0.0283
# Epoch 267/1000
# mean max of probabilities: 0.0001739895 - temperature 2.0344064
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0259 - val_loss: 0.0282
# Epoch 268/1000
# mean max of probabilities: 0.00017393853 - temperature 2.022264
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0259 - val_loss: 0.0281
# Epoch 269/1000
# mean max of probabilities: 0.00017394968 - temperature 2.0101943
# 160/160 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 270/1000
# mean max of probabilities: 0.00017402782 - temperature 1.9981962
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0259 - val_loss: 0.0285
# Epoch 271/1000
# mean max of probabilities: 0.00017404516 - temperature 1.98627
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0259 - val_loss: 0.0282
# Epoch 272/1000
# mean max of probabilities: 0.00017404137 - temperature 1.974415
# ...
# Epoch 905/1000
# mean max of probabilities: 0.00027884988 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0323 - val_loss: 0.0342
# Epoch 906/1000
# mean max of probabilities: 0.00027884706 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0308 - val_loss: 0.0317
# Epoch 907/1000
# mean max of probabilities: 0.00027884525 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0311 - val_loss: 0.0365
# Epoch 908/1000
# mean max of probabilities: 0.0002788441 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0347 - val_loss: 0.0342
# Epoch 909/1000
# mean max of probabilities: 0.00027884875 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0330 - val_loss: 0.0356
# Epoch 910/1000
# mean max of probabilities: 0.00027888297 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0331 - val_loss: 0.0309
# Epoch 911/1000
# mean max of probabilities: 0.00027889363 - temperature 0.1
# 160/160 [==============================] - 2s 16ms/step - loss: 0.0329 - val_loss: 0.0308
# Epoch 912/1000
# mean max of probabilities: 0.00027889613 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0325 - val_loss: 0.0322
# Epoch 913/1000
# mean max of probabilities: 0.00027889613 - temperature 0.1
# 160/160 [==============================] - 2s 16ms/step - loss: 0.0330 - val_loss: 0.0359
# Epoch 914/1000
# mean max of probabilities: 0.00027889712 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0326 - val_loss: 0.0356
# Epoch 915/1000
# mean max of probabilities: 0.00027891257 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0309 - val_loss: 0.0324
# Epoch 916/1000
# mean max of probabilities: 0.00027893047 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0331 - val_loss: 0.0350
# Epoch 917/1000
# mean max of probabilities: 0.00027893553 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0356 - val_loss: 0.0359
# Epoch 918/1000
# mean max of probabilities: 0.00027893652 - temperature 0.1
# 160/160 [==============================] - 3s 19ms/step - loss: 0.0326 - val_loss: 0.0370
# Epoch 919/1000
# mean max of probabilities: 0.00027893586 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0341 - val_loss: 0.0309
# Epoch 920/1000
# mean max of probabilities: 0.00027893475 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0323 - val_loss: 0.0341
# Epoch 921/1000
# mean max of probabilities: 0.00027900323 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0332 - val_loss: 0.0372
# Epoch 922/1000
# mean max of probabilities: 0.00027903647 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0341 - val_loss: 0.0342
# Epoch 923/1000
# mean max of probabilities: 0.000279047 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0320 - val_loss: 0.0328
# Epoch 924/1000
# mean max of probabilities: 0.0002790497 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0327 - val_loss: 0.0326
# Epoch 925/1000
# mean max of probabilities: 0.00027905207 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0318 - val_loss: 0.0344
# Epoch 926/1000
# mean max of probabilities: 0.00027905244 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0329 - val_loss: 0.0396
# Epoch 927/1000
# mean max of probabilities: 0.0002790515 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0332 - val_loss: 0.0311
# Epoch 928/1000
# mean max of probabilities: 0.000279061 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0315 - val_loss: 0.0392
# Epoch 929/1000
# mean max of probabilities: 0.0002791243 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0339 - val_loss: 0.0323
# Epoch 930/1000
# mean max of probabilities: 0.0002791457 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0331 - val_loss: 0.0346
# Epoch 931/1000
# mean max of probabilities: 0.00027915224 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0313 - val_loss: 0.0309
# Epoch 932/1000
# mean max of probabilities: 0.00027915643 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0300 - val_loss: 0.0327
# Epoch 933/1000
# mean max of probabilities: 0.00027915672 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0336 - val_loss: 0.0302
# Epoch 934/1000
# mean max of probabilities: 0.00027915867 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0319 - val_loss: 0.0345
# Epoch 935/1000
# mean max of probabilities: 0.00027918996 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0350 - val_loss: 0.0341
# Epoch 936/1000
# mean max of probabilities: 0.00027931057 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0333 - val_loss: 0.0340
# Epoch 937/1000
# mean max of probabilities: 0.00027935256 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0340 - val_loss: 0.0352
# Epoch 938/1000
# mean max of probabilities: 0.00027936645 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0353 - val_loss: 0.0334
# Epoch 939/1000
# mean max of probabilities: 0.0002793704 - temperature 0.1
# 160/160 [==============================] - 3s 19ms/step - loss: 0.0316 - val_loss: 0.0368
# Epoch 940/1000
# mean max of probabilities: 0.0002793901 - temperature 0.1
# 160/160 [==============================] - 3s 19ms/step - loss: 0.0319 - val_loss: 0.0306
# Epoch 941/1000
# mean max of probabilities: 0.00027943985 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0337 - val_loss: 0.0343
# Epoch 942/1000
# mean max of probabilities: 0.000279519 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0357 - val_loss: 0.0321
# Epoch 943/1000
# mean max of probabilities: 0.00027954605 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0365 - val_loss: 0.0333
# Epoch 944/1000
# mean max of probabilities: 0.00027955457 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0324 - val_loss: 0.0370
# Epoch 945/1000
# mean max of probabilities: 0.0002795644 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0328 - val_loss: 0.0380
# Epoch 946/1000
# mean max of probabilities: 0.0002796122 - temperature 0.1
# 160/160 [==============================] - 2s 16ms/step - loss: 0.0329 - val_loss: 0.0343
# Epoch 947/1000
# mean max of probabilities: 0.00027971173 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0322 - val_loss: 0.0375
# Epoch 948/1000
# mean max of probabilities: 0.00027991738 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0350 - val_loss: 0.0326
# Epoch 949/1000
# mean max of probabilities: 0.00027998927 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0338 - val_loss: 0.0380
# Epoch 950/1000
# mean max of probabilities: 0.00028001305 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0327 - val_loss: 0.0342
# Epoch 951/1000
# mean max of probabilities: 0.00028002006 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0324 - val_loss: 0.0378
# Epoch 952/1000
# mean max of probabilities: 0.00027998918 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0315 - val_loss: 0.0368
# Epoch 953/1000
# mean max of probabilities: 0.00027998857 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0348 - val_loss: 0.0327
# Epoch 954/1000
# mean max of probabilities: 0.00027998706 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0327 - val_loss: 0.0362
# Epoch 955/1000
# mean max of probabilities: 0.0002799845 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0321 - val_loss: 0.0333
# Epoch 956/1000
# mean max of probabilities: 0.00027998255 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0320 - val_loss: 0.0320
# Epoch 957/1000
# mean max of probabilities: 0.00027998077 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0368 - val_loss: 0.0340
# Epoch 958/1000
# mean max of probabilities: 0.00028004928 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0344 - val_loss: 0.0323
# Epoch 959/1000
# mean max of probabilities: 0.00028011345 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0334 - val_loss: 0.0364
# Epoch 960/1000
# mean max of probabilities: 0.00028016648 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0329 - val_loss: 0.0356
# Epoch 961/1000
# mean max of probabilities: 0.00028021843 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0321 - val_loss: 0.0361
# Epoch 962/1000
# mean max of probabilities: 0.0002802787 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0335 - val_loss: 0.0347
# Epoch 963/1000
# mean max of probabilities: 0.00028029917 - temperature 0.1
# 160/160 [==============================] - 3s 19ms/step - loss: 0.0333 - val_loss: 0.0289
# Epoch 964/1000
# mean max of probabilities: 0.00028030504 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0326 - val_loss: 0.0354
# Epoch 965/1000
# mean max of probabilities: 0.000280306 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0317 - val_loss: 0.0339
# Epoch 966/1000
# mean max of probabilities: 0.0002803055 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0332 - val_loss: 0.0350
# Epoch 967/1000
# mean max of probabilities: 0.0002803041 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0337 - val_loss: 0.0365
# Epoch 968/1000
# mean max of probabilities: 0.00028030254 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0315 - val_loss: 0.0397
# Epoch 969/1000
# mean max of probabilities: 0.00028030094 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0338 - val_loss: 0.0352
# Epoch 970/1000
# mean max of probabilities: 0.00028029917 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0330 - val_loss: 0.0351
# Epoch 971/1000
# mean max of probabilities: 0.00028034847 - temperature 0.1
# 160/160 [==============================] - 3s 19ms/step - loss: 0.0317 - val_loss: 0.0329
# Epoch 972/1000
# mean max of probabilities: 0.00028039352 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0324 - val_loss: 0.0351
# Epoch 973/1000
# mean max of probabilities: 0.00028040976 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0336 - val_loss: 0.0360
# Epoch 974/1000
# mean max of probabilities: 0.0002804143 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0344 - val_loss: 0.0331
# Epoch 975/1000
# mean max of probabilities: 0.00028045475 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0337 - val_loss: 0.0325
# Epoch 976/1000
# mean max of probabilities: 0.00028046785 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0338 - val_loss: 0.0347
# Epoch 977/1000
# mean max of probabilities: 0.0002804725 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0348 - val_loss: 0.0340
# Epoch 978/1000
# mean max of probabilities: 0.00028047973 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0342 - val_loss: 0.0340
# Epoch 979/1000
# mean max of probabilities: 0.00028050988 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0338 - val_loss: 0.0322
# Epoch 980/1000
# mean max of probabilities: 0.00028051922 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0326 - val_loss: 0.0352
# Epoch 981/1000
# mean max of probabilities: 0.0002805622 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0348 - val_loss: 0.0325
# Epoch 982/1000
# mean max of probabilities: 0.00028057658 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0334 - val_loss: 0.0369
# Epoch 983/1000
# mean max of probabilities: 0.00028059335 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0318 - val_loss: 0.0336
# Epoch 984/1000
# mean max of probabilities: 0.00028059998 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0338 - val_loss: 0.0356
# Epoch 985/1000
# mean max of probabilities: 0.00028060135 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0312 - val_loss: 0.0363
# Epoch 986/1000
# mean max of probabilities: 0.00028060077 - temperature 0.1
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0329 - val_loss: 0.0359
# Epoch 987/1000
# mean max of probabilities: 0.00028059952 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0342 - val_loss: 0.0377
# Epoch 988/1000
# mean max of probabilities: 0.00028059937 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0319 - val_loss: 0.0388
# Epoch 989/1000
# mean max of probabilities: 0.00028061977 - temperature 0.1
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0315 - val_loss: 0.0361
# Epoch 990/1000
# mean max of probabilities: 0.00028062795 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0348 - val_loss: 0.0358
# Epoch 991/1000
# mean max of probabilities: 0.00028063 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0314 - val_loss: 0.0340
# Epoch 992/1000
# mean max of probabilities: 0.0002806401 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0321 - val_loss: 0.0335
# Epoch 993/1000
# mean max of probabilities: 0.0002806612 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0341 - val_loss: 0.0333
# Epoch 994/1000
# mean max of probabilities: 0.00028066762 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0326 - val_loss: 0.0355
# Epoch 995/1000
# mean max of probabilities: 0.00028066855 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0341 - val_loss: 0.0424
# Epoch 996/1000
# mean max of probabilities: 0.0002806615 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0342 - val_loss: 0.0331
# Epoch 997/1000
# mean max of probabilities: 0.00028065257 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0322 - val_loss: 0.0340
# Epoch 998/1000
# mean max of probabilities: 0.00028064847 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0322 - val_loss: 0.0327
# Epoch 999/1000
# mean max of probabilities: 0.00028064614 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0331 - val_loss: 0.0345
# Epoch 1000/1000
# mean max of probabilities: 0.00028064457 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0315 - val_loss: 0.0385
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
train_compressed_Data.shape
# Out:
# (200, 64)

# %% [markdown]
# # 4. Classifying

# %% [markdown]
# ### Extra Trees

# %%
train_feature=C_train_x
train_label=C_train_y
test_feature=C_test_x
test_label=C_test_y

print('Shape of train_feature: ' + str(train_feature.shape)) 
print('Shape of train_label: ' + str(train_label.shape)) 
print('Shape of test_feature: ' + str(test_feature.shape)) 
print('Shape of test_label: ' + str(test_label.shape)) 

p_seed=seed
ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Shape of train_feature: (160, 10000)
# Shape of train_label: (160,)
# Shape of test_feature: (40, 10000)
# Shape of test_label: (40,)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.85
# Testing accuracy： 0.85

# %%
C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,label_arr,test_size=0.2,random_state=seed)

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape))
# Out:
# Shape of C_train_x: (160, 10000)
# Shape of C_train_y: (160,)
# Shape of C_test_x: (40, 10000)
# Shape of C_test_y: (40,)

# %%
train_feature=C_train_selected_x
train_label=C_train_y

test_feature=C_test_selected_x
test_label=C_test_y

print('Shape of train_feature: ' + str(train_feature.shape)) 
print('Shape of train_label: ' + str(train_label.shape)) 
print('Shape of test_feature: ' + str(test_feature.shape)) 
print('Shape of test_label: ' + str(test_label.shape)) 

p_seed=seed
ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Shape of train_feature: (160, 64)
# Shape of train_label: (160,)
# Shape of test_feature: (40, 64)
# Shape of test_label: (40,)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.775
# Testing accuracy： 0.775

# %% [markdown]
# # 5. Classifying 2

# %% [markdown]
# ## Extra Trees

# %%
train_feature=C_train_selected_x
train_label=C_train_y

test_feature=C_test_selected_x
test_label=C_test_y

print('Shape of train_feature: ' + str(train_feature.shape)) 
print('Shape of train_label: ' + str(train_label.shape)) 
print('Shape of test_feature: ' + str(test_feature.shape)) 
print('Shape of test_label: ' + str(test_label.shape)) 

p_seed=seed
ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Shape of train_feature: (160, 64)
# Shape of train_label: (160,)
# Shape of test_feature: (40, 64)
# Shape of test_label: (40,)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.775
# Testing accuracy： 0.775

# %% [markdown]
# # 6. Reconstruction loss

# %%
from sklearn.linear_model import LinearRegression

def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR

# %%
train_feature_tuple=(C_train_selected_x,C_train_x)
test_feature_tuple=(C_test_selected_x,C_test_x)

reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
print(reconstruction_loss)
# Out:
# 0.028948115205964683
