# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io

from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.function.similarity_based import lap_score
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.function.sparse_learning_based.UDFS import udfs
from skfeature.utility.sparse_learning import feature_ranking
import time

from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def ETree(p_train_feature,p_train_label,p_test_feature,p_test_label,p_seed):
    clf = ExtraTreesClassifier(n_estimators=50, random_state=p_seed)
    
    # Training
    clf.fit(p_train_feature, p_train_label)
    
    # Training accuracy
    print('Training accuracy：',clf.score(p_train_feature, np.array(p_train_label)))
    print('Training accuracy：',accuracy_score(np.array(p_train_label),clf.predict(p_train_feature)))
    #print('Training accuracy：',np.sum(clf.predict(p_train_feature)==np.array(p_train_label))/p_train_label.shape[0])

    # Testing accuracy
    print('Testing accuracy：',clf.score(p_test_feature, np.array(p_test_label)))
    print('Testing accuracy：',accuracy_score(np.array(p_test_label),clf.predict(p_test_feature)))
    #print('Testing accuracy：',np.sum(clf.predict(p_test_feature)==np.array(p_test_label))/p_test_label.shape[0])

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')

# %% [markdown]
# # 2. Loading data

# %%
data_path="./Dataset/SMK_CAN_187.mat"
Data = scipy.io.loadmat(data_path)

data_arr=Data['X']
label_arr=Data['Y'][:, 0]-1

C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(data_arr,label_arr,test_size=0.2,random_state=seed)

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape))
# Out:
# Shape of C_train_x: (149, 19993)
# Shape of C_train_y: (149,)
# Shape of C_test_x: (38, 19993)
# Shape of C_test_y: (38,)

# %%
key_feture_number=64

# %% [markdown]
# # 3. Model

# %%
def decoder(x):
    x = Dense(key_feture_number)(x)
    x = Dense(data_arr.shape[1])(x)
    return x

# %%
start = time.clock()

selector = ConcreteAutoencoderFeatureSelector(K = key_feture_number, output_function = decoder, num_epochs = 1000)
selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)

train_compressed_Data=data_arr[:, selector.get_support(indices=True)]

time_cost=time.clock() - start
write_to_csv(np.array([time_cost]),"./log/CAS_time"+str(key_feture_number)+".csv")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 19993)             0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                1279553
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 19993)             1299545
# =================================================================
# Total params: 2,583,258
# Trainable params: 2,583,257
# Non-trainable params: 1
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 149 samples, validate on 38 samples
# Epoch 1/1000
# mean max of probabilities: 5.1163606e-05 - temperature 10.0
# 149/149 [==============================] - 1s 5ms/step - loss: 23.8005 - val_loss: 4.9219
# Epoch 2/1000
# mean max of probabilities: 5.125959e-05 - temperature 9.940314
# 149/149 [==============================] - 1s 3ms/step - loss: 3.1733 - val_loss: 2.4004
# Epoch 3/1000
# mean max of probabilities: 5.1331594e-05 - temperature 9.880986
# 149/149 [==============================] - 1s 3ms/step - loss: 1.0732 - val_loss: 1.0150
# Epoch 4/1000
# mean max of probabilities: 5.122298e-05 - temperature 9.822011
# 149/149 [==============================] - 1s 4ms/step - loss: 0.7633 - val_loss: 0.2328
# Epoch 5/1000
# mean max of probabilities: 5.1235358e-05 - temperature 9.763389
# 149/149 [==============================] - 1s 4ms/step - loss: 0.3191 - val_loss: 0.2188
# Epoch 6/1000
# mean max of probabilities: 5.1239233e-05 - temperature 9.705116
# 149/149 [==============================] - 1s 4ms/step - loss: 0.2132 - val_loss: 0.1970
# Epoch 7/1000
# mean max of probabilities: 5.1239793e-05 - temperature 9.647191
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1884 - val_loss: 0.1654
# Epoch 8/1000
# mean max of probabilities: 5.12433e-05 - temperature 9.589611
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1775 - val_loss: 0.1544
# Epoch 9/1000
# mean max of probabilities: 5.1243675e-05 - temperature 9.532376
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1726 - val_loss: 0.1507
# Epoch 10/1000
# mean max of probabilities: 5.1245395e-05 - temperature 9.475481
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1706 - val_loss: 0.1498
# Epoch 11/1000
# mean max of probabilities: 5.12466e-05 - temperature 9.418927
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1704 - val_loss: 0.1510
# Epoch 12/1000
# mean max of probabilities: 5.1248484e-05 - temperature 9.36271
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1701 - val_loss: 0.1496
# Epoch 13/1000
# mean max of probabilities: 5.1250347e-05 - temperature 9.3068285
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1698 - val_loss: 0.1500
# Epoch 14/1000
# mean max of probabilities: 5.125237e-05 - temperature 9.251281
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1504
# Epoch 15/1000
# mean max of probabilities: 5.1254803e-05 - temperature 9.196063
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1710 - val_loss: 0.1500
# Epoch 16/1000
# mean max of probabilities: 5.1257884e-05 - temperature 9.141178
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1702 - val_loss: 0.1499
# Epoch 17/1000
# mean max of probabilities: 5.1261864e-05 - temperature 9.086616
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1705 - val_loss: 0.1500
# Epoch 18/1000
# mean max of probabilities: 5.1266554e-05 - temperature 9.032384
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1709 - val_loss: 0.1503
# Epoch 19/1000
# mean max of probabilities: 5.127171e-05 - temperature 8.978478
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1716 - val_loss: 0.1505
# Epoch 20/1000
# mean max of probabilities: 5.12779e-05 - temperature 8.924895
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1691 - val_loss: 0.1513
# Epoch 21/1000
# mean max of probabilities: 5.128362e-05 - temperature 8.871623
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1724 - val_loss: 0.1505
# Epoch 22/1000
# mean max of probabilities: 5.128994e-05 - temperature 8.818672
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1713 - val_loss: 0.1496
# Epoch 23/1000
# mean max of probabilities: 5.1296374e-05 - temperature 8.766038
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1706 - val_loss: 0.1508
# Epoch 24/1000
# mean max of probabilities: 5.1302963e-05 - temperature 8.713719
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1719 - val_loss: 0.1504
# Epoch 25/1000
# mean max of probabilities: 5.1310766e-05 - temperature 8.661711
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1712 - val_loss: 0.1502
# Epoch 26/1000
# mean max of probabilities: 5.1318188e-05 - temperature 8.610013
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1717 - val_loss: 0.1505
# Epoch 27/1000
# mean max of probabilities: 5.1327028e-05 - temperature 8.558624
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1703 - val_loss: 0.1505
# Epoch 28/1000
# mean max of probabilities: 5.133563e-05 - temperature 8.507542
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1714 - val_loss: 0.1501
# Epoch 29/1000
# mean max of probabilities: 5.1344156e-05 - temperature 8.456765
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1733 - val_loss: 0.1513
# Epoch 30/1000
# mean max of probabilities: 5.1353898e-05 - temperature 8.40629
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1720 - val_loss: 0.1501
# Epoch 31/1000
# mean max of probabilities: 5.1363488e-05 - temperature 8.356117
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1712 - val_loss: 0.1507
# Epoch 32/1000
# mean max of probabilities: 5.1373652e-05 - temperature 8.306244
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1731 - val_loss: 0.1501
# Epoch 33/1000
# mean max of probabilities: 5.1385483e-05 - temperature 8.256668
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1704 - val_loss: 0.1506
# Epoch 34/1000
# mean max of probabilities: 5.1396564e-05 - temperature 8.207388
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1701 - val_loss: 0.1514
# Epoch 35/1000
# mean max of probabilities: 5.140891e-05 - temperature 8.158402
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1737 - val_loss: 0.1502
# Epoch 36/1000
# mean max of probabilities: 5.1422423e-05 - temperature 8.109709
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1735 - val_loss: 0.1503
# Epoch 37/1000
# mean max of probabilities: 5.1434927e-05 - temperature 8.061306
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1725 - val_loss: 0.1508
# Epoch 38/1000
# mean max of probabilities: 5.144832e-05 - temperature 8.013191
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1726 - val_loss: 0.1506
# Epoch 39/1000
# mean max of probabilities: 5.1461917e-05 - temperature 7.9653645
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1711 - val_loss: 0.1501
# Epoch 40/1000
# mean max of probabilities: 5.1475276e-05 - temperature 7.9178233
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1723 - val_loss: 0.1503
# Epoch 41/1000
# mean max of probabilities: 5.148884e-05 - temperature 7.8705645
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1717 - val_loss: 0.1504
# Epoch 42/1000
# mean max of probabilities: 5.1502902e-05 - temperature 7.823588
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1714 - val_loss: 0.1501
# Epoch 43/1000
# mean max of probabilities: 5.1517905e-05 - temperature 7.7768927
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1721 - val_loss: 0.1507
# Epoch 44/1000
# mean max of probabilities: 5.1532144e-05 - temperature 7.730476
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1733 - val_loss: 0.1508
# Epoch 45/1000
# mean max of probabilities: 5.154865e-05 - temperature 7.6843367
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1706 - val_loss: 0.1507
# Epoch 46/1000
# mean max of probabilities: 5.1564464e-05 - temperature 7.6384726
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1721 - val_loss: 0.1507
# Epoch 47/1000
# mean max of probabilities: 5.157842e-05 - temperature 7.592882
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1723 - val_loss: 0.1502
# Epoch 48/1000
# mean max of probabilities: 5.1593488e-05 - temperature 7.5475636
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1737 - val_loss: 0.1502
# Epoch 49/1000
# mean max of probabilities: 5.1609004e-05 - temperature 7.5025163
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1743 - val_loss: 0.1505
# Epoch 50/1000
# mean max of probabilities: 5.162584e-05 - temperature 7.4577374
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1713 - val_loss: 0.1510
# Epoch 51/1000
# mean max of probabilities: 5.1643296e-05 - temperature 7.4132257
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1717 - val_loss: 0.1503
# Epoch 52/1000
# mean max of probabilities: 5.1659576e-05 - temperature 7.36898
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1716 - val_loss: 0.1506
# Epoch 53/1000
# mean max of probabilities: 5.1676638e-05 - temperature 7.324998
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1731 - val_loss: 0.1503
# Epoch 54/1000
# mean max of probabilities: 5.1694224e-05 - temperature 7.281278
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1734 - val_loss: 0.1509
# Epoch 55/1000
# mean max of probabilities: 5.171046e-05 - temperature 7.2378197
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1719 - val_loss: 0.1505
# Epoch 56/1000
# mean max of probabilities: 5.1728835e-05 - temperature 7.1946206
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1726 - val_loss: 0.1511
# Epoch 57/1000
# mean max of probabilities: 5.174666e-05 - temperature 7.15168
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1730 - val_loss: 0.1503
# Epoch 58/1000
# mean max of probabilities: 5.176728e-05 - temperature 7.108995
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1730 - val_loss: 0.1507
# Epoch 59/1000
# mean max of probabilities: 5.178573e-05 - temperature 7.066565
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1767 - val_loss: 0.1530
# Epoch 60/1000
# mean max of probabilities: 5.1805553e-05 - temperature 7.0243883
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1810 - val_loss: 0.1517
# Epoch 61/1000
# mean max of probabilities: 5.1824223e-05 - temperature 6.982463
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1717 - val_loss: 0.1515
# Epoch 62/1000
# mean max of probabilities: 5.1843912e-05 - temperature 6.940788
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1714 - val_loss: 0.1512
# Epoch 63/1000
# mean max of probabilities: 5.1864954e-05 - temperature 6.8993616
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1720 - val_loss: 0.1504
# Epoch 64/1000
# mean max of probabilities: 5.1884403e-05 - temperature 6.8581824
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1724 - val_loss: 0.1503
# Epoch 65/1000
# mean max of probabilities: 5.1905714e-05 - temperature 6.8172503
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1735 - val_loss: 0.1524
# Epoch 66/1000
# mean max of probabilities: 5.1926378e-05 - temperature 6.776561
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1784 - val_loss: 0.1520
# Epoch 67/1000
# mean max of probabilities: 5.1946765e-05 - temperature 6.736113
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1769 - val_loss: 0.1524
# Epoch 68/1000
# mean max of probabilities: 5.197211e-05 - temperature 6.695907
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1724 - val_loss: 0.1511
# Epoch 69/1000
# mean max of probabilities: 5.199502e-05 - temperature 6.655943
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1729 - val_loss: 0.1524
# Epoch 70/1000
# mean max of probabilities: 5.2017225e-05 - temperature 6.6162167
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1746 - val_loss: 0.1516
# Epoch 71/1000
# mean max of probabilities: 5.2042302e-05 - temperature 6.576728
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1746 - val_loss: 0.1509
# Epoch 72/1000
# mean max of probabilities: 5.206451e-05 - temperature 6.5374746
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1789 - val_loss: 0.1543
# Epoch 73/1000
# mean max of probabilities: 5.2090734e-05 - temperature 6.4984555
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1761 - val_loss: 0.1509
# Epoch 74/1000
# mean max of probabilities: 5.2114123e-05 - temperature 6.4596696
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1735 - val_loss: 0.1510
# Epoch 75/1000
# mean max of probabilities: 5.2139105e-05 - temperature 6.4211154
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1724 - val_loss: 0.1509
# Epoch 76/1000
# mean max of probabilities: 5.2164673e-05 - temperature 6.382791
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1723 - val_loss: 0.1505
# Epoch 77/1000
# mean max of probabilities: 5.2191186e-05 - temperature 6.344695
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1716 - val_loss: 0.1521
# Epoch 78/1000
# mean max of probabilities: 5.2218933e-05 - temperature 6.3068266
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1725 - val_loss: 0.1519
# Epoch 79/1000
# mean max of probabilities: 5.2244584e-05 - temperature 6.2691846
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1739 - val_loss: 0.1528
# Epoch 80/1000
# mean max of probabilities: 5.227096e-05 - temperature 6.2317667
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1740 - val_loss: 0.1510
# Epoch 81/1000
# mean max of probabilities: 5.2299154e-05 - temperature 6.1945724
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1727 - val_loss: 0.1509
# Epoch 82/1000
# mean max of probabilities: 5.232846e-05 - temperature 6.1576
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1737 - val_loss: 0.1524
# Epoch 83/1000
# mean max of probabilities: 5.2356474e-05 - temperature 6.1208487
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1756 - val_loss: 0.1520
# Epoch 84/1000
# mean max of probabilities: 5.238714e-05 - temperature 6.084316
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1723 - val_loss: 0.1506
# Epoch 85/1000
# mean max of probabilities: 5.2417716e-05 - temperature 6.0480013
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1738 - val_loss: 0.1523
# Epoch 86/1000
# mean max of probabilities: 5.2447183e-05 - temperature 6.0119033
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1727 - val_loss: 0.1519
# Epoch 87/1000
# mean max of probabilities: 5.2476156e-05 - temperature 5.976022
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1727 - val_loss: 0.1528
# Epoch 88/1000
# mean max of probabilities: 5.2506097e-05 - temperature 5.9403534
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1775 - val_loss: 0.1525
# Epoch 89/1000
# mean max of probabilities: 5.253704e-05 - temperature 5.9048986
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1755 - val_loss: 0.1517
# Epoch 90/1000
# mean max of probabilities: 5.257131e-05 - temperature 5.869655
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1733 - val_loss: 0.1511
# Epoch 91/1000
# mean max of probabilities: 5.2602813e-05 - temperature 5.8346214
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1737 - val_loss: 0.1525
# Epoch 92/1000
# mean max of probabilities: 5.2634117e-05 - temperature 5.7997975
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1739 - val_loss: 0.1507
# Epoch 93/1000
# mean max of probabilities: 5.2668445e-05 - temperature 5.765181
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1743 - val_loss: 0.1542
# Epoch 94/1000
# mean max of probabilities: 5.2698786e-05 - temperature 5.7307715
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1811 - val_loss: 0.1583
# Epoch 95/1000
# mean max of probabilities: 5.273378e-05 - temperature 5.696567
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1781 - val_loss: 0.1618
# Epoch 96/1000
# mean max of probabilities: 5.276288e-05 - temperature 5.662567
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1899 - val_loss: 0.1574
# Epoch 97/1000
# mean max of probabilities: 5.279619e-05 - temperature 5.6287694
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1826 - val_loss: 0.1542
# Epoch 98/1000
# mean max of probabilities: 5.283558e-05 - temperature 5.595173
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1835 - val_loss: 0.1569
# Epoch 99/1000
# mean max of probabilities: 5.2869837e-05 - temperature 5.561778
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1814 - val_loss: 0.1559
# Epoch 100/1000
# mean max of probabilities: 5.2905583e-05 - temperature 5.5285826
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1788 - val_loss: 0.1538
# Epoch 101/1000
# mean max of probabilities: 5.2941698e-05 - temperature 5.4955854
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1765 - val_loss: 0.1516
# Epoch 102/1000
# mean max of probabilities: 5.2978332e-05 - temperature 5.462785
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1751 - val_loss: 0.1555
# Epoch 103/1000
# mean max of probabilities: 5.3020693e-05 - temperature 5.43018
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1786 - val_loss: 0.1529
# Epoch 104/1000
# mean max of probabilities: 5.3060452e-05 - temperature 5.39777
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1751 - val_loss: 0.1523
# Epoch 105/1000
# mean max of probabilities: 5.3098207e-05 - temperature 5.365553
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1836 - val_loss: 0.1527
# Epoch 106/1000
# mean max of probabilities: 5.3146017e-05 - temperature 5.3335285
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1746 - val_loss: 0.1520
# Epoch 107/1000
# mean max of probabilities: 5.3191117e-05 - temperature 5.301695
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1769 - val_loss: 0.1541
# Epoch 108/1000
# mean max of probabilities: 5.3229393e-05 - temperature 5.2700515
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1739 - val_loss: 0.1529
# Epoch 109/1000
# mean max of probabilities: 5.3269145e-05 - temperature 5.2385964
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1737 - val_loss: 0.1517
# Epoch 110/1000
# mean max of probabilities: 5.3308126e-05 - temperature 5.2073293
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1754 - val_loss: 0.1547
# Epoch 111/1000
# mean max of probabilities: 5.334756e-05 - temperature 5.1762495
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1751 - val_loss: 0.1519
# Epoch 112/1000
# mean max of probabilities: 5.339032e-05 - temperature 5.145355
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1766 - val_loss: 0.1522
# Epoch 113/1000
# mean max of probabilities: 5.3430766e-05 - temperature 5.114645
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1756 - val_loss: 0.1545
# Epoch 114/1000
# mean max of probabilities: 5.346984e-05 - temperature 5.084118
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1760 - val_loss: 0.1520
# Epoch 115/1000
# mean max of probabilities: 5.351482e-05 - temperature 5.0537734
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1731 - val_loss: 0.1528
# Epoch 116/1000
# mean max of probabilities: 5.355824e-05 - temperature 5.02361
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1755 - val_loss: 0.1551
# Epoch 117/1000
# mean max of probabilities: 5.3603057e-05 - temperature 4.9936266
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1756 - val_loss: 0.1518
# Epoch 118/1000
# mean max of probabilities: 5.3646436e-05 - temperature 4.9638224
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1722 - val_loss: 0.1522
# Epoch 119/1000
# mean max of probabilities: 5.3690073e-05 - temperature 4.9341955
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1735 - val_loss: 0.1519
# Epoch 120/1000
# mean max of probabilities: 5.3736752e-05 - temperature 4.9047456
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1745 - val_loss: 0.1518
# Epoch 121/1000
# mean max of probabilities: 5.37804e-05 - temperature 4.8754716
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1726 - val_loss: 0.1528
# Epoch 122/1000
# mean max of probabilities: 5.382351e-05 - temperature 4.8463726
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1748 - val_loss: 0.1606
# Epoch 123/1000
# mean max of probabilities: 5.3869022e-05 - temperature 4.8174467
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1810 - val_loss: 0.1621
# Epoch 124/1000
# mean max of probabilities: 5.3918557e-05 - temperature 4.7886934
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1809 - val_loss: 0.1642
# Epoch 125/1000
# mean max of probabilities: 5.3963922e-05 - temperature 4.760113
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1829 - val_loss: 0.1638
# Epoch 126/1000
# mean max of probabilities: 5.401212e-05 - temperature 4.7317014
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1804 - val_loss: 0.1553
# Epoch 127/1000
# mean max of probabilities: 5.4063625e-05 - temperature 4.7034607
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1785 - val_loss: 0.1541
# Epoch 128/1000
# mean max of probabilities: 5.4108677e-05 - temperature 4.6753883
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1767 - val_loss: 0.1524
# Epoch 129/1000
# mean max of probabilities: 5.4160515e-05 - temperature 4.6474833
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1755 - val_loss: 0.1538
# Epoch 130/1000
# mean max of probabilities: 5.4207656e-05 - temperature 4.6197443
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1751 - val_loss: 0.1549
# Epoch 131/1000
# mean max of probabilities: 5.4253178e-05 - temperature 4.5921717
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1796 - val_loss: 0.1650
# Epoch 132/1000
# mean max of probabilities: 5.4305332e-05 - temperature 4.564763
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1831 - val_loss: 0.1549
# Epoch 133/1000
# mean max of probabilities: 5.4357348e-05 - temperature 4.537519
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1763 - val_loss: 0.1517
# Epoch 134/1000
# mean max of probabilities: 5.4407406e-05 - temperature 4.510436
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1741 - val_loss: 0.1531
# Epoch 135/1000
# mean max of probabilities: 5.4458207e-05 - temperature 4.4835143
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1729 - val_loss: 0.1519
# Epoch 136/1000
# mean max of probabilities: 5.4511198e-05 - temperature 4.4567537
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1725 - val_loss: 0.1523
# Epoch 137/1000
# mean max of probabilities: 5.456198e-05 - temperature 4.4301543
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1742 - val_loss: 0.1521
# Epoch 138/1000
# mean max of probabilities: 5.4618205e-05 - temperature 4.4037127
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1752 - val_loss: 0.1557
# Epoch 139/1000
# mean max of probabilities: 5.4667995e-05 - temperature 4.3774295
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1791 - val_loss: 0.1537
# Epoch 140/1000
# mean max of probabilities: 5.4722208e-05 - temperature 4.351302
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1735 - val_loss: 0.1524
# Epoch 141/1000
# mean max of probabilities: 5.4777993e-05 - temperature 4.325331
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1739 - val_loss: 0.1570
# Epoch 142/1000
# mean max of probabilities: 5.4831973e-05 - temperature 4.2995152
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1790 - val_loss: 0.1588
# Epoch 143/1000
# mean max of probabilities: 5.488156e-05 - temperature 4.273854
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1794 - val_loss: 0.1645
# Epoch 144/1000
# mean max of probabilities: 5.4939243e-05 - temperature 4.248345
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1767 - val_loss: 0.1603
# Epoch 145/1000
# mean max of probabilities: 5.4994976e-05 - temperature 4.2229886
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1815 - val_loss: 0.1545
# Epoch 146/1000
# mean max of probabilities: 5.505231e-05 - temperature 4.1977835
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1748 - val_loss: 0.1530
# Epoch 147/1000
# mean max of probabilities: 5.5106357e-05 - temperature 4.172729
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1745 - val_loss: 0.1518
# Epoch 148/1000
# mean max of probabilities: 5.5170523e-05 - temperature 4.147824
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1738 - val_loss: 0.1527
# Epoch 149/1000
# mean max of probabilities: 5.52294e-05 - temperature 4.1230674
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1746 - val_loss: 0.1508
# Epoch 150/1000
# mean max of probabilities: 5.52906e-05 - temperature 4.098459
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1769 - val_loss: 0.1546
# Epoch 151/1000
# mean max of probabilities: 5.535019e-05 - temperature 4.073997
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1771 - val_loss: 0.1532
# Epoch 152/1000
# mean max of probabilities: 5.540848e-05 - temperature 4.049681
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1888 - val_loss: 0.1666
# Epoch 153/1000
# mean max of probabilities: 5.548066e-05 - temperature 4.025511
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1868 - val_loss: 0.1624
# Epoch 154/1000
# mean max of probabilities: 5.5549688e-05 - temperature 4.0014844
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1765 - val_loss: 0.1598
# Epoch 155/1000
# mean max of probabilities: 5.5616743e-05 - temperature 3.9776015
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1795 - val_loss: 0.1544
# Epoch 156/1000
# mean max of probabilities: 5.568104e-05 - temperature 3.953861
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1733 - val_loss: 0.1563
# Epoch 157/1000
# mean max of probabilities: 5.5744313e-05 - temperature 3.9302626
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1748 - val_loss: 0.1562
# Epoch 158/1000
# mean max of probabilities: 5.5807643e-05 - temperature 3.906805
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1745 - val_loss: 0.1536
# Epoch 159/1000
# mean max of probabilities: 5.5875527e-05 - temperature 3.8834872
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1769 - val_loss: 0.1567
# Epoch 160/1000
# mean max of probabilities: 5.5937642e-05 - temperature 3.8603084
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1739 - val_loss: 0.1527
# Epoch 161/1000
# mean max of probabilities: 5.6003726e-05 - temperature 3.837268
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1773 - val_loss: 0.1618
# Epoch 162/1000
# mean max of probabilities: 5.606271e-05 - temperature 3.8143651
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1898 - val_loss: 0.1636
# Epoch 163/1000
# mean max of probabilities: 5.6140198e-05 - temperature 3.791599
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1836 - val_loss: 0.1633
# Epoch 164/1000
# mean max of probabilities: 5.6210454e-05 - temperature 3.7689688
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1809 - val_loss: 0.1525
# Epoch 165/1000
# mean max of probabilities: 5.6276564e-05 - temperature 3.7464738
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1827 - val_loss: 0.1581
# Epoch 166/1000
# mean max of probabilities: 5.6346955e-05 - temperature 3.724113
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1779 - val_loss: 0.1563
# Epoch 167/1000
# mean max of probabilities: 5.641792e-05 - temperature 3.7018855
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1786 - val_loss: 0.1527
# Epoch 168/1000
# mean max of probabilities: 5.64909e-05 - temperature 3.679791
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1769 - val_loss: 0.1581
# Epoch 169/1000
# mean max of probabilities: 5.6564066e-05 - temperature 3.6578279
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1770 - val_loss: 0.1573
# Epoch 170/1000
# mean max of probabilities: 5.663416e-05 - temperature 3.6359959
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1817 - val_loss: 0.1552
# Epoch 171/1000
# mean max of probabilities: 5.6716304e-05 - temperature 3.6142943
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1796 - val_loss: 0.1566
# Epoch 172/1000
# mean max of probabilities: 5.679323e-05 - temperature 3.5927222
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1763 - val_loss: 0.1540
# Epoch 173/1000
# mean max of probabilities: 5.6859175e-05 - temperature 3.571279
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1783 - val_loss: 0.1563
# Epoch 174/1000
# mean max of probabilities: 5.693087e-05 - temperature 3.549964
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1763 - val_loss: 0.1526
# Epoch 175/1000
# mean max of probabilities: 5.701262e-05 - temperature 3.528776
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1757 - val_loss: 0.1541
# Epoch 176/1000
# mean max of probabilities: 5.7088277e-05 - temperature 3.507714
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1761 - val_loss: 0.1536
# Epoch 177/1000
# mean max of probabilities: 5.716186e-05 - temperature 3.4867785
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1756 - val_loss: 0.1525
# Epoch 178/1000
# mean max of probabilities: 5.7248762e-05 - temperature 3.4659677
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1770 - val_loss: 0.1541
# Epoch 179/1000
# mean max of probabilities: 5.7331818e-05 - temperature 3.445281
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1779 - val_loss: 0.1532
# Epoch 180/1000
# mean max of probabilities: 5.7414767e-05 - temperature 3.424718
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1761 - val_loss: 0.1523
# Epoch 181/1000
# mean max of probabilities: 5.7498888e-05 - temperature 3.404277
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1741 - val_loss: 0.1546
# Epoch 182/1000
# mean max of probabilities: 5.758107e-05 - temperature 3.3839583
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1737 - val_loss: 0.1513
# Epoch 183/1000
# mean max of probabilities: 5.766464e-05 - temperature 3.3637624
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1728 - val_loss: 0.1514
# Epoch 184/1000
# mean max of probabilities: 5.7747424e-05 - temperature 3.3436856
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1739 - val_loss: 0.1527
# Epoch 185/1000
# mean max of probabilities: 5.7831567e-05 - temperature 3.3237283
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1740 - val_loss: 0.1535
# Epoch 186/1000
# mean max of probabilities: 5.7923768e-05 - temperature 3.3038907
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1763 - val_loss: 0.1538
# Epoch 187/1000
# mean max of probabilities: 5.800563e-05 - temperature 3.2841713
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1744 - val_loss: 0.1521
# Epoch 188/1000
# mean max of probabilities: 5.8090445e-05 - temperature 3.2645695
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1726 - val_loss: 0.1535
# Epoch 189/1000
# mean max of probabilities: 5.8170117e-05 - temperature 3.245085
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1730 - val_loss: 0.1532
# Epoch 190/1000
# mean max of probabilities: 5.8258564e-05 - temperature 3.2257168
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1758 - val_loss: 0.1537
# Epoch 191/1000
# mean max of probabilities: 5.8337926e-05 - temperature 3.206464
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1809 - val_loss: 0.1537
# Epoch 192/1000
# mean max of probabilities: 5.8423844e-05 - temperature 3.1873262
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1761 - val_loss: 0.1537
# Epoch 193/1000
# mean max of probabilities: 5.8518926e-05 - temperature 3.1683025
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1780 - val_loss: 0.1523
# Epoch 194/1000
# mean max of probabilities: 5.8616908e-05 - temperature 3.1493926
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1767 - val_loss: 0.1535
# Epoch 195/1000
# mean max of probabilities: 5.8706464e-05 - temperature 3.1305954
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1760 - val_loss: 0.1600
# Epoch 196/1000
# mean max of probabilities: 5.880044e-05 - temperature 3.1119103
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1791 - val_loss: 0.1542
# Epoch 197/1000
# mean max of probabilities: 5.8886835e-05 - temperature 3.0933368
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1766 - val_loss: 0.1560
# Epoch 198/1000
# mean max of probabilities: 5.8978876e-05 - temperature 3.0748744
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1828 - val_loss: 0.1576
# Epoch 199/1000
# mean max of probabilities: 5.9076847e-05 - temperature 3.056522
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1772 - val_loss: 0.1550
# Epoch 200/1000
# mean max of probabilities: 5.917093e-05 - temperature 3.038279
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1753 - val_loss: 0.1520
# Epoch 201/1000
# mean max of probabilities: 5.9267106e-05 - temperature 3.020145
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1750 - val_loss: 0.1542
# Epoch 202/1000
# mean max of probabilities: 5.935105e-05 - temperature 3.0021193
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1749 - val_loss: 0.1540
# Epoch 203/1000
# mean max of probabilities: 5.9443963e-05 - temperature 2.9842014
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1789 - val_loss: 0.1562
# Epoch 204/1000
# mean max of probabilities: 5.9539598e-05 - temperature 2.9663901
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1758 - val_loss: 0.1544
# Epoch 205/1000
# mean max of probabilities: 5.9631402e-05 - temperature 2.9486852
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1768 - val_loss: 0.1558
# Epoch 206/1000
# mean max of probabilities: 5.9727085e-05 - temperature 2.9310858
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1823 - val_loss: 0.1532
# Epoch 207/1000
# mean max of probabilities: 5.983988e-05 - temperature 2.9135914
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1739 - val_loss: 0.1536
# Epoch 208/1000
# mean max of probabilities: 5.994097e-05 - temperature 2.8962016
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1723 - val_loss: 0.1538
# Epoch 209/1000
# mean max of probabilities: 6.0053306e-05 - temperature 2.8789155
# 149/149 [==============================] - 0s 3ms/step - loss: 0.1737 - val_loss: 0.1511
# Epoch 210/1000
# mean max of probabilities: 6.0158065e-05 - temperature 2.8617325
# 149/149 [==============================] - 1s 3ms/step - loss: 0.1736 - val_loss: 0.1518
# Epoch 211/1000
# mean max of probabilities: 6.0251856e-05 - temperature 2.8446522
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1735 - val_loss: 0.1516
# Epoch 212/1000
# mean max of probabilities: 6.034459e-05 - temperature 2.8276742
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1726 - val_loss: 0.1517
# Epoch 213/1000
# mean max of probabilities: 6.0450133e-05 - temperature 2.810797
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1752 - val_loss: 0.1536
# Epoch 214/1000
# mean max of probabilities: 6.056408e-05 - temperature 2.7940204
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1743 - val_loss: 0.1531
# Epoch 215/1000
# mean max of probabilities: 6.067143e-05 - temperature 2.7773445
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1748 - val_loss: 0.1535
# Epoch 216/1000
# mean max of probabilities: 6.0777984e-05 - temperature 2.760768
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1783 - val_loss: 0.1574
# Epoch 217/1000
# mean max of probabilities: 6.0888062e-05 - temperature 2.74429
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1776 - val_loss: 0.1528
# Epoch 218/1000
# mean max of probabilities: 6.0996976e-05 - temperature 2.727911
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1775 - val_loss: 0.1531
# Epoch 219/1000
# mean max of probabilities: 6.110072e-05 - temperature 2.7116294
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1752 - val_loss: 0.1546
# Epoch 220/1000
# mean max of probabilities: 6.120834e-05 - temperature 2.6954448
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1743 - val_loss: 0.1574
# Epoch 221/1000
# mean max of probabilities: 6.131123e-05 - temperature 2.6793568
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1769 - val_loss: 0.1548
# Epoch 222/1000
# mean max of probabilities: 6.141538e-05 - temperature 2.6633651
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1743 - val_loss: 0.1609
# Epoch 223/1000
# mean max of probabilities: 6.151186e-05 - temperature 2.6474688
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1775 - val_loss: 0.1596
# Epoch 224/1000
# mean max of probabilities: 6.1619874e-05 - temperature 2.6316674
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1765 - val_loss: 0.1582
# Epoch 225/1000
# mean max of probabilities: 6.172778e-05 - temperature 2.6159604
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1739 - val_loss: 0.1566
# Epoch 226/1000
# mean max of probabilities: 6.18326e-05 - temperature 2.600347
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1744 - val_loss: 0.1544
# Epoch 227/1000
# mean max of probabilities: 6.194021e-05 - temperature 2.5848267
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1789 - val_loss: 0.1555
# Epoch 228/1000
# mean max of probabilities: 6.2067615e-05 - temperature 2.569399
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1744 - val_loss: 0.1529
# Epoch 229/1000
# mean max of probabilities: 6.219606e-05 - temperature 2.5540636
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1740 - val_loss: 0.1519
# Epoch 230/1000
# mean max of probabilities: 6.233254e-05 - temperature 2.5388196
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1734 - val_loss: 0.1509
# Epoch 231/1000
# mean max of probabilities: 6.24603e-05 - temperature 2.5236669
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1746 - val_loss: 0.1576
# Epoch 232/1000
# mean max of probabilities: 6.257003e-05 - temperature 2.5086043
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1782 - val_loss: 0.1549
# Epoch 233/1000
# mean max of probabilities: 6.268064e-05 - temperature 2.4936316
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1772 - val_loss: 0.1531
# Epoch 234/1000
# mean max of probabilities: 6.279857e-05 - temperature 2.4787483
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1765 - val_loss: 0.1532
# Epoch 235/1000
# mean max of probabilities: 6.2913896e-05 - temperature 2.4639542
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1714 - val_loss: 0.1539
# Epoch 236/1000
# mean max of probabilities: 6.302605e-05 - temperature 2.4492478
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1752 - val_loss: 0.1572
# Epoch 237/1000
# mean max of probabilities: 6.314098e-05 - temperature 2.4346297
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1794 - val_loss: 0.1589
# Epoch 238/1000
# mean max of probabilities: 6.3264786e-05 - temperature 2.4200985
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1779 - val_loss: 0.1535
# Epoch 239/1000
# mean max of probabilities: 6.3381216e-05 - temperature 2.4056542
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1770 - val_loss: 0.1563
# Epoch 240/1000
# mean max of probabilities: 6.35131e-05 - temperature 2.391296
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1812 - val_loss: 0.1591
# Epoch 241/1000
# mean max of probabilities: 6.3645326e-05 - temperature 2.3770237
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1773 - val_loss: 0.1547
# Epoch 242/1000
# mean max of probabilities: 6.3782194e-05 - temperature 2.3628364
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1764 - val_loss: 0.1541
# Epoch 243/1000
# mean max of probabilities: 6.390777e-05 - temperature 2.3487337
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1764 - val_loss: 0.1523
# Epoch 244/1000
# mean max of probabilities: 6.405001e-05 - temperature 2.3347154
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1731 - val_loss: 0.1513
# Epoch 245/1000
# mean max of probabilities: 6.41841e-05 - temperature 2.3207805
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1761 - val_loss: 0.1570
# Epoch 246/1000
# mean max of probabilities: 6.430868e-05 - temperature 2.306929
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1841 - val_loss: 0.1563
# Epoch 247/1000
# mean max of probabilities: 6.44234e-05 - temperature 2.2931604
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1789 - val_loss: 0.1570
# Epoch 248/1000
# mean max of probabilities: 6.454895e-05 - temperature 2.2794733
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1766 - val_loss: 0.1569
# Epoch 249/1000
# mean max of probabilities: 6.467315e-05 - temperature 2.2658682
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1761 - val_loss: 0.1546
# Epoch 250/1000
# mean max of probabilities: 6.48022e-05 - temperature 2.2523453
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1776 - val_loss: 0.1554
# Epoch 251/1000
# mean max of probabilities: 6.4943364e-05 - temperature 2.238903
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1769 - val_loss: 0.1582
# Epoch 252/1000
# mean max of probabilities: 6.507083e-05 - temperature 2.2255414
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1781 - val_loss: 0.1557
# Epoch 253/1000
# mean max of probabilities: 6.519969e-05 - temperature 2.2122571
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1777 - val_loss: 0.1521
# Epoch 254/1000
# mean max of probabilities: 6.533967e-05 - temperature 2.1990535
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1730 - val_loss: 0.1520
# Epoch 255/1000
# mean max of probabilities: 6.548719e-05 - temperature 2.185928
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1736 - val_loss: 0.1520
# Epoch 256/1000
# mean max of probabilities: 6.562708e-05 - temperature 2.1728814
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1730 - val_loss: 0.1522
# Epoch 257/1000
# mean max of probabilities: 6.575414e-05 - temperature 2.1599126
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1736 - val_loss: 0.1528
# Epoch 258/1000
# mean max of probabilities: 6.588207e-05 - temperature 2.147021
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1746 - val_loss: 0.1523
# Epoch 259/1000
# mean max of probabilities: 6.6006636e-05 - temperature 2.1342065
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1727 - val_loss: 0.1521
# Epoch 260/1000
# mean max of probabilities: 6.614668e-05 - temperature 2.1214688
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1765 - val_loss: 0.1523
# Epoch 261/1000
# mean max of probabilities: 6.6292254e-05 - temperature 2.1088066
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1726 - val_loss: 0.1519
# Epoch 262/1000
# mean max of probabilities: 6.643034e-05 - temperature 2.0962203
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1737 - val_loss: 0.1522
# Epoch 263/1000
# mean max of probabilities: 6.6581284e-05 - temperature 2.0837092
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1724 - val_loss: 0.1555
# Epoch 264/1000
# mean max of probabilities: 6.672742e-05 - temperature 2.0712726
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1747 - val_loss: 0.1519
# Epoch 265/1000
# mean max of probabilities: 6.687438e-05 - temperature 2.0589101
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1727 - val_loss: 0.1523
# Epoch 266/1000
# mean max of probabilities: 6.703154e-05 - temperature 2.0466216
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1742 - val_loss: 0.1528
# Epoch 267/1000
# mean max of probabilities: 6.717556e-05 - temperature 2.0344064
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1735 - val_loss: 0.1516
# Epoch 268/1000
# mean max of probabilities: 6.734162e-05 - temperature 2.022264
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1749 - val_loss: 0.1513
# Epoch 269/1000
# mean max of probabilities: 6.7499976e-05 - temperature 2.0101943
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1753 - val_loss: 0.1537
# Epoch 270/1000
# mean max of probabilities: 6.764653e-05 - temperature 1.9981962
# 149/149 [==============================] - 1s 7ms/step - loss: 0.1732 - val_loss: 0.1544
# Epoch 271/1000
# mean max of probabilities: 6.779251e-05 - temperature 1.98627
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1754 - val_loss: 0.1516
# Epoch 272/1000
# mean max of probabilities: 6.7945235e-05 - temperature 1.974415
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1731 - val_loss: 0.1527
# Epoch 273/1000
# mean max of probabilities: 6.812225e-05 - temperature 1.9626305
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1742 - val_loss: 0.1525
# Epoch 274/1000
# mean max of probabilities: 6.830708e-05 - temperature 1.9509165
# 149/149 [==============================] - 1s 4ms/step - loss: 0.1746 - val_loss: 0.1543
# Epoch 275/1000
# mean max of probabilities: 6.848875e-05 - temperature 1.9392724
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1761 - val_loss: 0.1553
# Epoch 276/1000
# mean max of probabilities: 6.865492e-05 - temperature 1.9276979
# ...
# Epoch 905/1000
# mean max of probabilities: 0.00011481834 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2182 - val_loss: 0.1675
# Epoch 906/1000
# mean max of probabilities: 0.00011481815 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2172 - val_loss: 0.1764
# Epoch 907/1000
# mean max of probabilities: 0.00011481796 - temperature 0.1
# 149/149 [==============================] - 1s 5ms/step - loss: 0.2494 - val_loss: 0.1774
# Epoch 908/1000
# mean max of probabilities: 0.000114817805 - temperature 0.1
# 149/149 [==============================] - 1s 5ms/step - loss: 0.2429 - val_loss: 0.2203
# Epoch 909/1000
# mean max of probabilities: 0.00011481767 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2176 - val_loss: 0.1846
# Epoch 910/1000
# mean max of probabilities: 0.000114795854 - temperature 0.1
# 149/149 [==============================] - 1s 5ms/step - loss: 0.2621 - val_loss: 0.2261
# Epoch 911/1000
# mean max of probabilities: 0.00011478251 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.1797 - val_loss: 0.2042
# Epoch 912/1000
# mean max of probabilities: 0.00011479671 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.1972 - val_loss: 0.1654
# Epoch 913/1000
# mean max of probabilities: 0.00011480631 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.2885 - val_loss: 0.3133
# Epoch 914/1000
# mean max of probabilities: 0.00011480957 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.3111 - val_loss: 0.2228
# Epoch 915/1000
# mean max of probabilities: 0.00011481058 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2064 - val_loss: 0.2261
# Epoch 916/1000
# mean max of probabilities: 0.00011481074 - temperature 0.1
# 149/149 [==============================] - 1s 10ms/step - loss: 0.2552 - val_loss: 0.2152
# Epoch 917/1000
# mean max of probabilities: 0.00011481068 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2329 - val_loss: 0.2505
# Epoch 918/1000
# mean max of probabilities: 0.00011482028 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2308 - val_loss: 0.1976
# Epoch 919/1000
# mean max of probabilities: 0.00011483731 - temperature 0.1
# 149/149 [==============================] - 46s 307ms/step - loss: 0.2401 - val_loss: 0.2062
# Epoch 920/1000
# mean max of probabilities: 0.00011484323 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2093 - val_loss: 0.1803
# Epoch 921/1000
# mean max of probabilities: 0.000114845185 - temperature 0.1
# 149/149 [==============================] - 2s 11ms/step - loss: 0.2019 - val_loss: 0.1674
# Epoch 922/1000
# mean max of probabilities: 0.000114845796 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.1871 - val_loss: 0.1711
# Epoch 923/1000
# mean max of probabilities: 0.00011484594 - temperature 0.1
# 149/149 [==============================] - 2s 11ms/step - loss: 0.2411 - val_loss: 0.1734
# Epoch 924/1000
# mean max of probabilities: 0.00011484592 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2767 - val_loss: 0.2182
# Epoch 925/1000
# mean max of probabilities: 0.00011484577 - temperature 0.1
# 149/149 [==============================] - 2s 11ms/step - loss: 0.2004 - val_loss: 0.1610
# Epoch 926/1000
# mean max of probabilities: 0.00011484555 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2342 - val_loss: 0.3772
# Epoch 927/1000
# mean max of probabilities: 0.0001148565 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.2264 - val_loss: 0.2877
# Epoch 928/1000
# mean max of probabilities: 0.00011488779 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2327 - val_loss: 0.2050
# Epoch 929/1000
# mean max of probabilities: 0.00011489874 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2022 - val_loss: 0.3582
# Epoch 930/1000
# mean max of probabilities: 0.00011490247 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.2052 - val_loss: 0.1858
# Epoch 931/1000
# mean max of probabilities: 0.000114903654 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2569 - val_loss: 0.2044
# Epoch 932/1000
# mean max of probabilities: 0.00011490399 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2048 - val_loss: 0.1744
# Epoch 933/1000
# mean max of probabilities: 0.00011490405 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.2904 - val_loss: 0.1579
# Epoch 934/1000
# mean max of probabilities: 0.00011490396 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.2708 - val_loss: 0.1821
# Epoch 935/1000
# mean max of probabilities: 0.00011490372 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.3318 - val_loss: 0.3533
# Epoch 936/1000
# mean max of probabilities: 0.00011490351 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.3420 - val_loss: 0.3533
# Epoch 937/1000
# mean max of probabilities: 0.00011490335 - temperature 0.1
# 149/149 [==============================] - 1s 5ms/step - loss: 0.2194 - val_loss: 0.2106
# Epoch 938/1000
# mean max of probabilities: 0.00011490328 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2586 - val_loss: 0.2844
# Epoch 939/1000
# mean max of probabilities: 0.00011492071 - temperature 0.1
# 149/149 [==============================] - 1s 10ms/step - loss: 0.2868 - val_loss: 0.2025
# Epoch 940/1000
# mean max of probabilities: 0.00011494577 - temperature 0.1
# 149/149 [==============================] - 1s 10ms/step - loss: 0.2608 - val_loss: 0.1776
# Epoch 941/1000
# mean max of probabilities: 0.00011495462 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2917 - val_loss: 0.3309
# Epoch 942/1000
# mean max of probabilities: 0.000114957664 - temperature 0.1
# 149/149 [==============================] - 1s 10ms/step - loss: 0.2901 - val_loss: 0.2884
# Epoch 943/1000
# mean max of probabilities: 0.000114958704 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2355 - val_loss: 0.1991
# Epoch 944/1000
# mean max of probabilities: 0.00011496474 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2344 - val_loss: 0.2606
# Epoch 945/1000
# mean max of probabilities: 0.00011499887 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.2302 - val_loss: 0.2169
# Epoch 946/1000
# mean max of probabilities: 0.00011501088 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2181 - val_loss: 0.1785
# Epoch 947/1000
# mean max of probabilities: 0.00011501502 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2108 - val_loss: 0.1530
# Epoch 948/1000
# mean max of probabilities: 0.00011501636 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.4111 - val_loss: 0.1510
# Epoch 949/1000
# mean max of probabilities: 0.00011501607 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.3419 - val_loss: 0.3148
# Epoch 950/1000
# mean max of probabilities: 0.00011501217 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2378 - val_loss: 0.2210
# Epoch 951/1000
# mean max of probabilities: 0.000115010655 - temperature 0.1
# 149/149 [==============================] - 2s 10ms/step - loss: 0.2124 - val_loss: 0.1669
# Epoch 952/1000
# mean max of probabilities: 0.00011501011 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2032 - val_loss: 0.3813
# Epoch 953/1000
# mean max of probabilities: 0.00011500697 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2292 - val_loss: 0.2397
# Epoch 954/1000
# mean max of probabilities: 0.000115006784 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2065 - val_loss: 0.1777
# Epoch 955/1000
# mean max of probabilities: 0.00011500656 - temperature 0.1
# 149/149 [==============================] - 1s 10ms/step - loss: 0.2102 - val_loss: 0.2364
# Epoch 956/1000
# mean max of probabilities: 0.00011500637 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.3421 - val_loss: 0.2356
# Epoch 957/1000
# mean max of probabilities: 0.000115006194 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.3257 - val_loss: 0.1984
# Epoch 958/1000
# mean max of probabilities: 0.00011500601 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2433 - val_loss: 0.1799
# Epoch 959/1000
# mean max of probabilities: 0.00011500589 - temperature 0.1
# 149/149 [==============================] - 1s 10ms/step - loss: 0.2115 - val_loss: 0.2181
# Epoch 960/1000
# mean max of probabilities: 0.00011500575 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2393 - val_loss: 0.2004
# Epoch 961/1000
# mean max of probabilities: 0.00011500572 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2358 - val_loss: 0.2473
# Epoch 962/1000
# mean max of probabilities: 0.000115005765 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.2897 - val_loss: 0.4272
# Epoch 963/1000
# mean max of probabilities: 0.00011501612 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.3920 - val_loss: 0.1802
# Epoch 964/1000
# mean max of probabilities: 0.00011502387 - temperature 0.1
# 149/149 [==============================] - 2s 11ms/step - loss: 0.2883 - val_loss: 0.3229
# Epoch 965/1000
# mean max of probabilities: 0.00011502506 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2340 - val_loss: 0.1680
# Epoch 966/1000
# mean max of probabilities: 0.000115094204 - temperature 0.1
# 149/149 [==============================] - 2s 10ms/step - loss: 0.3108 - val_loss: 0.1707
# Epoch 967/1000
# mean max of probabilities: 0.000115136274 - temperature 0.1
# 149/149 [==============================] - 2s 11ms/step - loss: 0.2137 - val_loss: 0.2722
# Epoch 968/1000
# mean max of probabilities: 0.000115152136 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2233 - val_loss: 0.1685
# Epoch 969/1000
# mean max of probabilities: 0.00011515805 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2054 - val_loss: 0.1604
# Epoch 970/1000
# mean max of probabilities: 0.00011516006 - temperature 0.1
# 149/149 [==============================] - 2s 13ms/step - loss: 0.2043 - val_loss: 0.1682
# Epoch 971/1000
# mean max of probabilities: 0.000115160685 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2533 - val_loss: 0.1756
# Epoch 972/1000
# mean max of probabilities: 0.000115160816 - temperature 0.1
# 149/149 [==============================] - 2s 12ms/step - loss: 0.2352 - val_loss: 0.1683
# Epoch 973/1000
# mean max of probabilities: 0.00011516115 - temperature 0.1
# 149/149 [==============================] - 2s 12ms/step - loss: 0.2607 - val_loss: 0.2237
# Epoch 974/1000
# mean max of probabilities: 0.0001151614 - temperature 0.1
# 149/149 [==============================] - 2s 11ms/step - loss: 0.3109 - val_loss: 0.1971
# Epoch 975/1000
# mean max of probabilities: 0.0001151614 - temperature 0.1
# 149/149 [==============================] - 2s 11ms/step - loss: 0.2442 - val_loss: 0.1733
# Epoch 976/1000
# mean max of probabilities: 0.00011516122 - temperature 0.1
# 149/149 [==============================] - 1s 10ms/step - loss: 0.2494 - val_loss: 0.2115
# Epoch 977/1000
# mean max of probabilities: 0.000115161114 - temperature 0.1
# 149/149 [==============================] - 2s 10ms/step - loss: 0.2447 - val_loss: 0.1974
# Epoch 978/1000
# mean max of probabilities: 0.00011516096 - temperature 0.1
# 149/149 [==============================] - 2s 13ms/step - loss: 0.2432 - val_loss: 0.2944
# Epoch 979/1000
# mean max of probabilities: 0.00011516079 - temperature 0.1
# 149/149 [==============================] - 2s 10ms/step - loss: 0.2224 - val_loss: 0.1706
# Epoch 980/1000
# mean max of probabilities: 0.000115160576 - temperature 0.1
# 149/149 [==============================] - 1s 9ms/step - loss: 0.2028 - val_loss: 0.2194
# Epoch 981/1000
# mean max of probabilities: 0.000115160394 - temperature 0.1
# 149/149 [==============================] - 1s 10ms/step - loss: 0.2337 - val_loss: 0.1970
# Epoch 982/1000
# mean max of probabilities: 0.00011517496 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.2439 - val_loss: 0.1846
# Epoch 983/1000
# mean max of probabilities: 0.00011518053 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2230 - val_loss: 0.1485
# Epoch 984/1000
# mean max of probabilities: 0.0001151894 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.1807 - val_loss: 0.1819
# Epoch 985/1000
# mean max of probabilities: 0.000115203446 - temperature 0.1
# 149/149 [==============================] - 7s 48ms/step - loss: 0.2177 - val_loss: 0.2234
# Epoch 986/1000
# mean max of probabilities: 0.00011520837 - temperature 0.1
# 149/149 [==============================] - 1s 8ms/step - loss: 0.3040 - val_loss: 0.3532
# Epoch 987/1000
# mean max of probabilities: 0.000115209914 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.3088 - val_loss: 0.1983
# Epoch 988/1000
# mean max of probabilities: 0.00011521031 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.3386 - val_loss: 0.1930
# Epoch 989/1000
# mean max of probabilities: 0.00011521038 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.2154 - val_loss: 0.1705
# Epoch 990/1000
# mean max of probabilities: 0.00011521034 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.1937 - val_loss: 0.1785
# Epoch 991/1000
# mean max of probabilities: 0.0001152103 - temperature 0.1
# 149/149 [==============================] - 1s 7ms/step - loss: 0.2502 - val_loss: 0.1961
# Epoch 992/1000
# mean max of probabilities: 0.000115210176 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2380 - val_loss: 0.1807
# Epoch 993/1000
# mean max of probabilities: 0.000115210016 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2651 - val_loss: 0.1626
# Epoch 994/1000
# mean max of probabilities: 0.000115209885 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2349 - val_loss: 0.3450
# Epoch 995/1000
# mean max of probabilities: 0.00011522516 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2268 - val_loss: 0.1567
# Epoch 996/1000
# mean max of probabilities: 0.00011526042 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2474 - val_loss: 0.2022
# Epoch 997/1000
# mean max of probabilities: 0.00011527282 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2373 - val_loss: 0.2039
# Epoch 998/1000
# mean max of probabilities: 0.000115277406 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2048 - val_loss: 0.2385
# Epoch 999/1000
# mean max of probabilities: 0.00011527899 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2117 - val_loss: 0.2043
# Epoch 1000/1000
# mean max of probabilities: 0.000115279436 - temperature 0.1
# 149/149 [==============================] - 1s 6ms/step - loss: 0.2371 - val_loss: 0.1654
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
train_compressed_Data.shape
# Out:
# (187, 64)

# %% [markdown]
# # 4. Classifying

# %% [markdown]
# ### Extra Trees

# %%
train_feature=C_train_x
train_label=C_train_y
test_feature=C_test_x
test_label=C_test_y

print('Shape of train_feature: ' + str(train_feature.shape)) 
print('Shape of train_label: ' + str(train_label.shape)) 
print('Shape of test_feature: ' + str(test_feature.shape)) 
print('Shape of test_label: ' + str(test_label.shape)) 

p_seed=seed
ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Shape of train_feature: (149, 19993)
# Shape of train_label: (149,)
# Shape of test_feature: (38, 19993)
# Shape of test_label: (38,)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.7368421052631579
# Testing accuracy： 0.7368421052631579

# %%
C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,label_arr,test_size=0.2,random_state=seed)

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape))
# Out:
# Shape of C_train_x: (149, 19993)
# Shape of C_train_y: (149,)
# Shape of C_test_x: (38, 19993)
# Shape of C_test_y: (38,)

# %%
train_feature=C_train_selected_x
train_label=C_train_y

test_feature=C_test_selected_x
test_label=C_test_y

print('Shape of train_feature: ' + str(train_feature.shape)) 
print('Shape of train_label: ' + str(train_label.shape)) 
print('Shape of test_feature: ' + str(test_feature.shape)) 
print('Shape of test_label: ' + str(test_label.shape)) 

p_seed=seed
ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Shape of train_feature: (149, 64)
# Shape of train_label: (149,)
# Shape of test_feature: (38, 64)
# Shape of test_label: (38,)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.7368421052631579
# Testing accuracy： 0.7368421052631579

# %% [markdown]
# # 5. Classifying 2

# %% [markdown]
# ## Extra Trees

# %%
train_feature=C_train_selected_x
train_label=C_train_y

test_feature=C_test_selected_x
test_label=C_test_y

print('Shape of train_feature: ' + str(train_feature.shape)) 
print('Shape of train_label: ' + str(train_label.shape)) 
print('Shape of test_feature: ' + str(test_feature.shape)) 
print('Shape of test_label: ' + str(test_label.shape)) 

p_seed=seed
ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Shape of train_feature: (149, 64)
# Shape of train_label: (149,)
# Shape of test_feature: (38, 64)
# Shape of test_label: (38,)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.7368421052631579
# Testing accuracy： 0.7368421052631579

# %% [markdown]
# # 6. Reconstruction loss

# %%
from sklearn.linear_model import LinearRegression

def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR

# %%
train_feature_tuple=(C_train_selected_x,C_train_x)
test_feature_tuple=(C_test_selected_x,C_test_x)

reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
print(reconstruction_loss)
# Out:
# 0.07727934996354033
