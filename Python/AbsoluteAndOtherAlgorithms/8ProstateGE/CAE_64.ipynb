# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io

from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.function.similarity_based import lap_score
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.function.sparse_learning_based.UDFS import udfs
from skfeature.utility.sparse_learning import feature_ranking
import time

from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def ETree(p_train_feature,p_train_label,p_test_feature,p_test_label,p_seed):
    clf = ExtraTreesClassifier(n_estimators=50, random_state=p_seed)
    
    # Training
    clf.fit(p_train_feature, p_train_label)
    
    # Training accuracy
    print('Training accuracy：',clf.score(p_train_feature, np.array(p_train_label)))
    print('Training accuracy：',accuracy_score(np.array(p_train_label),clf.predict(p_train_feature)))
    #print('Training accuracy：',np.sum(clf.predict(p_train_feature)==np.array(p_train_label))/p_train_label.shape[0])

    # Testing accuracy
    print('Testing accuracy：',clf.score(p_test_feature, np.array(p_test_label)))
    print('Testing accuracy：',accuracy_score(np.array(p_test_label),clf.predict(p_test_feature)))
    #print('Testing accuracy：',np.sum(clf.predict(p_test_feature)==np.array(p_test_label))/p_test_label.shape[0])

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')

# %% [markdown]
# # 2. Loading data

# %%
data_path="./Dataset/Prostate_GE.mat"
Data = scipy.io.loadmat(data_path)

data_arr=Data['X']
label_arr=Data['Y'][:, 0]-1

Data=MinMaxScaler(feature_range=(0,1)).fit_transform(data_arr)

C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(Data,label_arr,test_size=0.2,random_state=seed)

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape))
# Out:
# Shape of C_train_x: (81, 5966)
# Shape of C_train_y: (81,)
# Shape of C_test_x: (21, 5966)
# Shape of C_test_y: (21,)

# %%
key_feture_number=64

# %% [markdown]
# # 3. Model

# %%
def decoder(x):
    x = Dense(key_feture_number)(x)
    x = Dense(Data.shape[1])(x)
    return x

# %%
start = time.clock()

selector = ConcreteAutoencoderFeatureSelector(K = key_feture_number, output_function = decoder, num_epochs = 1000)
selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)

train_compressed_Data=Data[:, selector.get_support(indices=True)]

time_cost=time.clock() - start
write_to_csv(np.array([time_cost]),"./log/CAS_time"+str(key_feture_number)+".csv")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 5966)              0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                381825
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 5966)              387790
# =================================================================
# Total params: 773,775
# Trainable params: 773,774
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 81 samples, validate on 21 samples
# Epoch 1/1000
# mean max of probabilities: 0.000174671 - temperature 10.0
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1801 - val_loss: 0.1465
# Epoch 2/1000
# mean max of probabilities: 0.00017467109 - temperature 9.9387865
# 81/81 [==============================] - 0s 5ms/step - loss: 0.1117 - val_loss: 0.0798
# Epoch 3/1000
# mean max of probabilities: 0.00017467361 - temperature 9.877948
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0677 - val_loss: 0.0721
# Epoch 4/1000
# mean max of probabilities: 0.00017467848 - temperature 9.817481
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0650 - val_loss: 0.0742
# Epoch 5/1000
# mean max of probabilities: 0.00017467717 - temperature 9.757384
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0598 - val_loss: 0.0723
# Epoch 6/1000
# mean max of probabilities: 0.00017467313 - temperature 9.697654
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0576 - val_loss: 0.0706
# Epoch 7/1000
# mean max of probabilities: 0.00017467322 - temperature 9.638289
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0572 - val_loss: 0.0660
# Epoch 8/1000
# mean max of probabilities: 0.00017467728 - temperature 9.579291
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0559 - val_loss: 0.0653
# Epoch 9/1000
# mean max of probabilities: 0.00017468471 - temperature 9.520652
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0557 - val_loss: 0.0668
# Epoch 10/1000
# mean max of probabilities: 0.00017469295 - temperature 9.462373
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0552 - val_loss: 0.0682
# Epoch 11/1000
# mean max of probabilities: 0.00017470247 - temperature 9.404449
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0553 - val_loss: 0.0678
# Epoch 12/1000
# mean max of probabilities: 0.00017471456 - temperature 9.346882
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0551 - val_loss: 0.0653
# Epoch 13/1000
# mean max of probabilities: 0.00017472851 - temperature 9.289665
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0550 - val_loss: 0.0655
# Epoch 14/1000
# mean max of probabilities: 0.00017474344 - temperature 9.2328
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0547 - val_loss: 0.0659
# Epoch 15/1000
# mean max of probabilities: 0.00017475955 - temperature 9.176282
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0547 - val_loss: 0.0667
# Epoch 16/1000
# mean max of probabilities: 0.00017477534 - temperature 9.1201105
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0545 - val_loss: 0.0643
# Epoch 17/1000
# mean max of probabilities: 0.00017479225 - temperature 9.064283
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0544 - val_loss: 0.0636
# Epoch 18/1000
# mean max of probabilities: 0.00017480974 - temperature 9.008798
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0546 - val_loss: 0.0621
# Epoch 19/1000
# mean max of probabilities: 0.00017482619 - temperature 8.953651
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0551 - val_loss: 0.0622
# Epoch 20/1000
# mean max of probabilities: 0.00017484001 - temperature 8.898842
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0547 - val_loss: 0.0624
# Epoch 21/1000
# mean max of probabilities: 0.0001748509 - temperature 8.844368
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0543 - val_loss: 0.0646
# Epoch 22/1000
# mean max of probabilities: 0.00017486139 - temperature 8.790229
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0540 - val_loss: 0.0673
# Epoch 23/1000
# mean max of probabilities: 0.00017487565 - temperature 8.736421
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0546 - val_loss: 0.0692
# Epoch 24/1000
# mean max of probabilities: 0.00017489365 - temperature 8.682941
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0550 - val_loss: 0.0685
# Epoch 25/1000
# mean max of probabilities: 0.00017491508 - temperature 8.62979
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0543 - val_loss: 0.0638
# Epoch 26/1000
# mean max of probabilities: 0.00017493684 - temperature 8.576964
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0537 - val_loss: 0.0627
# Epoch 27/1000
# mean max of probabilities: 0.00017495772 - temperature 8.524462
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0533 - val_loss: 0.0636
# Epoch 28/1000
# mean max of probabilities: 0.00017497511 - temperature 8.4722805
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0533 - val_loss: 0.0653
# Epoch 29/1000
# mean max of probabilities: 0.00017499062 - temperature 8.420419
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0535 - val_loss: 0.0657
# Epoch 30/1000
# mean max of probabilities: 0.00017500829 - temperature 8.368875
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0534 - val_loss: 0.0653
# Epoch 31/1000
# mean max of probabilities: 0.00017502898 - temperature 8.317645
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0532 - val_loss: 0.0635
# Epoch 32/1000
# mean max of probabilities: 0.00017505043 - temperature 8.266729
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0527 - val_loss: 0.0613
# Epoch 33/1000
# mean max of probabilities: 0.00017506945 - temperature 8.216126
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0531 - val_loss: 0.0602
# Epoch 34/1000
# mean max of probabilities: 0.0001750839 - temperature 8.165831
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0533 - val_loss: 0.0612
# Epoch 35/1000
# mean max of probabilities: 0.0001750953 - temperature 8.115847
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0522 - val_loss: 0.0627
# Epoch 36/1000
# mean max of probabilities: 0.00017510721 - temperature 8.066168
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0526 - val_loss: 0.0653
# Epoch 37/1000
# mean max of probabilities: 0.00017512054 - temperature 8.016794
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0527 - val_loss: 0.0638
# Epoch 38/1000
# mean max of probabilities: 0.0001751378 - temperature 7.9677196
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0522 - val_loss: 0.0630
# Epoch 39/1000
# mean max of probabilities: 0.00017515844 - temperature 7.9189463
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0522 - val_loss: 0.0624
# Epoch 40/1000
# mean max of probabilities: 0.00017517872 - temperature 7.870471
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0519 - val_loss: 0.0614
# Epoch 41/1000
# mean max of probabilities: 0.00017519853 - temperature 7.822293
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0518 - val_loss: 0.0617
# Epoch 42/1000
# mean max of probabilities: 0.00017521826 - temperature 7.77441
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0514 - val_loss: 0.0602
# Epoch 43/1000
# mean max of probabilities: 0.00017523835 - temperature 7.7268195
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0513 - val_loss: 0.0605
# Epoch 44/1000
# mean max of probabilities: 0.00017525951 - temperature 7.679521
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0511 - val_loss: 0.0616
# Epoch 45/1000
# mean max of probabilities: 0.00017528087 - temperature 7.632512
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0510 - val_loss: 0.0604
# Epoch 46/1000
# mean max of probabilities: 0.00017530442 - temperature 7.5857906
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0508 - val_loss: 0.0583
# Epoch 47/1000
# mean max of probabilities: 0.00017532991 - temperature 7.5393553
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0511 - val_loss: 0.0587
# Epoch 48/1000
# mean max of probabilities: 0.0001753534 - temperature 7.4932036
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0502 - val_loss: 0.0608
# Epoch 49/1000
# mean max of probabilities: 0.00017537983 - temperature 7.447335
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0517 - val_loss: 0.0627
# Epoch 50/1000
# mean max of probabilities: 0.0001754137 - temperature 7.4017463
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0507 - val_loss: 0.0569
# Epoch 51/1000
# mean max of probabilities: 0.0001754532 - temperature 7.356437
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0500 - val_loss: 0.0565
# Epoch 52/1000
# mean max of probabilities: 0.00017549074 - temperature 7.311406
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0499 - val_loss: 0.0566
# Epoch 53/1000
# mean max of probabilities: 0.00017553044 - temperature 7.26665
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0495 - val_loss: 0.0589
# Epoch 54/1000
# mean max of probabilities: 0.00017557826 - temperature 7.222169
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0490 - val_loss: 0.0567
# Epoch 55/1000
# mean max of probabilities: 0.0001756355 - temperature 7.177959
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0485 - val_loss: 0.0571
# Epoch 56/1000
# mean max of probabilities: 0.00017569921 - temperature 7.1340203
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0483 - val_loss: 0.0570
# Epoch 57/1000
# mean max of probabilities: 0.00017576519 - temperature 7.09035
# 81/81 [==============================] - 1s 6ms/step - loss: 0.0480 - val_loss: 0.0579
# Epoch 58/1000
# mean max of probabilities: 0.00017583658 - temperature 7.0469475
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0476 - val_loss: 0.0558
# Epoch 59/1000
# mean max of probabilities: 0.00017591103 - temperature 7.0038104
# 81/81 [==============================] - 1s 6ms/step - loss: 0.0473 - val_loss: 0.0553
# Epoch 60/1000
# mean max of probabilities: 0.00017599345 - temperature 6.9609375
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0467 - val_loss: 0.0554
# Epoch 61/1000
# mean max of probabilities: 0.00017607847 - temperature 6.918327
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0465 - val_loss: 0.0552
# Epoch 62/1000
# mean max of probabilities: 0.00017617326 - temperature 6.875977
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0457 - val_loss: 0.0515
# Epoch 63/1000
# mean max of probabilities: 0.00017627602 - temperature 6.8338866
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0475 - val_loss: 0.0509
# Epoch 64/1000
# mean max of probabilities: 0.00017638502 - temperature 6.7920537
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0458 - val_loss: 0.0538
# Epoch 65/1000
# mean max of probabilities: 0.00017649763 - temperature 6.750477
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0460 - val_loss: 0.0589
# Epoch 66/1000
# mean max of probabilities: 0.00017661689 - temperature 6.709154
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0465 - val_loss: 0.0534
# Epoch 67/1000
# mean max of probabilities: 0.00017674654 - temperature 6.668085
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0440 - val_loss: 0.0503
# Epoch 68/1000
# mean max of probabilities: 0.00017687675 - temperature 6.6272674
# 81/81 [==============================] - 1s 6ms/step - loss: 0.0433 - val_loss: 0.0477
# Epoch 69/1000
# mean max of probabilities: 0.00017701456 - temperature 6.5866995
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0452 - val_loss: 0.0477
# Epoch 70/1000
# mean max of probabilities: 0.00017715956 - temperature 6.5463796
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0425 - val_loss: 0.0520
# Epoch 71/1000
# mean max of probabilities: 0.00017731235 - temperature 6.506306
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0429 - val_loss: 0.0508
# Epoch 72/1000
# mean max of probabilities: 0.00017745729 - temperature 6.466477
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0417 - val_loss: 0.0483
# Epoch 73/1000
# mean max of probabilities: 0.00017760733 - temperature 6.426892
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0410 - val_loss: 0.0471
# Epoch 74/1000
# mean max of probabilities: 0.0001777733 - temperature 6.387551
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0407 - val_loss: 0.0449
# Epoch 75/1000
# mean max of probabilities: 0.0001779426 - temperature 6.34845
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0453 - val_loss: 0.0484
# Epoch 76/1000
# mean max of probabilities: 0.00017814046 - temperature 6.3095884
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0431 - val_loss: 0.0513
# Epoch 77/1000
# mean max of probabilities: 0.00017835779 - temperature 6.270965
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0401 - val_loss: 0.0444
# Epoch 78/1000
# mean max of probabilities: 0.00017857514 - temperature 6.232578
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0390 - val_loss: 0.0428
# Epoch 79/1000
# mean max of probabilities: 0.0001787756 - temperature 6.194426
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0382 - val_loss: 0.0426
# Epoch 80/1000
# mean max of probabilities: 0.000178975 - temperature 6.1565075
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0377 - val_loss: 0.0422
# Epoch 81/1000
# mean max of probabilities: 0.00017916143 - temperature 6.118821
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0378 - val_loss: 0.0414
# Epoch 82/1000
# mean max of probabilities: 0.00017935576 - temperature 6.0813656
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0366 - val_loss: 0.0437
# Epoch 83/1000
# mean max of probabilities: 0.00017954971 - temperature 6.04414
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0368 - val_loss: 0.0426
# Epoch 84/1000
# mean max of probabilities: 0.00017974654 - temperature 6.007141
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0356 - val_loss: 0.0396
# Epoch 85/1000
# mean max of probabilities: 0.00017994753 - temperature 5.9703693
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0396 - val_loss: 0.0402
# Epoch 86/1000
# mean max of probabilities: 0.00018019439 - temperature 5.933822
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0371 - val_loss: 0.0444
# Epoch 87/1000
# mean max of probabilities: 0.00018044867 - temperature 5.8974986
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0365 - val_loss: 0.0383
# Epoch 88/1000
# mean max of probabilities: 0.00018068886 - temperature 5.8613977
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0341 - val_loss: 0.0393
# Epoch 89/1000
# mean max of probabilities: 0.00018092118 - temperature 5.8255177
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0340 - val_loss: 0.0382
# Epoch 90/1000
# mean max of probabilities: 0.00018114931 - temperature 5.7898574
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0337 - val_loss: 0.0372
# Epoch 91/1000
# mean max of probabilities: 0.00018136809 - temperature 5.7544155
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0332 - val_loss: 0.0379
# Epoch 92/1000
# mean max of probabilities: 0.00018157593 - temperature 5.7191906
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0327 - val_loss: 0.0373
# Epoch 93/1000
# mean max of probabilities: 0.00018178922 - temperature 5.684181
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0324 - val_loss: 0.0360
# Epoch 94/1000
# mean max of probabilities: 0.00018199967 - temperature 5.6493855
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0341 - val_loss: 0.0359
# Epoch 95/1000
# mean max of probabilities: 0.00018225062 - temperature 5.6148033
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0319 - val_loss: 0.0403
# Epoch 96/1000
# mean max of probabilities: 0.00018249193 - temperature 5.580433
# 81/81 [==============================] - 1s 6ms/step - loss: 0.0341 - val_loss: 0.0351
# Epoch 97/1000
# mean max of probabilities: 0.00018269813 - temperature 5.5462728
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0337 - val_loss: 0.0360
# Epoch 98/1000
# mean max of probabilities: 0.000182911 - temperature 5.512322
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0320 - val_loss: 0.0389
# Epoch 99/1000
# mean max of probabilities: 0.00018310409 - temperature 5.4785786
# 81/81 [==============================] - 1s 6ms/step - loss: 0.0334 - val_loss: 0.0367
# Epoch 100/1000
# mean max of probabilities: 0.00018329712 - temperature 5.4450417
# 81/81 [==============================] - 1s 6ms/step - loss: 0.0308 - val_loss: 0.0344
# Epoch 101/1000
# mean max of probabilities: 0.0001835018 - temperature 5.4117103
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0305 - val_loss: 0.0346
# Epoch 102/1000
# mean max of probabilities: 0.0001837354 - temperature 5.3785834
# 81/81 [==============================] - 1s 6ms/step - loss: 0.0303 - val_loss: 0.0339
# Epoch 103/1000
# mean max of probabilities: 0.00018395548 - temperature 5.345659
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0301 - val_loss: 0.0348
# Epoch 104/1000
# mean max of probabilities: 0.00018415542 - temperature 5.312936
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0302 - val_loss: 0.0344
# Epoch 105/1000
# mean max of probabilities: 0.00018434928 - temperature 5.280413
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0299 - val_loss: 0.0337
# Epoch 106/1000
# mean max of probabilities: 0.00018454049 - temperature 5.2480893
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0296 - val_loss: 0.0332
# Epoch 107/1000
# mean max of probabilities: 0.00018473048 - temperature 5.215964
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0296 - val_loss: 0.0333
# Epoch 108/1000
# mean max of probabilities: 0.00018492411 - temperature 5.184035
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0294 - val_loss: 0.0342
# Epoch 109/1000
# mean max of probabilities: 0.00018510298 - temperature 5.1523013
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0294 - val_loss: 0.0335
# Epoch 110/1000
# mean max of probabilities: 0.00018526474 - temperature 5.120762
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0293 - val_loss: 0.0333
# Epoch 111/1000
# mean max of probabilities: 0.00018543535 - temperature 5.089416
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0290 - val_loss: 0.0334
# Epoch 112/1000
# mean max of probabilities: 0.00018562625 - temperature 5.0582614
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0296 - val_loss: 0.0328
# Epoch 113/1000
# mean max of probabilities: 0.00018582802 - temperature 5.027298
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0294 - val_loss: 0.0327
# Epoch 114/1000
# mean max of probabilities: 0.00018602495 - temperature 4.9965234
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0290 - val_loss: 0.0340
# Epoch 115/1000
# mean max of probabilities: 0.00018620881 - temperature 4.965938
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0291 - val_loss: 0.0324
# Epoch 116/1000
# mean max of probabilities: 0.00018637342 - temperature 4.9355397
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0288 - val_loss: 0.0328
# Epoch 117/1000
# mean max of probabilities: 0.00018655992 - temperature 4.9053273
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0286 - val_loss: 0.0323
# Epoch 118/1000
# mean max of probabilities: 0.00018672794 - temperature 4.8753
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0285 - val_loss: 0.0320
# Epoch 119/1000
# mean max of probabilities: 0.00018689081 - temperature 4.8454576
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0290 - val_loss: 0.0318
# Epoch 120/1000
# mean max of probabilities: 0.00018707699 - temperature 4.8157973
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0289 - val_loss: 0.0327
# Epoch 121/1000
# mean max of probabilities: 0.00018724683 - temperature 4.7863173
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0290 - val_loss: 0.0322
# Epoch 122/1000
# mean max of probabilities: 0.00018740569 - temperature 4.7570186
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0289 - val_loss: 0.0324
# Epoch 123/1000
# mean max of probabilities: 0.00018758822 - temperature 4.727899
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0286 - val_loss: 0.0320
# Epoch 124/1000
# mean max of probabilities: 0.00018774597 - temperature 4.698958
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0285 - val_loss: 0.0322
# Epoch 125/1000
# mean max of probabilities: 0.00018789517 - temperature 4.6701937
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0284 - val_loss: 0.0323
# Epoch 126/1000
# mean max of probabilities: 0.00018804 - temperature 4.6416054
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0285 - val_loss: 0.0323
# Epoch 127/1000
# mean max of probabilities: 0.00018818471 - temperature 4.6131926
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0284 - val_loss: 0.0320
# Epoch 128/1000
# mean max of probabilities: 0.00018833297 - temperature 4.584953
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0282 - val_loss: 0.0318
# Epoch 129/1000
# mean max of probabilities: 0.00018846874 - temperature 4.556886
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0283 - val_loss: 0.0319
# Epoch 130/1000
# mean max of probabilities: 0.00018860977 - temperature 4.5289917
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0285 - val_loss: 0.0323
# Epoch 131/1000
# mean max of probabilities: 0.00018875573 - temperature 4.501268
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0284 - val_loss: 0.0319
# Epoch 132/1000
# mean max of probabilities: 0.00018889002 - temperature 4.473714
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0282 - val_loss: 0.0317
# Epoch 133/1000
# mean max of probabilities: 0.00018902234 - temperature 4.446328
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0285 - val_loss: 0.0316
# Epoch 134/1000
# mean max of probabilities: 0.00018918174 - temperature 4.4191103
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0286 - val_loss: 0.0326
# Epoch 135/1000
# mean max of probabilities: 0.00018932583 - temperature 4.3920593
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0288 - val_loss: 0.0318
# Epoch 136/1000
# mean max of probabilities: 0.00018949396 - temperature 4.365174
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0294 - val_loss: 0.0323
# Epoch 137/1000
# mean max of probabilities: 0.00018965961 - temperature 4.338453
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0295 - val_loss: 0.0336
# Epoch 138/1000
# mean max of probabilities: 0.00018981377 - temperature 4.3118954
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0285 - val_loss: 0.0325
# Epoch 139/1000
# mean max of probabilities: 0.00018997691 - temperature 4.2855
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0287 - val_loss: 0.0323
# Epoch 140/1000
# mean max of probabilities: 0.00019013928 - temperature 4.259267
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0289 - val_loss: 0.0318
# Epoch 141/1000
# mean max of probabilities: 0.0001903205 - temperature 4.2331944
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0284 - val_loss: 0.0322
# Epoch 142/1000
# mean max of probabilities: 0.00019043071 - temperature 4.207281
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0285 - val_loss: 0.0321
# Epoch 143/1000
# mean max of probabilities: 0.0001905284 - temperature 4.1815267
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0281 - val_loss: 0.0316
# Epoch 144/1000
# mean max of probabilities: 0.00019063482 - temperature 4.15593
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0282 - val_loss: 0.0319
# Epoch 145/1000
# mean max of probabilities: 0.00019075518 - temperature 4.13049
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0285 - val_loss: 0.0322
# Epoch 146/1000
# mean max of probabilities: 0.00019089077 - temperature 4.105205
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0289 - val_loss: 0.0322
# Epoch 147/1000
# mean max of probabilities: 0.00019105751 - temperature 4.0800757
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0286 - val_loss: 0.0328
# Epoch 148/1000
# mean max of probabilities: 0.00019121656 - temperature 4.055099
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0282 - val_loss: 0.0318
# Epoch 149/1000
# mean max of probabilities: 0.00019135707 - temperature 4.030275
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0281 - val_loss: 0.0319
# Epoch 150/1000
# mean max of probabilities: 0.00019151288 - temperature 4.0056033
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0280 - val_loss: 0.0318
# Epoch 151/1000
# mean max of probabilities: 0.00019166002 - temperature 3.9810834
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0281 - val_loss: 0.0316
# Epoch 152/1000
# mean max of probabilities: 0.00019180478 - temperature 3.956714
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0282 - val_loss: 0.0316
# Epoch 153/1000
# mean max of probabilities: 0.00019194579 - temperature 3.9324934
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0281 - val_loss: 0.0319
# Epoch 154/1000
# mean max of probabilities: 0.00019209011 - temperature 3.908421
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0283 - val_loss: 0.0320
# Epoch 155/1000
# mean max of probabilities: 0.00019223196 - temperature 3.884496
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0282 - val_loss: 0.0318
# Epoch 156/1000
# mean max of probabilities: 0.00019240603 - temperature 3.8607175
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0280 - val_loss: 0.0318
# Epoch 157/1000
# mean max of probabilities: 0.0001925813 - temperature 3.8370845
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0281 - val_loss: 0.0320
# Epoch 158/1000
# mean max of probabilities: 0.00019274921 - temperature 3.8135962
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0284 - val_loss: 0.0319
# Epoch 159/1000
# mean max of probabilities: 0.00019293292 - temperature 3.7902517
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0285 - val_loss: 0.0320
# Epoch 160/1000
# mean max of probabilities: 0.00019311134 - temperature 3.76705
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0279 - val_loss: 0.0326
# Epoch 161/1000
# mean max of probabilities: 0.00019327259 - temperature 3.7439907
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0283 - val_loss: 0.0318
# Epoch 162/1000
# mean max of probabilities: 0.00019341693 - temperature 3.7210722
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0282 - val_loss: 0.0319
# Epoch 163/1000
# mean max of probabilities: 0.00019356245 - temperature 3.6982942
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0282 - val_loss: 0.0318
# Epoch 164/1000
# mean max of probabilities: 0.00019371581 - temperature 3.6756554
# 81/81 [==============================] - 1s 14ms/step - loss: 0.0281 - val_loss: 0.0317
# Epoch 165/1000
# mean max of probabilities: 0.00019386815 - temperature 3.6531553
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0284 - val_loss: 0.0320
# Epoch 166/1000
# mean max of probabilities: 0.00019403134 - temperature 3.6307926
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0286 - val_loss: 0.0320
# Epoch 167/1000
# mean max of probabilities: 0.0001941984 - temperature 3.6085672
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0286 - val_loss: 0.0317
# Epoch 168/1000
# mean max of probabilities: 0.00019435398 - temperature 3.5864778
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0280 - val_loss: 0.0325
# Epoch 169/1000
# mean max of probabilities: 0.0001945135 - temperature 3.5645237
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0286 - val_loss: 0.0318
# Epoch 170/1000
# mean max of probabilities: 0.00019471056 - temperature 3.5427039
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0279 - val_loss: 0.0318
# Epoch 171/1000
# mean max of probabilities: 0.00019489066 - temperature 3.5210178
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0280 - val_loss: 0.0321
# Epoch 172/1000
# mean max of probabilities: 0.0001950635 - temperature 3.499464
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0286 - val_loss: 0.0316
# Epoch 173/1000
# mean max of probabilities: 0.00019526214 - temperature 3.4780424
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0293 - val_loss: 0.0316
# Epoch 174/1000
# mean max of probabilities: 0.00019541176 - temperature 3.456752
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0288 - val_loss: 0.0324
# Epoch 175/1000
# mean max of probabilities: 0.00019553668 - temperature 3.435592
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0286 - val_loss: 0.0323
# Epoch 176/1000
# mean max of probabilities: 0.00019566511 - temperature 3.4145615
# 81/81 [==============================] - 0s 5ms/step - loss: 0.0288 - val_loss: 0.0329
# Epoch 177/1000
# mean max of probabilities: 0.00019580845 - temperature 3.3936596
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0284 - val_loss: 0.0324
# Epoch 178/1000
# mean max of probabilities: 0.00019601101 - temperature 3.3728857
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0285 - val_loss: 0.0324
# Epoch 179/1000
# mean max of probabilities: 0.0001962106 - temperature 3.352239
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0282 - val_loss: 0.0318
# Epoch 180/1000
# mean max of probabilities: 0.00019641046 - temperature 3.3317184
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0281 - val_loss: 0.0316
# Epoch 181/1000
# mean max of probabilities: 0.00019661119 - temperature 3.311324
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0284 - val_loss: 0.0316
# Epoch 182/1000
# mean max of probabilities: 0.00019687362 - temperature 3.291054
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0288 - val_loss: 0.0323
# Epoch 183/1000
# mean max of probabilities: 0.00019714847 - temperature 3.2709084
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0281 - val_loss: 0.0332
# Epoch 184/1000
# mean max of probabilities: 0.0001973835 - temperature 3.2508857
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0284 - val_loss: 0.0317
# Epoch 185/1000
# mean max of probabilities: 0.00019761929 - temperature 3.2309864
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0281 - val_loss: 0.0317
# Epoch 186/1000
# mean max of probabilities: 0.00019783451 - temperature 3.2112086
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0279 - val_loss: 0.0316
# Epoch 187/1000
# mean max of probabilities: 0.00019803812 - temperature 3.1915514
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0279 - val_loss: 0.0319
# Epoch 188/1000
# mean max of probabilities: 0.00019820631 - temperature 3.1720147
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0280 - val_loss: 0.0321
# Epoch 189/1000
# mean max of probabilities: 0.00019836798 - temperature 3.1525974
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0284 - val_loss: 0.0319
# Epoch 190/1000
# mean max of probabilities: 0.0001985887 - temperature 3.1332994
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0291 - val_loss: 0.0318
# Epoch 191/1000
# mean max of probabilities: 0.00019882798 - temperature 3.1141193
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0282 - val_loss: 0.0330
# Epoch 192/1000
# mean max of probabilities: 0.00019903595 - temperature 3.0950563
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0285 - val_loss: 0.0324
# Epoch 193/1000
# mean max of probabilities: 0.00019929226 - temperature 3.0761101
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0282 - val_loss: 0.0328
# Epoch 194/1000
# mean max of probabilities: 0.00019956364 - temperature 3.05728
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0284 - val_loss: 0.0322
# Epoch 195/1000
# mean max of probabilities: 0.00019984023 - temperature 3.0385652
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0283 - val_loss: 0.0321
# Epoch 196/1000
# mean max of probabilities: 0.0002001456 - temperature 3.0199647
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0281 - val_loss: 0.0319
# Epoch 197/1000
# mean max of probabilities: 0.000200392 - temperature 3.0014784
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0279 - val_loss: 0.0320
# Epoch 198/1000
# mean max of probabilities: 0.00020062044 - temperature 2.9831052
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0284 - val_loss: 0.0320
# Epoch 199/1000
# mean max of probabilities: 0.00020088573 - temperature 2.9648442
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0281 - val_loss: 0.0320
# Epoch 200/1000
# mean max of probabilities: 0.00020117064 - temperature 2.946695
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0292 - val_loss: 0.0322
# Epoch 201/1000
# mean max of probabilities: 0.00020149625 - temperature 2.9286573
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0289 - val_loss: 0.0323
# Epoch 202/1000
# mean max of probabilities: 0.00020175622 - temperature 2.91073
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0290 - val_loss: 0.0323
# Epoch 203/1000
# mean max of probabilities: 0.0002020694 - temperature 2.892912
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0283 - val_loss: 0.0329
# Epoch 204/1000
# mean max of probabilities: 0.00020236259 - temperature 2.8752031
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0280 - val_loss: 0.0317
# Epoch 205/1000
# mean max of probabilities: 0.00020260387 - temperature 2.857603
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0279 - val_loss: 0.0320
# Epoch 206/1000
# mean max of probabilities: 0.00020279197 - temperature 2.84011
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0282 - val_loss: 0.0320
# Epoch 207/1000
# mean max of probabilities: 0.00020301952 - temperature 2.8227253
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0282 - val_loss: 0.0323
# Epoch 208/1000
# mean max of probabilities: 0.00020329059 - temperature 2.8054457
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0280 - val_loss: 0.0318
# Epoch 209/1000
# mean max of probabilities: 0.00020352985 - temperature 2.7882726
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0281 - val_loss: 0.0320
# Epoch 210/1000
# mean max of probabilities: 0.00020382254 - temperature 2.7712045
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0280 - val_loss: 0.0318
# Epoch 211/1000
# mean max of probabilities: 0.00020410639 - temperature 2.7542408
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0277 - val_loss: 0.0318
# Epoch 212/1000
# mean max of probabilities: 0.00020436294 - temperature 2.737381
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0278 - val_loss: 0.0318
# Epoch 213/1000
# mean max of probabilities: 0.00020464178 - temperature 2.7206244
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0278 - val_loss: 0.0318
# Epoch 214/1000
# mean max of probabilities: 0.00020489663 - temperature 2.7039704
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0279 - val_loss: 0.0317
# Epoch 215/1000
# mean max of probabilities: 0.00020515567 - temperature 2.6874185
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0281 - val_loss: 0.0317
# Epoch 216/1000
# mean max of probabilities: 0.00020543401 - temperature 2.6709678
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0278 - val_loss: 0.0317
# Epoch 217/1000
# mean max of probabilities: 0.00020567911 - temperature 2.6546178
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0278 - val_loss: 0.0318
# Epoch 218/1000
# mean max of probabilities: 0.00020589291 - temperature 2.638368
# 81/81 [==============================] - 2s 24ms/step - loss: 0.0278 - val_loss: 0.0316
# Epoch 219/1000
# mean max of probabilities: 0.0002061183 - temperature 2.6222174
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0276 - val_loss: 0.0316
# Epoch 220/1000
# mean max of probabilities: 0.00020636278 - temperature 2.606166
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0277 - val_loss: 0.0318
# Epoch 221/1000
# mean max of probabilities: 0.00020658287 - temperature 2.5902123
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0279 - val_loss: 0.0321
# Epoch 222/1000
# mean max of probabilities: 0.00020682343 - temperature 2.5743566
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0283 - val_loss: 0.0322
# Epoch 223/1000
# mean max of probabilities: 0.00020711911 - temperature 2.5585978
# 81/81 [==============================] - 2s 20ms/step - loss: 0.0281 - val_loss: 0.0317
# Epoch 224/1000
# mean max of probabilities: 0.00020739494 - temperature 2.5429356
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0277 - val_loss: 0.0318
# Epoch 225/1000
# mean max of probabilities: 0.0002076563 - temperature 2.5273693
# 81/81 [==============================] - 2s 20ms/step - loss: 0.0277 - val_loss: 0.0318
# Epoch 226/1000
# mean max of probabilities: 0.00020791934 - temperature 2.5118983
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0280 - val_loss: 0.0322
# Epoch 227/1000
# mean max of probabilities: 0.0002082289 - temperature 2.496522
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0279 - val_loss: 0.0322
# Epoch 228/1000
# mean max of probabilities: 0.0002085191 - temperature 2.4812398
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0279 - val_loss: 0.0320
# Epoch 229/1000
# mean max of probabilities: 0.00020881588 - temperature 2.466051
# 81/81 [==============================] - 2s 19ms/step - loss: 0.0278 - val_loss: 0.0318
# Epoch 230/1000
# mean max of probabilities: 0.0002090942 - temperature 2.4509554
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0277 - val_loss: 0.0319
# Epoch 231/1000
# mean max of probabilities: 0.00020939435 - temperature 2.4359522
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0277 - val_loss: 0.0316
# Epoch 232/1000
# mean max of probabilities: 0.00020969493 - temperature 2.4210405
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0276 - val_loss: 0.0318
# Epoch 233/1000
# mean max of probabilities: 0.00021001772 - temperature 2.4062204
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0276 - val_loss: 0.0320
# Epoch 234/1000
# mean max of probabilities: 0.00021032651 - temperature 2.3914912
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0276 - val_loss: 0.0323
# Epoch 235/1000
# mean max of probabilities: 0.0002106291 - temperature 2.376852
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0277 - val_loss: 0.0321
# Epoch 236/1000
# mean max of probabilities: 0.00021092873 - temperature 2.3623023
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0276 - val_loss: 0.0320
# Epoch 237/1000
# mean max of probabilities: 0.00021122227 - temperature 2.3478417
# 81/81 [==============================] - 2s 20ms/step - loss: 0.0278 - val_loss: 0.0319
# Epoch 238/1000
# mean max of probabilities: 0.00021157318 - temperature 2.3334696
# 81/81 [==============================] - 1s 17ms/step - loss: 0.0276 - val_loss: 0.0317
# Epoch 239/1000
# mean max of probabilities: 0.00021187217 - temperature 2.3191855
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0276 - val_loss: 0.0318
# Epoch 240/1000
# mean max of probabilities: 0.00021218043 - temperature 2.3049889
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0276 - val_loss: 0.0318
# Epoch 241/1000
# mean max of probabilities: 0.00021243299 - temperature 2.2908792
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0275 - val_loss: 0.0317
# Epoch 242/1000
# mean max of probabilities: 0.00021267717 - temperature 2.276856
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0275 - val_loss: 0.0316
# Epoch 243/1000
# mean max of probabilities: 0.0002129458 - temperature 2.2629185
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0275 - val_loss: 0.0321
# Epoch 244/1000
# mean max of probabilities: 0.00021323461 - temperature 2.2490664
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0278 - val_loss: 0.0318
# Epoch 245/1000
# mean max of probabilities: 0.00021358702 - temperature 2.235299
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0281 - val_loss: 0.0321
# Epoch 246/1000
# mean max of probabilities: 0.00021394734 - temperature 2.2216158
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0276 - val_loss: 0.0318
# Epoch 247/1000
# mean max of probabilities: 0.00021426094 - temperature 2.2080164
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0276 - val_loss: 0.0317
# Epoch 248/1000
# mean max of probabilities: 0.00021462617 - temperature 2.1945004
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0275 - val_loss: 0.0318
# Epoch 249/1000
# mean max of probabilities: 0.00021491878 - temperature 2.1810672
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0275 - val_loss: 0.0318
# Epoch 250/1000
# mean max of probabilities: 0.0002152469 - temperature 2.167716
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0274 - val_loss: 0.0318
# Epoch 251/1000
# mean max of probabilities: 0.00021555067 - temperature 2.1544466
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0273 - val_loss: 0.0319
# Epoch 252/1000
# mean max of probabilities: 0.00021579835 - temperature 2.1412585
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0273 - val_loss: 0.0317
# Epoch 253/1000
# mean max of probabilities: 0.00021605755 - temperature 2.128151
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0276 - val_loss: 0.0317
# Epoch 254/1000
# mean max of probabilities: 0.00021633728 - temperature 2.1151237
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0279 - val_loss: 0.0319
# Epoch 255/1000
# mean max of probabilities: 0.00021670193 - temperature 2.1021764
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0274 - val_loss: 0.0318
# Epoch 256/1000
# mean max of probabilities: 0.0002170071 - temperature 2.089308
# 81/81 [==============================] - 1s 15ms/step - loss: 0.0275 - val_loss: 0.0315
# Epoch 257/1000
# mean max of probabilities: 0.00021729807 - temperature 2.0765185
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0273 - val_loss: 0.0315
# Epoch 258/1000
# mean max of probabilities: 0.0002175836 - temperature 2.0638072
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0274 - val_loss: 0.0316
# Epoch 259/1000
# mean max of probabilities: 0.000217944 - temperature 2.051174
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0273 - val_loss: 0.0314
# Epoch 260/1000
# mean max of probabilities: 0.00021829706 - temperature 2.038618
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0273 - val_loss: 0.0317
# Epoch 261/1000
# mean max of probabilities: 0.00021867095 - temperature 2.0261393
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0271 - val_loss: 0.0315
# Epoch 262/1000
# mean max of probabilities: 0.00021901733 - temperature 2.0137367
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0273 - val_loss: 0.0317
# Epoch 263/1000
# mean max of probabilities: 0.00021930186 - temperature 2.0014105
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0273 - val_loss: 0.0317
# Epoch 264/1000
# mean max of probabilities: 0.0002195719 - temperature 1.9891591
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0273 - val_loss: 0.0317
# Epoch 265/1000
# mean max of probabilities: 0.00021988305 - temperature 1.9769827
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0272 - val_loss: 0.0315
# Epoch 266/1000
# mean max of probabilities: 0.00022017205 - temperature 1.9648808
# 81/81 [==============================] - 1s 7ms/step - loss: 0.0272 - val_loss: 0.0316
# Epoch 267/1000
# mean max of probabilities: 0.00022045175 - temperature 1.952853
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0272 - val_loss: 0.0315
# Epoch 268/1000
# mean max of probabilities: 0.00022072828 - temperature 1.9408988
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0272 - val_loss: 0.0318
# Epoch 269/1000
# mean max of probabilities: 0.00022100023 - temperature 1.9290178
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0272 - val_loss: 0.0317
# Epoch 270/1000
# mean max of probabilities: 0.00022133664 - temperature 1.9172094
# 81/81 [==============================] - 1s 13ms/step - loss: 0.0272 - val_loss: 0.0316
# Epoch 271/1000
# mean max of probabilities: 0.00022173057 - temperature 1.9054735
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0272 - val_loss: 0.0317
# Epoch 272/1000
# mean max of probabilities: 0.00022209916 - temperature 1.8938093
# 81/81 [==============================] - 1s 8ms/step - loss: 0.0272 - val_loss: 0.0319
# Epoch 273/1000
# mean max of probabilities: 0.00022240599 - temperature 1.8822165
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0272 - val_loss: 0.0317
# Epoch 274/1000
# mean max of probabilities: 0.00022269928 - temperature 1.8706946
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0272 - val_loss: 0.0316
# Epoch 275/1000
# mean max of probabilities: 0.0002229934 - temperature 1.8592434
# ...
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0300 - val_loss: 0.0339
# Epoch 904/1000
# mean max of probabilities: 0.00028034154 - temperature 0.1
# 81/81 [==============================] - 4s 43ms/step - loss: 0.0319 - val_loss: 0.0362
# Epoch 905/1000
# mean max of probabilities: 0.00028036622 - temperature 0.1
# 81/81 [==============================] - 4s 50ms/step - loss: 0.0328 - val_loss: 0.0392
# Epoch 906/1000
# mean max of probabilities: 0.00028039468 - temperature 0.1
# 81/81 [==============================] - 3s 35ms/step - loss: 0.0339 - val_loss: 0.0347
# Epoch 907/1000
# mean max of probabilities: 0.00028040964 - temperature 0.1
# 81/81 [==============================] - 2s 22ms/step - loss: 0.0312 - val_loss: 0.0405
# Epoch 908/1000
# mean max of probabilities: 0.00028043456 - temperature 0.1
# 81/81 [==============================] - 3s 40ms/step - loss: 0.0300 - val_loss: 0.0334
# Epoch 909/1000
# mean max of probabilities: 0.0002804597 - temperature 0.1
# 81/81 [==============================] - 6s 71ms/step - loss: 0.0320 - val_loss: 0.0360
# Epoch 910/1000
# mean max of probabilities: 0.00028047257 - temperature 0.1
# 81/81 [==============================] - 5s 63ms/step - loss: 0.0292 - val_loss: 0.0354
# Epoch 911/1000
# mean max of probabilities: 0.00028047906 - temperature 0.1
# 81/81 [==============================] - 4s 44ms/step - loss: 0.0321 - val_loss: 0.0440
# Epoch 912/1000
# mean max of probabilities: 0.00028048205 - temperature 0.1
# 81/81 [==============================] - 3s 43ms/step - loss: 0.0327 - val_loss: 0.0357
# Epoch 913/1000
# mean max of probabilities: 0.00028048316 - temperature 0.1
# 81/81 [==============================] - 5s 63ms/step - loss: 0.0307 - val_loss: 0.0415
# Epoch 914/1000
# mean max of probabilities: 0.00028048313 - temperature 0.1
# 81/81 [==============================] - 6s 69ms/step - loss: 0.0303 - val_loss: 0.0351
# Epoch 915/1000
# mean max of probabilities: 0.0002804824 - temperature 0.1
# 81/81 [==============================] - 4s 51ms/step - loss: 0.0349 - val_loss: 0.0338
# Epoch 916/1000
# mean max of probabilities: 0.00028048168 - temperature 0.1
# 81/81 [==============================] - 3s 39ms/step - loss: 0.0300 - val_loss: 0.0378
# Epoch 917/1000
# mean max of probabilities: 0.00028046645 - temperature 0.1
# 81/81 [==============================] - 3s 35ms/step - loss: 0.0314 - val_loss: 0.0421
# Epoch 918/1000
# mean max of probabilities: 0.00028045278 - temperature 0.1
# 81/81 [==============================] - 4s 54ms/step - loss: 0.0298 - val_loss: 0.0345
# Epoch 919/1000
# mean max of probabilities: 0.00028045074 - temperature 0.1
# 81/81 [==============================] - 4s 50ms/step - loss: 0.0336 - val_loss: 0.0345
# Epoch 920/1000
# mean max of probabilities: 0.00028045714 - temperature 0.1
# 81/81 [==============================] - 2s 31ms/step - loss: 0.0342 - val_loss: 0.0341
# Epoch 921/1000
# mean max of probabilities: 0.00028045964 - temperature 0.1
# 81/81 [==============================] - 3s 34ms/step - loss: 0.0318 - val_loss: 0.0338
# Epoch 922/1000
# mean max of probabilities: 0.0002804606 - temperature 0.1
# 81/81 [==============================] - 4s 52ms/step - loss: 0.0305 - val_loss: 0.0396
# Epoch 923/1000
# mean max of probabilities: 0.00028046078 - temperature 0.1
# 81/81 [==============================] - 5s 61ms/step - loss: 0.0314 - val_loss: 0.0434
# Epoch 924/1000
# mean max of probabilities: 0.00028046063 - temperature 0.1
# 81/81 [==============================] - 5s 65ms/step - loss: 0.0288 - val_loss: 0.0425
# Epoch 925/1000
# mean max of probabilities: 0.00028046017 - temperature 0.1
# 81/81 [==============================] - 6s 68ms/step - loss: 0.0331 - val_loss: 0.0349
# Epoch 926/1000
# mean max of probabilities: 0.0002804594 - temperature 0.1
# 81/81 [==============================] - 8s 97ms/step - loss: 0.0320 - val_loss: 0.0439
# Epoch 927/1000
# mean max of probabilities: 0.00028045863 - temperature 0.1
# 81/81 [==============================] - 5s 66ms/step - loss: 0.0316 - val_loss: 0.0370
# Epoch 928/1000
# mean max of probabilities: 0.0002804577 - temperature 0.1
# 81/81 [==============================] - 5s 62ms/step - loss: 0.0332 - val_loss: 0.0380
# Epoch 929/1000
# mean max of probabilities: 0.00028045662 - temperature 0.1
# 81/81 [==============================] - 6s 76ms/step - loss: 0.0318 - val_loss: 0.0392
# Epoch 930/1000
# mean max of probabilities: 0.00028045542 - temperature 0.1
# 81/81 [==============================] - 6s 77ms/step - loss: 0.0322 - val_loss: 0.0340
# Epoch 931/1000
# mean max of probabilities: 0.00028045604 - temperature 0.1
# 81/81 [==============================] - 6s 69ms/step - loss: 0.0320 - val_loss: 0.0407
# Epoch 932/1000
# mean max of probabilities: 0.0002804562 - temperature 0.1
# 81/81 [==============================] - 3s 43ms/step - loss: 0.0330 - val_loss: 0.0408
# Epoch 933/1000
# mean max of probabilities: 0.00028045577 - temperature 0.1
# 81/81 [==============================] - 4s 44ms/step - loss: 0.0308 - val_loss: 0.0367
# Epoch 934/1000
# mean max of probabilities: 0.00028045528 - temperature 0.1
# 81/81 [==============================] - 4s 54ms/step - loss: 0.0311 - val_loss: 0.0329
# Epoch 935/1000
# mean max of probabilities: 0.00028045458 - temperature 0.1
# 81/81 [==============================] - 6s 70ms/step - loss: 0.0312 - val_loss: 0.0417
# Epoch 936/1000
# mean max of probabilities: 0.00028045347 - temperature 0.1
# 81/81 [==============================] - 4s 49ms/step - loss: 0.0302 - val_loss: 0.0341
# Epoch 937/1000
# mean max of probabilities: 0.0002804523 - temperature 0.1
# 81/81 [==============================] - 4s 52ms/step - loss: 0.0305 - val_loss: 0.0371
# Epoch 938/1000
# mean max of probabilities: 0.00028045825 - temperature 0.1
# 81/81 [==============================] - 5s 64ms/step - loss: 0.0284 - val_loss: 0.0406
# Epoch 939/1000
# mean max of probabilities: 0.0002804618 - temperature 0.1
# 81/81 [==============================] - 7s 81ms/step - loss: 0.0308 - val_loss: 0.0364
# Epoch 940/1000
# mean max of probabilities: 0.00028046317 - temperature 0.1
# 81/81 [==============================] - 6s 69ms/step - loss: 0.0366 - val_loss: 0.0419
# Epoch 941/1000
# mean max of probabilities: 0.0002804636 - temperature 0.1
# 81/81 [==============================] - 5s 62ms/step - loss: 0.0302 - val_loss: 0.0355
# Epoch 942/1000
# mean max of probabilities: 0.00028047233 - temperature 0.1
# 81/81 [==============================] - 4s 52ms/step - loss: 0.0311 - val_loss: 0.0332
# Epoch 943/1000
# mean max of probabilities: 0.00028048258 - temperature 0.1
# 81/81 [==============================] - 5s 68ms/step - loss: 0.0291 - val_loss: 0.0341
# Epoch 944/1000
# mean max of probabilities: 0.00028048787 - temperature 0.1
# 81/81 [==============================] - 6s 73ms/step - loss: 0.0323 - val_loss: 0.0358
# Epoch 945/1000
# mean max of probabilities: 0.00028049017 - temperature 0.1
# 81/81 [==============================] - 4s 47ms/step - loss: 0.0329 - val_loss: 0.0367
# Epoch 946/1000
# mean max of probabilities: 0.00028049108 - temperature 0.1
# 81/81 [==============================] - 3s 34ms/step - loss: 0.0328 - val_loss: 0.0336
# Epoch 947/1000
# mean max of probabilities: 0.00028048822 - temperature 0.1
# 81/81 [==============================] - 3s 39ms/step - loss: 0.0339 - val_loss: 0.0370
# Epoch 948/1000
# mean max of probabilities: 0.00028048476 - temperature 0.1
# 81/81 [==============================] - 4s 48ms/step - loss: 0.0304 - val_loss: 0.0352
# Epoch 949/1000
# mean max of probabilities: 0.0002804979 - temperature 0.1
# 81/81 [==============================] - 3s 38ms/step - loss: 0.0327 - val_loss: 0.0352
# Epoch 950/1000
# mean max of probabilities: 0.00028051354 - temperature 0.1
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0355 - val_loss: 0.0400
# Epoch 951/1000
# mean max of probabilities: 0.00028052158 - temperature 0.1
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0346 - val_loss: 0.0359
# Epoch 952/1000
# mean max of probabilities: 0.0002805257 - temperature 0.1
# 81/81 [==============================] - 4s 46ms/step - loss: 0.0351 - val_loss: 0.0349
# Epoch 953/1000
# mean max of probabilities: 0.00028052897 - temperature 0.1
# 81/81 [==============================] - 5s 61ms/step - loss: 0.0289 - val_loss: 0.0341
# Epoch 954/1000
# mean max of probabilities: 0.00028053147 - temperature 0.1
# 81/81 [==============================] - 6s 73ms/step - loss: 0.0313 - val_loss: 0.0354
# Epoch 955/1000
# mean max of probabilities: 0.0002805325 - temperature 0.1
# 81/81 [==============================] - 7s 81ms/step - loss: 0.0329 - val_loss: 0.0361
# Epoch 956/1000
# mean max of probabilities: 0.00028053246 - temperature 0.1
# 81/81 [==============================] - 6s 79ms/step - loss: 0.0306 - val_loss: 0.0360
# Epoch 957/1000
# mean max of probabilities: 0.0002805322 - temperature 0.1
# 81/81 [==============================] - 8s 98ms/step - loss: 0.0329 - val_loss: 0.0447
# Epoch 958/1000
# mean max of probabilities: 0.00028059183 - temperature 0.1
# 81/81 [==============================] - 6s 68ms/step - loss: 0.0307 - val_loss: 0.0347
# Epoch 959/1000
# mean max of probabilities: 0.0002806322 - temperature 0.1
# 81/81 [==============================] - 5s 60ms/step - loss: 0.0313 - val_loss: 0.0332
# Epoch 960/1000
# mean max of probabilities: 0.00028069707 - temperature 0.1
# 81/81 [==============================] - 4s 52ms/step - loss: 0.0356 - val_loss: 0.0334
# Epoch 961/1000
# mean max of probabilities: 0.00028074725 - temperature 0.1
# 81/81 [==============================] - 4s 52ms/step - loss: 0.0323 - val_loss: 0.0330
# Epoch 962/1000
# mean max of probabilities: 0.0002807737 - temperature 0.1
# 81/81 [==============================] - 4s 47ms/step - loss: 0.0312 - val_loss: 0.0391
# Epoch 963/1000
# mean max of probabilities: 0.00028078735 - temperature 0.1
# 81/81 [==============================] - 3s 41ms/step - loss: 0.0304 - val_loss: 0.0333
# Epoch 964/1000
# mean max of probabilities: 0.00028079422 - temperature 0.1
# 81/81 [==============================] - 4s 46ms/step - loss: 0.0314 - val_loss: 0.0389
# Epoch 965/1000
# mean max of probabilities: 0.00028077708 - temperature 0.1
# 81/81 [==============================] - 4s 54ms/step - loss: 0.0304 - val_loss: 0.0371
# Epoch 966/1000
# mean max of probabilities: 0.0002807377 - temperature 0.1
# 81/81 [==============================] - 4s 53ms/step - loss: 0.0318 - val_loss: 0.0354
# Epoch 967/1000
# mean max of probabilities: 0.00028071646 - temperature 0.1
# 81/81 [==============================] - 4s 51ms/step - loss: 0.0293 - val_loss: 0.0382
# Epoch 968/1000
# mean max of probabilities: 0.0002807046 - temperature 0.1
# 81/81 [==============================] - 5s 62ms/step - loss: 0.0310 - val_loss: 0.0336
# Epoch 969/1000
# mean max of probabilities: 0.0002806979 - temperature 0.1
# 81/81 [==============================] - 5s 62ms/step - loss: 0.0312 - val_loss: 0.0323
# Epoch 970/1000
# mean max of probabilities: 0.00028069416 - temperature 0.1
# 81/81 [==============================] - 5s 60ms/step - loss: 0.0315 - val_loss: 0.0387
# Epoch 971/1000
# mean max of probabilities: 0.00028069192 - temperature 0.1
# 81/81 [==============================] - 5s 66ms/step - loss: 0.0323 - val_loss: 0.0351
# Epoch 972/1000
# mean max of probabilities: 0.00028074227 - temperature 0.1
# 81/81 [==============================] - 5s 60ms/step - loss: 0.0309 - val_loss: 0.0386
# Epoch 973/1000
# mean max of probabilities: 0.00028078927 - temperature 0.1
# 81/81 [==============================] - 6s 73ms/step - loss: 0.0303 - val_loss: 0.0404
# Epoch 974/1000
# mean max of probabilities: 0.00028081867 - temperature 0.1
# 81/81 [==============================] - 5s 59ms/step - loss: 0.0318 - val_loss: 0.0363
# Epoch 975/1000
# mean max of probabilities: 0.0002808342 - temperature 0.1
# 81/81 [==============================] - 5s 58ms/step - loss: 0.0326 - val_loss: 0.0390
# Epoch 976/1000
# mean max of probabilities: 0.00028084236 - temperature 0.1
# 81/81 [==============================] - 2s 25ms/step - loss: 0.0313 - val_loss: 0.0338
# Epoch 977/1000
# mean max of probabilities: 0.00028084658 - temperature 0.1
# 81/81 [==============================] - 3s 39ms/step - loss: 0.0300 - val_loss: 0.0365
# Epoch 978/1000
# mean max of probabilities: 0.0002808487 - temperature 0.1
# 81/81 [==============================] - 4s 44ms/step - loss: 0.0318 - val_loss: 0.0417
# Epoch 979/1000
# mean max of probabilities: 0.000280852 - temperature 0.1
# 81/81 [==============================] - 4s 44ms/step - loss: 0.0302 - val_loss: 0.0371
# Epoch 980/1000
# mean max of probabilities: 0.00028085426 - temperature 0.1
# 81/81 [==============================] - 4s 46ms/step - loss: 0.0302 - val_loss: 0.0421
# Epoch 981/1000
# mean max of probabilities: 0.0002808551 - temperature 0.1
# 81/81 [==============================] - 4s 48ms/step - loss: 0.0316 - val_loss: 0.0339
# Epoch 982/1000
# mean max of probabilities: 0.00028085517 - temperature 0.1
# 81/81 [==============================] - 4s 46ms/step - loss: 0.0333 - val_loss: 0.0382
# Epoch 983/1000
# mean max of probabilities: 0.00028085453 - temperature 0.1
# 81/81 [==============================] - 3s 40ms/step - loss: 0.0322 - val_loss: 0.0330
# Epoch 984/1000
# mean max of probabilities: 0.00028086483 - temperature 0.1
# 81/81 [==============================] - 4s 44ms/step - loss: 0.0297 - val_loss: 0.0357
# Epoch 985/1000
# mean max of probabilities: 0.00028087466 - temperature 0.1
# 81/81 [==============================] - 3s 43ms/step - loss: 0.0320 - val_loss: 0.0392
# Epoch 986/1000
# mean max of probabilities: 0.00028089422 - temperature 0.1
# 81/81 [==============================] - 3s 40ms/step - loss: 0.0347 - val_loss: 0.0351
# Epoch 987/1000
# mean max of probabilities: 0.00028090976 - temperature 0.1
# 81/81 [==============================] - 4s 46ms/step - loss: 0.0338 - val_loss: 0.0339
# Epoch 988/1000
# mean max of probabilities: 0.0002809178 - temperature 0.1
# 81/81 [==============================] - 4s 51ms/step - loss: 0.0315 - val_loss: 0.0361
# Epoch 989/1000
# mean max of probabilities: 0.00028088584 - temperature 0.1
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0309 - val_loss: 0.0355
# Epoch 990/1000
# mean max of probabilities: 0.0002808557 - temperature 0.1
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0314 - val_loss: 0.0351
# Epoch 991/1000
# mean max of probabilities: 0.00028084742 - temperature 0.1
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0313 - val_loss: 0.0339
# Epoch 992/1000
# mean max of probabilities: 0.00028084728 - temperature 0.1
# 81/81 [==============================] - 1s 10ms/step - loss: 0.0323 - val_loss: 0.0356
# Epoch 993/1000
# mean max of probabilities: 0.00028084673 - temperature 0.1
# 81/81 [==============================] - 1s 9ms/step - loss: 0.0300 - val_loss: 0.0371
# Epoch 994/1000
# mean max of probabilities: 0.0002808459 - temperature 0.1
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0354 - val_loss: 0.0373
# Epoch 995/1000
# mean max of probabilities: 0.0002808449 - temperature 0.1
# 81/81 [==============================] - 1s 12ms/step - loss: 0.0322 - val_loss: 0.0385
# Epoch 996/1000
# mean max of probabilities: 0.00028084376 - temperature 0.1
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0312 - val_loss: 0.0471
# Epoch 997/1000
# mean max of probabilities: 0.00028084265 - temperature 0.1
# 81/81 [==============================] - 2s 20ms/step - loss: 0.0330 - val_loss: 0.0336
# Epoch 998/1000
# mean max of probabilities: 0.00028088718 - temperature 0.1
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0315 - val_loss: 0.0339
# Epoch 999/1000
# mean max of probabilities: 0.00028091742 - temperature 0.1
# 81/81 [==============================] - 5s 58ms/step - loss: 0.0311 - val_loss: 0.0373
# Epoch 1000/1000
# mean max of probabilities: 0.00028093325 - temperature 0.1
# 81/81 [==============================] - 4s 52ms/step - loss: 0.0295 - val_loss: 0.0366
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
train_compressed_Data.shape
# Out:
# (102, 64)

# %% [markdown]
# # 4. Classifying

# %% [markdown]
# ### Extra Trees

# %%
train_feature=C_train_x
train_label=C_train_y
test_feature=C_test_x
test_label=C_test_y

print('Shape of train_feature: ' + str(train_feature.shape)) 
print('Shape of train_label: ' + str(train_label.shape)) 
print('Shape of test_feature: ' + str(test_feature.shape)) 
print('Shape of test_label: ' + str(test_label.shape)) 

p_seed=seed
ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Shape of train_feature: (81, 5966)
# Shape of train_label: (81,)
# Shape of test_feature: (21, 5966)
# Shape of test_label: (21,)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9523809523809523
# Testing accuracy： 0.9523809523809523

# %%
C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,label_arr,test_size=0.2,random_state=seed)

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape))
# Out:
# Shape of C_train_x: (81, 5966)
# Shape of C_train_y: (81,)
# Shape of C_test_x: (21, 5966)
# Shape of C_test_y: (21,)

# %%
train_feature=C_train_selected_x
train_label=C_train_y

test_feature=C_test_selected_x
test_label=C_test_y

print('Shape of train_feature: ' + str(train_feature.shape)) 
print('Shape of train_label: ' + str(train_label.shape)) 
print('Shape of test_feature: ' + str(test_feature.shape)) 
print('Shape of test_label: ' + str(test_label.shape)) 

p_seed=seed
ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Shape of train_feature: (81, 64)
# Shape of train_label: (81,)
# Shape of test_feature: (21, 64)
# Shape of test_label: (21,)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.8571428571428571
# Testing accuracy： 0.8571428571428571

# %% [markdown]
# # 6. Reconstruction loss

# %%
from sklearn.linear_model import LinearRegression

def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR

# %%
train_feature_tuple=(C_train_selected_x,C_train_x)
test_feature_tuple=(C_test_selected_x,C_test_x)

reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
print(reconstruction_loss)
# Out:
# 0.048098013784049265
