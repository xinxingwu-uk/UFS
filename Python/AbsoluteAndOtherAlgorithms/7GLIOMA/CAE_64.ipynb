# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io

from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.function.similarity_based import lap_score
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.function.sparse_learning_based.UDFS import udfs
from skfeature.utility.sparse_learning import feature_ranking
import time

from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def ETree(p_train_feature,p_train_label,p_test_feature,p_test_label,p_seed):
    clf = ExtraTreesClassifier(n_estimators=50, random_state=p_seed)
    
    # Training
    clf.fit(p_train_feature, p_train_label)
    
    # Training accuracy
    print('Training accuracy：',clf.score(p_train_feature, np.array(p_train_label)))
    print('Training accuracy：',accuracy_score(np.array(p_train_label),clf.predict(p_train_feature)))
    #print('Training accuracy：',np.sum(clf.predict(p_train_feature)==np.array(p_train_label))/p_train_label.shape[0])

    # Testing accuracy
    print('Testing accuracy：',clf.score(p_test_feature, np.array(p_test_label)))
    print('Testing accuracy：',accuracy_score(np.array(p_test_label),clf.predict(p_test_feature)))
    #print('Testing accuracy：',np.sum(clf.predict(p_test_feature)==np.array(p_test_label))/p_test_label.shape[0])

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')

# %% [markdown]
# # 2. Loading data

# %%
data_path="./Dataset/GLIOMA.mat"
Data = scipy.io.loadmat(data_path)

data_arr=Data['X']
label_arr=Data['Y'][:, 0]-1

Data=MinMaxScaler(feature_range=(0,1)).fit_transform(data_arr)

C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(Data,label_arr,test_size=0.2,random_state=seed)

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape))
# Out:
# Shape of C_train_x: (40, 4434)
# Shape of C_train_y: (40,)
# Shape of C_test_x: (10, 4434)
# Shape of C_test_y: (10,)

# %%
key_feture_number=64

# %% [markdown]
# # 3. Model

# %%
def decoder(x):
    x = Dense(key_feture_number)(x)
    x = Dense(Data.shape[1])(x)
    return x

# %%
C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(Data,label_arr,test_size=0.2,random_state=seed)

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape))
# Out:
# Shape of C_train_x: (40, 4434)
# Shape of C_train_y: (40,)
# Shape of C_test_x: (10, 4434)
# Shape of C_test_y: (10,)

# %%
start = time.clock()

selector = ConcreteAutoencoderFeatureSelector(K = key_feture_number, output_function = decoder, num_epochs = 1000)
selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)

train_compressed_Data=Data[:, selector.get_support(indices=True)]

time_cost=time.clock() - start
write_to_csv(np.array([time_cost]),"./log/CAS_time"+str(key_feture_number)+".csv")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 4434)              0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                283777
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 4434)              288210
# =================================================================
# Total params: 576,147
# Trainable params: 576,146
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 40 samples, validate on 10 samples
# Epoch 1/1000
# mean max of probabilities: 0.00023654701 - temperature 10.0
# 40/40 [==============================] - 1s 29ms/step - loss: 0.2430 - val_loss: 0.1938
# Epoch 2/1000
# mean max of probabilities: 0.00023654712 - temperature 9.9387865
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1917 - val_loss: 0.1414
# Epoch 3/1000
# mean max of probabilities: 0.00023654794 - temperature 9.877948
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1337 - val_loss: 0.0910
# Epoch 4/1000
# mean max of probabilities: 0.00023654981 - temperature 9.817482
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0843 - val_loss: 0.0580
# Epoch 5/1000
# mean max of probabilities: 0.00023655317 - temperature 9.757385
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0563 - val_loss: 0.0518
# Epoch 6/1000
# mean max of probabilities: 0.0002365569 - temperature 9.697658
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0540 - val_loss: 0.0564
# Epoch 7/1000
# mean max of probabilities: 0.00023655855 - temperature 9.638294
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0572 - val_loss: 0.0521
# Epoch 8/1000
# mean max of probabilities: 0.00023655682 - temperature 9.579295
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0512 - val_loss: 0.0446
# Epoch 9/1000
# mean max of probabilities: 0.00023655356 - temperature 9.520658
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0443 - val_loss: 0.0422
# Epoch 10/1000
# mean max of probabilities: 0.00023655107 - temperature 9.4623785
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0433 - val_loss: 0.0433
# Epoch 11/1000
# mean max of probabilities: 0.00023655077 - temperature 9.404456
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0446 - val_loss: 0.0442
# Epoch 12/1000
# mean max of probabilities: 0.00023655116 - temperature 9.346888
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0449 - val_loss: 0.0431
# Epoch 13/1000
# mean max of probabilities: 0.0002365516 - temperature 9.289673
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0433 - val_loss: 0.0414
# Epoch 14/1000
# mean max of probabilities: 0.00023655195 - temperature 9.232808
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0416 - val_loss: 0.0406
# Epoch 15/1000
# mean max of probabilities: 0.00023655235 - temperature 9.1762905
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0410 - val_loss: 0.0408
# Epoch 16/1000
# mean max of probabilities: 0.00023655273 - temperature 9.120119
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0413 - val_loss: 0.0409
# Epoch 17/1000
# mean max of probabilities: 0.00023655308 - temperature 9.064291
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0412 - val_loss: 0.0405
# Epoch 18/1000
# mean max of probabilities: 0.00023655331 - temperature 9.008805
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0408 - val_loss: 0.0401
# Epoch 19/1000
# mean max of probabilities: 0.00023655362 - temperature 8.953659
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0406 - val_loss: 0.0402
# Epoch 20/1000
# mean max of probabilities: 0.00023655393 - temperature 8.8988495
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0406 - val_loss: 0.0403
# Epoch 21/1000
# mean max of probabilities: 0.00023655425 - temperature 8.844376
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0408 - val_loss: 0.0402
# Epoch 22/1000
# mean max of probabilities: 0.0002365545 - temperature 8.790236
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0406 - val_loss: 0.0401
# Epoch 23/1000
# mean max of probabilities: 0.00023655471 - temperature 8.736428
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0405 - val_loss: 0.0401
# Epoch 24/1000
# mean max of probabilities: 0.00023655497 - temperature 8.68295
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0404 - val_loss: 0.0402
# Epoch 25/1000
# mean max of probabilities: 0.0002365553 - temperature 8.629799
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0405 - val_loss: 0.0402
# Epoch 26/1000
# mean max of probabilities: 0.00023655561 - temperature 8.576973
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0405 - val_loss: 0.0400
# Epoch 27/1000
# mean max of probabilities: 0.00023655593 - temperature 8.524469
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0404 - val_loss: 0.0401
# Epoch 28/1000
# mean max of probabilities: 0.00023655628 - temperature 8.472286
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0404 - val_loss: 0.0401
# Epoch 29/1000
# mean max of probabilities: 0.00023655665 - temperature 8.4204235
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0404 - val_loss: 0.0401
# Epoch 30/1000
# mean max of probabilities: 0.00023655707 - temperature 8.368879
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0404 - val_loss: 0.0400
# Epoch 31/1000
# mean max of probabilities: 0.00023655756 - temperature 8.317651
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0403 - val_loss: 0.0399
# Epoch 32/1000
# mean max of probabilities: 0.00023655806 - temperature 8.266736
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0404 - val_loss: 0.0398
# Epoch 33/1000
# mean max of probabilities: 0.00023655863 - temperature 8.216132
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0404 - val_loss: 0.0398
# Epoch 34/1000
# mean max of probabilities: 0.00023655928 - temperature 8.165838
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0404 - val_loss: 0.0398
# Epoch 35/1000
# mean max of probabilities: 0.00023655996 - temperature 8.115852
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 36/1000
# mean max of probabilities: 0.00023656068 - temperature 8.066174
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0403 - val_loss: 0.0399
# Epoch 37/1000
# mean max of probabilities: 0.00023656143 - temperature 8.016797
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0403 - val_loss: 0.0400
# Epoch 38/1000
# mean max of probabilities: 0.00023656228 - temperature 7.9677234
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0404 - val_loss: 0.0401
# Epoch 39/1000
# mean max of probabilities: 0.00023656317 - temperature 7.91895
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0403 - val_loss: 0.0400
# Epoch 40/1000
# mean max of probabilities: 0.00023656407 - temperature 7.870476
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0403 - val_loss: 0.0399
# Epoch 41/1000
# mean max of probabilities: 0.00023656504 - temperature 7.8222976
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 42/1000
# mean max of probabilities: 0.00023656618 - temperature 7.7744145
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 43/1000
# mean max of probabilities: 0.00023656734 - temperature 7.7268248
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 44/1000
# mean max of probabilities: 0.00023656855 - temperature 7.6795263
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 45/1000
# mean max of probabilities: 0.00023656979 - temperature 7.6325173
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 46/1000
# mean max of probabilities: 0.0002365711 - temperature 7.585796
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0403 - val_loss: 0.0397
# Epoch 47/1000
# mean max of probabilities: 0.00023657238 - temperature 7.5393605
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0403 - val_loss: 0.0397
# Epoch 48/1000
# mean max of probabilities: 0.0002365737 - temperature 7.4932094
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 49/1000
# mean max of probabilities: 0.00023657501 - temperature 7.4473405
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0401 - val_loss: 0.0398
# Epoch 50/1000
# mean max of probabilities: 0.00023657634 - temperature 7.401753
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0402 - val_loss: 0.0399
# Epoch 51/1000
# mean max of probabilities: 0.00023657767 - temperature 7.356444
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0402 - val_loss: 0.0399
# Epoch 52/1000
# mean max of probabilities: 0.0002365791 - temperature 7.3114123
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0402 - val_loss: 0.0400
# Epoch 53/1000
# mean max of probabilities: 0.0002365807 - temperature 7.2666564
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0402 - val_loss: 0.0400
# Epoch 54/1000
# mean max of probabilities: 0.00023658242 - temperature 7.2221746
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0401 - val_loss: 0.0400
# Epoch 55/1000
# mean max of probabilities: 0.00023658422 - temperature 7.177965
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0401 - val_loss: 0.0401
# Epoch 56/1000
# mean max of probabilities: 0.00023658598 - temperature 7.134026
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0401
# Epoch 57/1000
# mean max of probabilities: 0.00023658774 - temperature 7.0903563
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0402 - val_loss: 0.0401
# Epoch 58/1000
# mean max of probabilities: 0.00023658958 - temperature 7.0469537
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0402 - val_loss: 0.0399
# Epoch 59/1000
# mean max of probabilities: 0.0002365915 - temperature 7.0038166
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0396
# Epoch 60/1000
# mean max of probabilities: 0.00023659348 - temperature 6.9609437
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0401 - val_loss: 0.0395
# Epoch 61/1000
# mean max of probabilities: 0.0002365956 - temperature 6.918333
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0401 - val_loss: 0.0396
# Epoch 62/1000
# mean max of probabilities: 0.0002365978 - temperature 6.8759837
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0401 - val_loss: 0.0397
# Epoch 63/1000
# mean max of probabilities: 0.0002366 - temperature 6.8338933
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0401 - val_loss: 0.0398
# Epoch 64/1000
# mean max of probabilities: 0.00023660224 - temperature 6.7920604
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0401 - val_loss: 0.0400
# Epoch 65/1000
# mean max of probabilities: 0.00023660454 - temperature 6.750484
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0401 - val_loss: 0.0402
# Epoch 66/1000
# mean max of probabilities: 0.00023660691 - temperature 6.7091618
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0403
# Epoch 67/1000
# mean max of probabilities: 0.00023660943 - temperature 6.668092
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0400 - val_loss: 0.0400
# Epoch 68/1000
# mean max of probabilities: 0.0002366119 - temperature 6.6272736
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0400 - val_loss: 0.0398
# Epoch 69/1000
# mean max of probabilities: 0.00023661439 - temperature 6.5867057
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0400 - val_loss: 0.0397
# Epoch 70/1000
# mean max of probabilities: 0.00023661707 - temperature 6.5463862
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0400 - val_loss: 0.0397
# Epoch 71/1000
# mean max of probabilities: 0.0002366197 - temperature 6.5063133
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0399 - val_loss: 0.0398
# Epoch 72/1000
# mean max of probabilities: 0.00023662232 - temperature 6.466486
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0400 - val_loss: 0.0400
# Epoch 73/1000
# mean max of probabilities: 0.000236625 - temperature 6.426903
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0400 - val_loss: 0.0398
# Epoch 74/1000
# mean max of probabilities: 0.00023662767 - temperature 6.3875613
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0400 - val_loss: 0.0396
# Epoch 75/1000
# mean max of probabilities: 0.00023663047 - temperature 6.3484607
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0399 - val_loss: 0.0396
# Epoch 76/1000
# mean max of probabilities: 0.0002366334 - temperature 6.3095994
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0399 - val_loss: 0.0397
# Epoch 77/1000
# mean max of probabilities: 0.00023663638 - temperature 6.2709765
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0398 - val_loss: 0.0397
# Epoch 78/1000
# mean max of probabilities: 0.00023663933 - temperature 6.23259
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0400 - val_loss: 0.0396
# Epoch 79/1000
# mean max of probabilities: 0.00023664226 - temperature 6.194438
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0399 - val_loss: 0.0397
# Epoch 80/1000
# mean max of probabilities: 0.00023664525 - temperature 6.15652
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0398 - val_loss: 0.0398
# Epoch 81/1000
# mean max of probabilities: 0.00023664837 - temperature 6.1188335
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0398 - val_loss: 0.0398
# Epoch 82/1000
# mean max of probabilities: 0.00023665154 - temperature 6.081378
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0399 - val_loss: 0.0397
# Epoch 83/1000
# mean max of probabilities: 0.00023665473 - temperature 6.0441523
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0399 - val_loss: 0.0398
# Epoch 84/1000
# mean max of probabilities: 0.0002366581 - temperature 6.0071535
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0398 - val_loss: 0.0398
# Epoch 85/1000
# mean max of probabilities: 0.00023666148 - temperature 5.9703813
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0398 - val_loss: 0.0398
# Epoch 86/1000
# mean max of probabilities: 0.00023666496 - temperature 5.9338346
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0398 - val_loss: 0.0398
# Epoch 87/1000
# mean max of probabilities: 0.00023666852 - temperature 5.8975115
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0398 - val_loss: 0.0398
# Epoch 88/1000
# mean max of probabilities: 0.00023667235 - temperature 5.86141
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0398 - val_loss: 0.0398
# Epoch 89/1000
# mean max of probabilities: 0.0002366762 - temperature 5.82553
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0398 - val_loss: 0.0398
# Epoch 90/1000
# mean max of probabilities: 0.00023668008 - temperature 5.78987
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0398 - val_loss: 0.0397
# Epoch 91/1000
# mean max of probabilities: 0.00023668399 - temperature 5.754428
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0397 - val_loss: 0.0398
# Epoch 92/1000
# mean max of probabilities: 0.00023668798 - temperature 5.7192025
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0399 - val_loss: 0.0398
# Epoch 93/1000
# mean max of probabilities: 0.00023669198 - temperature 5.684193
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0398 - val_loss: 0.0397
# Epoch 94/1000
# mean max of probabilities: 0.0002366961 - temperature 5.6493974
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0397 - val_loss: 0.0397
# Epoch 95/1000
# mean max of probabilities: 0.00023670039 - temperature 5.614815
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0397 - val_loss: 0.0397
# Epoch 96/1000
# mean max of probabilities: 0.0002367047 - temperature 5.5804453
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0397 - val_loss: 0.0395
# Epoch 97/1000
# mean max of probabilities: 0.00023670911 - temperature 5.5462856
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0397 - val_loss: 0.0394
# Epoch 98/1000
# mean max of probabilities: 0.0002367137 - temperature 5.512335
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0396 - val_loss: 0.0396
# Epoch 99/1000
# mean max of probabilities: 0.00023671848 - temperature 5.478592
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0397 - val_loss: 0.0397
# Epoch 100/1000
# mean max of probabilities: 0.00023672314 - temperature 5.445056
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0397 - val_loss: 0.0399
# Epoch 101/1000
# mean max of probabilities: 0.00023672782 - temperature 5.4117246
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0397 - val_loss: 0.0399
# Epoch 102/1000
# mean max of probabilities: 0.00023673254 - temperature 5.3785977
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0397 - val_loss: 0.0398
# Epoch 103/1000
# mean max of probabilities: 0.00023673731 - temperature 5.345673
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0397 - val_loss: 0.0399
# Epoch 104/1000
# mean max of probabilities: 0.00023674237 - temperature 5.31295
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0397 - val_loss: 0.0398
# Epoch 105/1000
# mean max of probabilities: 0.00023674729 - temperature 5.280428
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0396 - val_loss: 0.0397
# Epoch 106/1000
# mean max of probabilities: 0.00023675253 - temperature 5.248104
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0396 - val_loss: 0.0398
# Epoch 107/1000
# mean max of probabilities: 0.00023675791 - temperature 5.2159786
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0396 - val_loss: 0.0398
# Epoch 108/1000
# mean max of probabilities: 0.00023676359 - temperature 5.18405
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0397 - val_loss: 0.0396
# Epoch 109/1000
# mean max of probabilities: 0.00023676924 - temperature 5.1523166
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0396 - val_loss: 0.0395
# Epoch 110/1000
# mean max of probabilities: 0.00023677517 - temperature 5.120777
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0395 - val_loss: 0.0394
# Epoch 111/1000
# mean max of probabilities: 0.00023678121 - temperature 5.089431
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0396 - val_loss: 0.0395
# Epoch 112/1000
# mean max of probabilities: 0.0002367873 - temperature 5.058277
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0396 - val_loss: 0.0394
# Epoch 113/1000
# mean max of probabilities: 0.00023679339 - temperature 5.027314
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0396 - val_loss: 0.0393
# Epoch 114/1000
# mean max of probabilities: 0.00023679921 - temperature 4.99654
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0395 - val_loss: 0.0393
# Epoch 115/1000
# mean max of probabilities: 0.00023680512 - temperature 4.9659543
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0395 - val_loss: 0.0393
# Epoch 116/1000
# mean max of probabilities: 0.00023681123 - temperature 4.935556
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0395 - val_loss: 0.0397
# Epoch 117/1000
# mean max of probabilities: 0.00023681775 - temperature 4.9053435
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0396 - val_loss: 0.0400
# Epoch 118/1000
# mean max of probabilities: 0.00023682431 - temperature 4.875316
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0396 - val_loss: 0.0399
# Epoch 119/1000
# mean max of probabilities: 0.0002368309 - temperature 4.845472
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0396 - val_loss: 0.0399
# Epoch 120/1000
# mean max of probabilities: 0.0002368376 - temperature 4.8158107
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0394 - val_loss: 0.0397
# Epoch 121/1000
# mean max of probabilities: 0.00023684441 - temperature 4.7863317
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0394 - val_loss: 0.0396
# Epoch 122/1000
# mean max of probabilities: 0.00023685127 - temperature 4.757033
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0395 - val_loss: 0.0395
# Epoch 123/1000
# mean max of probabilities: 0.0002368583 - temperature 4.7279134
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0395 - val_loss: 0.0394
# Epoch 124/1000
# mean max of probabilities: 0.00023686542 - temperature 4.6989717
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0394 - val_loss: 0.0395
# Epoch 125/1000
# mean max of probabilities: 0.00023687293 - temperature 4.670208
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0394 - val_loss: 0.0395
# Epoch 126/1000
# mean max of probabilities: 0.00023688038 - temperature 4.6416197
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0394 - val_loss: 0.0394
# Epoch 127/1000
# mean max of probabilities: 0.00023688769 - temperature 4.613207
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0394 - val_loss: 0.0394
# Epoch 128/1000
# mean max of probabilities: 0.00023689489 - temperature 4.5849676
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0393 - val_loss: 0.0394
# Epoch 129/1000
# mean max of probabilities: 0.00023690233 - temperature 4.5569015
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0394 - val_loss: 0.0395
# Epoch 130/1000
# mean max of probabilities: 0.00023690988 - temperature 4.5290074
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0395 - val_loss: 0.0396
# Epoch 131/1000
# mean max of probabilities: 0.00023691762 - temperature 4.5012836
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0393 - val_loss: 0.0396
# Epoch 132/1000
# mean max of probabilities: 0.0002369257 - temperature 4.4737296
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0393 - val_loss: 0.0396
# Epoch 133/1000
# mean max of probabilities: 0.0002369343 - temperature 4.446344
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0393 - val_loss: 0.0397
# Epoch 134/1000
# mean max of probabilities: 0.00023694322 - temperature 4.419126
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0393 - val_loss: 0.0397
# Epoch 135/1000
# mean max of probabilities: 0.0002369523 - temperature 4.392075
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0393 - val_loss: 0.0397
# Epoch 136/1000
# mean max of probabilities: 0.00023696164 - temperature 4.3651896
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0393 - val_loss: 0.0394
# Epoch 137/1000
# mean max of probabilities: 0.00023697104 - temperature 4.3384686
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0393 - val_loss: 0.0395
# Epoch 138/1000
# mean max of probabilities: 0.00023698057 - temperature 4.311911
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0393 - val_loss: 0.0394
# Epoch 139/1000
# mean max of probabilities: 0.00023699 - temperature 4.2855163
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0394 - val_loss: 0.0392
# Epoch 140/1000
# mean max of probabilities: 0.0002369993 - temperature 4.2592835
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0393 - val_loss: 0.0392
# Epoch 141/1000
# mean max of probabilities: 0.00023700835 - temperature 4.233211
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0392 - val_loss: 0.0394
# Epoch 142/1000
# mean max of probabilities: 0.0002370174 - temperature 4.2072983
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0392 - val_loss: 0.0396
# Epoch 143/1000
# mean max of probabilities: 0.00023702654 - temperature 4.181544
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0392 - val_loss: 0.0396
# Epoch 144/1000
# mean max of probabilities: 0.000237036 - temperature 4.155947
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0392 - val_loss: 0.0396
# Epoch 145/1000
# mean max of probabilities: 0.00023704604 - temperature 4.130507
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0392 - val_loss: 0.0396
# Epoch 146/1000
# mean max of probabilities: 0.00023705643 - temperature 4.1052227
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0391 - val_loss: 0.0395
# Epoch 147/1000
# mean max of probabilities: 0.00023706739 - temperature 4.0800934
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0391 - val_loss: 0.0394
# Epoch 148/1000
# mean max of probabilities: 0.00023707868 - temperature 4.0551176
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0391 - val_loss: 0.0393
# Epoch 149/1000
# mean max of probabilities: 0.00023708997 - temperature 4.0302954
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0392 - val_loss: 0.0393
# Epoch 150/1000
# mean max of probabilities: 0.00023710122 - temperature 4.0056243
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0392 - val_loss: 0.0392
# Epoch 151/1000
# mean max of probabilities: 0.00023711227 - temperature 3.9811044
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0392 - val_loss: 0.0393
# Epoch 152/1000
# mean max of probabilities: 0.00023712344 - temperature 3.9567347
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0391 - val_loss: 0.0394
# Epoch 153/1000
# mean max of probabilities: 0.0002371352 - temperature 3.9325137
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0390 - val_loss: 0.0394
# Epoch 154/1000
# mean max of probabilities: 0.000237147 - temperature 3.9084413
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0391 - val_loss: 0.0394
# Epoch 155/1000
# mean max of probabilities: 0.00023715885 - temperature 3.8845165
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0390 - val_loss: 0.0392
# Epoch 156/1000
# mean max of probabilities: 0.00023717078 - temperature 3.860738
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0390 - val_loss: 0.0393
# Epoch 157/1000
# mean max of probabilities: 0.00023718312 - temperature 3.837105
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0391 - val_loss: 0.0395
# Epoch 158/1000
# mean max of probabilities: 0.00023719549 - temperature 3.8136168
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0390 - val_loss: 0.0394
# Epoch 159/1000
# mean max of probabilities: 0.00023720787 - temperature 3.7902722
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0390 - val_loss: 0.0395
# Epoch 160/1000
# mean max of probabilities: 0.00023722067 - temperature 3.7670705
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0390 - val_loss: 0.0395
# Epoch 161/1000
# mean max of probabilities: 0.00023723421 - temperature 3.7440112
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0389 - val_loss: 0.0395
# Epoch 162/1000
# mean max of probabilities: 0.00023724785 - temperature 3.721093
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0389 - val_loss: 0.0394
# Epoch 163/1000
# mean max of probabilities: 0.00023726166 - temperature 3.6983147
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0389 - val_loss: 0.0394
# Epoch 164/1000
# mean max of probabilities: 0.00023727608 - temperature 3.6756759
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0389 - val_loss: 0.0395
# Epoch 165/1000
# mean max of probabilities: 0.00023729085 - temperature 3.6531758
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0389 - val_loss: 0.0395
# Epoch 166/1000
# mean max of probabilities: 0.00023730606 - temperature 3.6308131
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0389 - val_loss: 0.0394
# Epoch 167/1000
# mean max of probabilities: 0.00023732128 - temperature 3.6085875
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0389 - val_loss: 0.0393
# Epoch 168/1000
# mean max of probabilities: 0.00023733672 - temperature 3.586498
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0388 - val_loss: 0.0391
# Epoch 169/1000
# mean max of probabilities: 0.00023735261 - temperature 3.5645437
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0389 - val_loss: 0.0391
# Epoch 170/1000
# mean max of probabilities: 0.00023736863 - temperature 3.5427241
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0389 - val_loss: 0.0391
# Epoch 171/1000
# mean max of probabilities: 0.0002373843 - temperature 3.521038
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0388 - val_loss: 0.0392
# Epoch 172/1000
# mean max of probabilities: 0.0002374002 - temperature 3.4994843
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0388 - val_loss: 0.0393
# Epoch 173/1000
# mean max of probabilities: 0.00023741653 - temperature 3.4780629
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0388 - val_loss: 0.0392
# Epoch 174/1000
# mean max of probabilities: 0.00023743277 - temperature 3.4567723
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0388 - val_loss: 0.0392
# Epoch 175/1000
# mean max of probabilities: 0.0002374498 - temperature 3.4356122
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0388 - val_loss: 0.0392
# Epoch 176/1000
# mean max of probabilities: 0.00023746726 - temperature 3.4145818
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0388 - val_loss: 0.0393
# Epoch 177/1000
# mean max of probabilities: 0.00023748484 - temperature 3.3936799
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0387 - val_loss: 0.0393
# Epoch 178/1000
# mean max of probabilities: 0.00023750254 - temperature 3.372906
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0388 - val_loss: 0.0394
# Epoch 179/1000
# mean max of probabilities: 0.00023752074 - temperature 3.3522592
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0387 - val_loss: 0.0392
# Epoch 180/1000
# mean max of probabilities: 0.0002375396 - temperature 3.3317385
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0388 - val_loss: 0.0393
# Epoch 181/1000
# mean max of probabilities: 0.00023755805 - temperature 3.3113437
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0387 - val_loss: 0.0393
# Epoch 182/1000
# mean max of probabilities: 0.00023757615 - temperature 3.2910736
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0386 - val_loss: 0.0394
# Epoch 183/1000
# mean max of probabilities: 0.00023759525 - temperature 3.2709277
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0387 - val_loss: 0.0395
# Epoch 184/1000
# mean max of probabilities: 0.00023761483 - temperature 3.250905
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0388 - val_loss: 0.0395
# Epoch 185/1000
# mean max of probabilities: 0.00023763638 - temperature 3.2310047
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0387 - val_loss: 0.0393
# Epoch 186/1000
# mean max of probabilities: 0.00023765913 - temperature 3.2112265
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0386 - val_loss: 0.0393
# Epoch 187/1000
# mean max of probabilities: 0.00023768301 - temperature 3.1915693
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0386 - val_loss: 0.0392
# Epoch 188/1000
# mean max of probabilities: 0.00023770769 - temperature 3.1720326
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0385 - val_loss: 0.0392
# Epoch 189/1000
# mean max of probabilities: 0.0002377321 - temperature 3.1526153
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0385 - val_loss: 0.0392
# Epoch 190/1000
# mean max of probabilities: 0.00023775594 - temperature 3.1333172
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0386 - val_loss: 0.0393
# Epoch 191/1000
# mean max of probabilities: 0.00023777949 - temperature 3.1141372
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0386 - val_loss: 0.0392
# Epoch 192/1000
# mean max of probabilities: 0.00023780318 - temperature 3.0950744
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0385 - val_loss: 0.0393
# Epoch 193/1000
# mean max of probabilities: 0.0002378273 - temperature 3.0761282
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0385 - val_loss: 0.0393
# Epoch 194/1000
# mean max of probabilities: 0.0002378533 - temperature 3.0572982
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0385 - val_loss: 0.0395
# Epoch 195/1000
# mean max of probabilities: 0.00023788033 - temperature 3.0385833
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0386 - val_loss: 0.0396
# Epoch 196/1000
# mean max of probabilities: 0.00023790807 - temperature 3.0199828
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0386 - val_loss: 0.0396
# Epoch 197/1000
# mean max of probabilities: 0.00023793652 - temperature 3.0014963
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0385 - val_loss: 0.0394
# Epoch 198/1000
# mean max of probabilities: 0.00023796585 - temperature 2.983123
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0385 - val_loss: 0.0392
# Epoch 199/1000
# mean max of probabilities: 0.00023799593 - temperature 2.9648623
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0385 - val_loss: 0.0392
# Epoch 200/1000
# mean max of probabilities: 0.00023802606 - temperature 2.9467134
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0384 - val_loss: 0.0392
# Epoch 201/1000
# mean max of probabilities: 0.00023805547 - temperature 2.9286752
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0384 - val_loss: 0.0391
# Epoch 202/1000
# mean max of probabilities: 0.00023808476 - temperature 2.9107475
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0385 - val_loss: 0.0390
# Epoch 203/1000
# mean max of probabilities: 0.00023811443 - temperature 2.8929298
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0385 - val_loss: 0.0391
# Epoch 204/1000
# mean max of probabilities: 0.0002381439 - temperature 2.875221
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0384 - val_loss: 0.0392
# Epoch 205/1000
# mean max of probabilities: 0.00023817371 - temperature 2.8576207
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0384 - val_loss: 0.0393
# Epoch 206/1000
# mean max of probabilities: 0.0002382035 - temperature 2.8401282
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0384 - val_loss: 0.0393
# Epoch 207/1000
# mean max of probabilities: 0.00023823469 - temperature 2.8227427
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0383 - val_loss: 0.0394
# Epoch 208/1000
# mean max of probabilities: 0.00023826612 - temperature 2.8054638
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0383 - val_loss: 0.0394
# Epoch 209/1000
# mean max of probabilities: 0.00023829791 - temperature 2.7882905
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0384 - val_loss: 0.0395
# Epoch 210/1000
# mean max of probabilities: 0.0002383306 - temperature 2.7712226
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0384 - val_loss: 0.0394
# Epoch 211/1000
# mean max of probabilities: 0.00023836398 - temperature 2.7542589
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0384 - val_loss: 0.0393
# Epoch 212/1000
# mean max of probabilities: 0.0002383969 - temperature 2.737399
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0384 - val_loss: 0.0394
# Epoch 213/1000
# mean max of probabilities: 0.00023843138 - temperature 2.7206426
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0383 - val_loss: 0.0393
# Epoch 214/1000
# mean max of probabilities: 0.00023846517 - temperature 2.7039886
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0383 - val_loss: 0.0392
# Epoch 215/1000
# mean max of probabilities: 0.00023849844 - temperature 2.6874366
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0383 - val_loss: 0.0391
# Epoch 216/1000
# mean max of probabilities: 0.00023853226 - temperature 2.6709857
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0384 - val_loss: 0.0390
# Epoch 217/1000
# mean max of probabilities: 0.00023856625 - temperature 2.6546357
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0384 - val_loss: 0.0393
# Epoch 218/1000
# mean max of probabilities: 0.00023860016 - temperature 2.6383858
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0383 - val_loss: 0.0394
# Epoch 219/1000
# mean max of probabilities: 0.0002386369 - temperature 2.6222353
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0384 - val_loss: 0.0395
# Epoch 220/1000
# mean max of probabilities: 0.00023867449 - temperature 2.6061838
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0383 - val_loss: 0.0396
# Epoch 221/1000
# mean max of probabilities: 0.00023871128 - temperature 2.5902305
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0384 - val_loss: 0.0397
# Epoch 222/1000
# mean max of probabilities: 0.00023874787 - temperature 2.5743747
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0384 - val_loss: 0.0396
# Epoch 223/1000
# mean max of probabilities: 0.00023878635 - temperature 2.5586162
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0383 - val_loss: 0.0394
# Epoch 224/1000
# mean max of probabilities: 0.00023882606 - temperature 2.542954
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0383 - val_loss: 0.0393
# Epoch 225/1000
# mean max of probabilities: 0.00023886444 - temperature 2.5273876
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0382 - val_loss: 0.0392
# Epoch 226/1000
# mean max of probabilities: 0.00023890394 - temperature 2.5119166
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0383 - val_loss: 0.0392
# Epoch 227/1000
# mean max of probabilities: 0.00023894313 - temperature 2.4965403
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0384 - val_loss: 0.0392
# Epoch 228/1000
# mean max of probabilities: 0.000238982 - temperature 2.4812582
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0384 - val_loss: 0.0393
# Epoch 229/1000
# mean max of probabilities: 0.00023902087 - temperature 2.4660695
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0382 - val_loss: 0.0394
# Epoch 230/1000
# mean max of probabilities: 0.00023905994 - temperature 2.4509737
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0383 - val_loss: 0.0394
# Epoch 231/1000
# mean max of probabilities: 0.00023910045 - temperature 2.4359705
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0383 - val_loss: 0.0394
# Epoch 232/1000
# mean max of probabilities: 0.00023914225 - temperature 2.421059
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0382 - val_loss: 0.0393
# Epoch 233/1000
# mean max of probabilities: 0.00023918482 - temperature 2.4062388
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0382 - val_loss: 0.0391
# Epoch 234/1000
# mean max of probabilities: 0.00023923021 - temperature 2.3915093
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0383 - val_loss: 0.0392
# Epoch 235/1000
# mean max of probabilities: 0.00023927588 - temperature 2.37687
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0383 - val_loss: 0.0392
# Epoch 236/1000
# mean max of probabilities: 0.0002393215 - temperature 2.3623202
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0383 - val_loss: 0.0392
# Epoch 237/1000
# mean max of probabilities: 0.00023936701 - temperature 2.3478596
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0384 - val_loss: 0.0392
# Epoch 238/1000
# mean max of probabilities: 0.00023941262 - temperature 2.3334873
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0384 - val_loss: 0.0392
# Epoch 239/1000
# mean max of probabilities: 0.00023945764 - temperature 2.3192034
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0383 - val_loss: 0.0396
# Epoch 240/1000
# mean max of probabilities: 0.00023950427 - temperature 2.3050065
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0384 - val_loss: 0.0396
# Epoch 241/1000
# mean max of probabilities: 0.00023955232 - temperature 2.2908967
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0382 - val_loss: 0.0394
# Epoch 242/1000
# mean max of probabilities: 0.00023960028 - temperature 2.2768734
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0383 - val_loss: 0.0393
# Epoch 243/1000
# mean max of probabilities: 0.000239649 - temperature 2.2629359
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0384 - val_loss: 0.0393
# Epoch 244/1000
# mean max of probabilities: 0.00023969912 - temperature 2.2490835
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0383 - val_loss: 0.0398
# Epoch 245/1000
# mean max of probabilities: 0.00023974762 - temperature 2.2353163
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0383 - val_loss: 0.0396
# Epoch 246/1000
# mean max of probabilities: 0.00023979972 - temperature 2.221633
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0382 - val_loss: 0.0394
# Epoch 247/1000
# mean max of probabilities: 0.00023985584 - temperature 2.2080336
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0383 - val_loss: 0.0393
# Epoch 248/1000
# mean max of probabilities: 0.00023990942 - temperature 2.1945174
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0384 - val_loss: 0.0392
# Epoch 249/1000
# mean max of probabilities: 0.0002399617 - temperature 2.181084
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0383 - val_loss: 0.0394
# Epoch 250/1000
# mean max of probabilities: 0.00024001262 - temperature 2.1677327
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0384 - val_loss: 0.0394
# Epoch 251/1000
# mean max of probabilities: 0.0002400642 - temperature 2.1544633
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0384 - val_loss: 0.0394
# Epoch 252/1000
# mean max of probabilities: 0.00024011647 - temperature 2.1412752
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0383 - val_loss: 0.0394
# Epoch 253/1000
# mean max of probabilities: 0.00024016842 - temperature 2.1281674
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0382 - val_loss: 0.0394
# Epoch 254/1000
# mean max of probabilities: 0.0002402204 - temperature 2.1151397
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0382 - val_loss: 0.0394
# Epoch 255/1000
# mean max of probabilities: 0.00024027316 - temperature 2.1021922
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0382 - val_loss: 0.0392
# Epoch 256/1000
# mean max of probabilities: 0.00024033437 - temperature 2.089324
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0383 - val_loss: 0.0392
# Epoch 257/1000
# mean max of probabilities: 0.00024039292 - temperature 2.0765345
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0382 - val_loss: 0.0394
# Epoch 258/1000
# mean max of probabilities: 0.0002404506 - temperature 2.0638235
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0383 - val_loss: 0.0396
# Epoch 259/1000
# mean max of probabilities: 0.00024050931 - temperature 2.05119
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0382 - val_loss: 0.0395
# Epoch 260/1000
# mean max of probabilities: 0.00024056825 - temperature 2.0386338
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0382 - val_loss: 0.0395
# Epoch 261/1000
# mean max of probabilities: 0.00024062875 - temperature 2.0261548
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0383 - val_loss: 0.0395
# Epoch 262/1000
# mean max of probabilities: 0.00024069051 - temperature 2.0137522
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0382 - val_loss: 0.0395
# Epoch 263/1000
# mean max of probabilities: 0.00024074974 - temperature 2.0014253
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0382 - val_loss: 0.0396
# Epoch 264/1000
# mean max of probabilities: 0.0002408126 - temperature 1.9891739
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0382 - val_loss: 0.0395
# Epoch 265/1000
# mean max of probabilities: 0.00024088245 - temperature 1.9769975
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0382 - val_loss: 0.0395
# Epoch 266/1000
# mean max of probabilities: 0.000240947 - temperature 1.9648956
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0383 - val_loss: 0.0395
# Epoch 267/1000
# mean max of probabilities: 0.00024101119 - temperature 1.9528677
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0382 - val_loss: 0.0395
# Epoch 268/1000
# mean max of probabilities: 0.00024107445 - temperature 1.9409134
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0382 - val_loss: 0.0394
# Epoch 269/1000
# mean max of probabilities: 0.00024113784 - temperature 1.9290324
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0382 - val_loss: 0.0394
# Epoch 270/1000
# mean max of probabilities: 0.00024119858 - temperature 1.917224
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0382 - val_loss: 0.0393
# Epoch 271/1000
# mean max of probabilities: 0.00024126214 - temperature 1.905488
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0383 - val_loss: 0.0394
# Epoch 272/1000
# mean max of probabilities: 0.00024132915 - temperature 1.8938239
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0383 - val_loss: 0.0391
# Epoch 273/1000
# mean max of probabilities: 0.00024139964 - temperature 1.8822311
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0383 - val_loss: 0.0392
# Epoch 274/1000
# mean max of probabilities: 0.00024146793 - temperature 1.8707093
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0382 - val_loss: 0.0394
# Epoch 275/1000
# ...
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0388 - val_loss: 0.0403
# Epoch 904/1000
# mean max of probabilities: 0.00026834337 - temperature 0.1
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0405 - val_loss: 0.0415
# Epoch 905/1000
# mean max of probabilities: 0.00026834483 - temperature 0.1
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0393 - val_loss: 0.0405
# Epoch 906/1000
# mean max of probabilities: 0.0002683457 - temperature 0.1
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0397 - val_loss: 0.0390
# Epoch 907/1000
# mean max of probabilities: 0.00026834858 - temperature 0.1
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0402 - val_loss: 0.0418
# Epoch 908/1000
# mean max of probabilities: 0.00026835274 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0404 - val_loss: 0.0394
# Epoch 909/1000
# mean max of probabilities: 0.0002683557 - temperature 0.1
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0398 - val_loss: 0.0422
# Epoch 910/1000
# mean max of probabilities: 0.00026835775 - temperature 0.1
# 40/40 [==============================] - 2s 47ms/step - loss: 0.0414 - val_loss: 0.0410
# Epoch 911/1000
# mean max of probabilities: 0.00026835917 - temperature 0.1
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0387 - val_loss: 0.0418
# Epoch 912/1000
# mean max of probabilities: 0.00026836008 - temperature 0.1
# 40/40 [==============================] - 2s 60ms/step - loss: 0.0407 - val_loss: 0.0426
# Epoch 913/1000
# mean max of probabilities: 0.00026836072 - temperature 0.1
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0408 - val_loss: 0.0402
# Epoch 914/1000
# mean max of probabilities: 0.00026836115 - temperature 0.1
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0402 - val_loss: 0.0403
# Epoch 915/1000
# mean max of probabilities: 0.00026836764 - temperature 0.1
# 40/40 [==============================] - 2s 48ms/step - loss: 0.0403 - val_loss: 0.0400
# Epoch 916/1000
# mean max of probabilities: 0.00026839142 - temperature 0.1
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0401 - val_loss: 0.0431
# Epoch 917/1000
# mean max of probabilities: 0.0002684087 - temperature 0.1
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0404 - val_loss: 0.0408
# Epoch 918/1000
# mean max of probabilities: 0.00026842143 - temperature 0.1
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0387 - val_loss: 0.0402
# Epoch 919/1000
# mean max of probabilities: 0.00026843062 - temperature 0.1
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0401 - val_loss: 0.0405
# Epoch 920/1000
# mean max of probabilities: 0.00026843732 - temperature 0.1
# 40/40 [==============================] - 2s 48ms/step - loss: 0.0405 - val_loss: 0.0409
# Epoch 921/1000
# mean max of probabilities: 0.00026844206 - temperature 0.1
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0400 - val_loss: 0.0409
# Epoch 922/1000
# mean max of probabilities: 0.0002684454 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0395 - val_loss: 0.0419
# Epoch 923/1000
# mean max of probabilities: 0.0002684478 - temperature 0.1
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0411 - val_loss: 0.0432
# Epoch 924/1000
# mean max of probabilities: 0.00026844942 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0399 - val_loss: 0.0406
# Epoch 925/1000
# mean max of probabilities: 0.00026845062 - temperature 0.1
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0402 - val_loss: 0.0421
# Epoch 926/1000
# mean max of probabilities: 0.0002684514 - temperature 0.1
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0399 - val_loss: 0.0403
# Epoch 927/1000
# mean max of probabilities: 0.00026845184 - temperature 0.1
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0394 - val_loss: 0.0381
# Epoch 928/1000
# mean max of probabilities: 0.00026845207 - temperature 0.1
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0395 - val_loss: 0.0403
# Epoch 929/1000
# mean max of probabilities: 0.00026845216 - temperature 0.1
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0412 - val_loss: 0.0411
# Epoch 930/1000
# mean max of probabilities: 0.00026845312 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0399 - val_loss: 0.0418
# Epoch 931/1000
# mean max of probabilities: 0.00026845382 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0400 - val_loss: 0.0405
# Epoch 932/1000
# mean max of probabilities: 0.0002684542 - temperature 0.1
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0397 - val_loss: 0.0405
# Epoch 933/1000
# mean max of probabilities: 0.00026846156 - temperature 0.1
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0403 - val_loss: 0.0394
# Epoch 934/1000
# mean max of probabilities: 0.0002684815 - temperature 0.1
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0406 - val_loss: 0.0396
# Epoch 935/1000
# mean max of probabilities: 0.00026849605 - temperature 0.1
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0399 - val_loss: 0.0412
# Epoch 936/1000
# mean max of probabilities: 0.00026850658 - temperature 0.1
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0397 - val_loss: 0.0396
# Epoch 937/1000
# mean max of probabilities: 0.0002685142 - temperature 0.1
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0393 - val_loss: 0.0423
# Epoch 938/1000
# mean max of probabilities: 0.00026851968 - temperature 0.1
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0398 - val_loss: 0.0438
# Epoch 939/1000
# mean max of probabilities: 0.00026852358 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0389 - val_loss: 0.0410
# Epoch 940/1000
# mean max of probabilities: 0.00026852635 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0395 - val_loss: 0.0397
# Epoch 941/1000
# mean max of probabilities: 0.0002685283 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0396 - val_loss: 0.0411
# Epoch 942/1000
# mean max of probabilities: 0.00026852963 - temperature 0.1
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0394 - val_loss: 0.0401
# Epoch 943/1000
# mean max of probabilities: 0.00026853054 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0394 - val_loss: 0.0415
# Epoch 944/1000
# mean max of probabilities: 0.00026853138 - temperature 0.1
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0395 - val_loss: 0.0399
# Epoch 945/1000
# mean max of probabilities: 0.000268532 - temperature 0.1
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0395 - val_loss: 0.0406
# Epoch 946/1000
# mean max of probabilities: 0.00026853825 - temperature 0.1
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0397 - val_loss: 0.0394
# Epoch 947/1000
# mean max of probabilities: 0.00026854264 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0400 - val_loss: 0.0399
# Epoch 948/1000
# mean max of probabilities: 0.00026853976 - temperature 0.1
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0393 - val_loss: 0.0399
# Epoch 949/1000
# mean max of probabilities: 0.00026854617 - temperature 0.1
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0392 - val_loss: 0.0403
# Epoch 950/1000
# mean max of probabilities: 0.00026855525 - temperature 0.1
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0399 - val_loss: 0.0404
# Epoch 951/1000
# mean max of probabilities: 0.00026857862 - temperature 0.1
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0399 - val_loss: 0.0414
# Epoch 952/1000
# mean max of probabilities: 0.00026860426 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0396 - val_loss: 0.0404
# Epoch 953/1000
# mean max of probabilities: 0.00026863132 - temperature 0.1
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0393 - val_loss: 0.0401
# Epoch 954/1000
# mean max of probabilities: 0.00026865103 - temperature 0.1
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0393 - val_loss: 0.0398
# Epoch 955/1000
# mean max of probabilities: 0.00026866543 - temperature 0.1
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0393 - val_loss: 0.0407
# Epoch 956/1000
# mean max of probabilities: 0.00026867585 - temperature 0.1
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0405 - val_loss: 0.0406
# Epoch 957/1000
# mean max of probabilities: 0.0002686835 - temperature 0.1
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0398 - val_loss: 0.0407
# Epoch 958/1000
# mean max of probabilities: 0.000268689 - temperature 0.1
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0397 - val_loss: 0.0397
# Epoch 959/1000
# mean max of probabilities: 0.000268693 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0388 - val_loss: 0.0423
# Epoch 960/1000
# mean max of probabilities: 0.0002686957 - temperature 0.1
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0399 - val_loss: 0.0401
# Epoch 961/1000
# mean max of probabilities: 0.00026869762 - temperature 0.1
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0383 - val_loss: 0.0398
# Epoch 962/1000
# mean max of probabilities: 0.000268699 - temperature 0.1
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0393 - val_loss: 0.0412
# Epoch 963/1000
# mean max of probabilities: 0.00026869995 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0401 - val_loss: 0.0398
# Epoch 964/1000
# mean max of probabilities: 0.0002687006 - temperature 0.1
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0394 - val_loss: 0.0407
# Epoch 965/1000
# mean max of probabilities: 0.00026870094 - temperature 0.1
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0395 - val_loss: 0.0397
# Epoch 966/1000
# mean max of probabilities: 0.00026870106 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0398 - val_loss: 0.0405
# Epoch 967/1000
# mean max of probabilities: 0.00026870304 - temperature 0.1
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0397 - val_loss: 0.0401
# Epoch 968/1000
# mean max of probabilities: 0.00026870443 - temperature 0.1
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 969/1000
# mean max of probabilities: 0.00026870536 - temperature 0.1
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0391 - val_loss: 0.0403
# Epoch 970/1000
# mean max of probabilities: 0.00026870595 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0398 - val_loss: 0.0430
# Epoch 971/1000
# mean max of probabilities: 0.00026870635 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0391 - val_loss: 0.0426
# Epoch 972/1000
# mean max of probabilities: 0.00026870664 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0414 - val_loss: 0.0401
# Epoch 973/1000
# mean max of probabilities: 0.0002687067 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0417 - val_loss: 0.0415
# Epoch 974/1000
# mean max of probabilities: 0.00026871066 - temperature 0.1
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0392 - val_loss: 0.0432
# Epoch 975/1000
# mean max of probabilities: 0.00026871482 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0391 - val_loss: 0.0408
# Epoch 976/1000
# mean max of probabilities: 0.00026871782 - temperature 0.1
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0400 - val_loss: 0.0420
# Epoch 977/1000
# mean max of probabilities: 0.00026872125 - temperature 0.1
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0394 - val_loss: 0.0398
# Epoch 978/1000
# mean max of probabilities: 0.00026872498 - temperature 0.1
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0382 - val_loss: 0.0414
# Epoch 979/1000
# mean max of probabilities: 0.00026872795 - temperature 0.1
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0401 - val_loss: 0.0404
# Epoch 980/1000
# mean max of probabilities: 0.00026873936 - temperature 0.1
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0402 - val_loss: 0.0413
# Epoch 981/1000
# mean max of probabilities: 0.00026875176 - temperature 0.1
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0396 - val_loss: 0.0400
# Epoch 982/1000
# mean max of probabilities: 0.00026877018 - temperature 0.1
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0396 - val_loss: 0.0413
# Epoch 983/1000
# mean max of probabilities: 0.00026878365 - temperature 0.1
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0394 - val_loss: 0.0405
# Epoch 984/1000
# mean max of probabilities: 0.00026879355 - temperature 0.1
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0394 - val_loss: 0.0419
# Epoch 985/1000
# mean max of probabilities: 0.00026880074 - temperature 0.1
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0406 - val_loss: 0.0418
# Epoch 986/1000
# mean max of probabilities: 0.00026880606 - temperature 0.1
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0396 - val_loss: 0.0384
# Epoch 987/1000
# mean max of probabilities: 0.00026880988 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0406 - val_loss: 0.0414
# Epoch 988/1000
# mean max of probabilities: 0.0002688126 - temperature 0.1
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0390 - val_loss: 0.0423
# Epoch 989/1000
# mean max of probabilities: 0.0002688145 - temperature 0.1
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0397 - val_loss: 0.0410
# Epoch 990/1000
# mean max of probabilities: 0.00026881578 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0398 - val_loss: 0.0402
# Epoch 991/1000
# mean max of probabilities: 0.0002688167 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0388 - val_loss: 0.0410
# Epoch 992/1000
# mean max of probabilities: 0.00026881724 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0403 - val_loss: 0.0402
# Epoch 993/1000
# mean max of probabilities: 0.0002688176 - temperature 0.1
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0417 - val_loss: 0.0418
# Epoch 994/1000
# mean max of probabilities: 0.00026882315 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0411 - val_loss: 0.0434
# Epoch 995/1000
# mean max of probabilities: 0.00026883837 - temperature 0.1
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0427 - val_loss: 0.0400
# Epoch 996/1000
# mean max of probabilities: 0.0002688494 - temperature 0.1
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0389 - val_loss: 0.0408
# Epoch 997/1000
# mean max of probabilities: 0.00026885967 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0429 - val_loss: 0.0410
# Epoch 998/1000
# mean max of probabilities: 0.00026889358 - temperature 0.1
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0392 - val_loss: 0.0405
# Epoch 999/1000
# mean max of probabilities: 0.00026891846 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0399 - val_loss: 0.0415
# Epoch 1000/1000
# mean max of probabilities: 0.00026893665 - temperature 0.1
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0391 - val_loss: 0.0409
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
train_compressed_Data.shape
# Out:
# (50, 64)

# %% [markdown]
# # 4. Classifying

# %% [markdown]
# ### Extra Trees

# %%
train_feature=C_train_x
train_label=C_train_y
test_feature=C_test_x
test_label=C_test_y

print('Shape of train_feature: ' + str(train_feature.shape)) 
print('Shape of train_label: ' + str(train_label.shape)) 
print('Shape of test_feature: ' + str(test_feature.shape)) 
print('Shape of test_label: ' + str(test_label.shape)) 

p_seed=seed
ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Shape of train_feature: (40, 4434)
# Shape of train_label: (40,)
# Shape of test_feature: (10, 4434)
# Shape of test_label: (10,)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9
# Testing accuracy： 0.9

# %%
C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,label_arr,test_size=0.2,random_state=seed)

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape))
# Out:
# Shape of C_train_x: (40, 4434)
# Shape of C_train_y: (40,)
# Shape of C_test_x: (10, 4434)
# Shape of C_test_y: (10,)

# %%
train_feature=C_train_selected_x
train_label=C_train_y

test_feature=C_test_selected_x
test_label=C_test_y

print('Shape of train_feature: ' + str(train_feature.shape)) 
print('Shape of train_label: ' + str(train_label.shape)) 
print('Shape of test_feature: ' + str(test_feature.shape)) 
print('Shape of test_label: ' + str(test_label.shape)) 

p_seed=seed
ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Shape of train_feature: (40, 64)
# Shape of train_label: (40,)
# Shape of test_feature: (10, 64)
# Shape of test_label: (10,)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.5
# Testing accuracy： 0.5

# %% [markdown]
# # 6. Reconstruction loss

# %%
from sklearn.linear_model import LinearRegression

def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR

# %%
train_feature_tuple=(C_train_selected_x,C_train_x)
test_feature_tuple=(C_test_selected_x,C_test_x)

reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
print(reconstruction_loss)
# Out:
# 0.06273260372857421
