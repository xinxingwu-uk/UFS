# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K

#tf.set_random_seed(seed)
tf.compat.v1.set_random_seed(seed)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)

K.set_session(sess)
#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
from keras.datasets import fashion_mnist
from keras.models import Model
from keras.layers import Dense, Input, Flatten, Activation, Dropout, Layer
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical
from keras import optimizers,initializers,constraints,regularizers
from keras import backend as K
from keras.callbacks import LambdaCallback,ModelCheckpoint
from keras.utils import plot_model

from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

import h5py
import math
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.model_selection import train_test_split
import scipy.sparse as sparse

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"./Defined")
import Functions as F

# The following code should be added before the keras model
#np.random.seed(seed)
# Out:
# Using TensorFlow backend.

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

# %% [markdown]
# # 2. Loading data

# %%
dataset_path='./Dataset/coil-20-proc/'

samples={}
for dirpath, dirnames, filenames in os.walk(dataset_path):
    #print(dirpath)
    #print(dirnames)
    #print(filenames)
    dirnames.sort()
    filenames.sort()
    for filename in [f for f in filenames if f.endswith(".png") and not f.find('checkpoint')>0]:
        full_path = os.path.join(dirpath, filename)
        file_identifier=filename.split('__')[0][3:]
        if file_identifier not in samples.keys():
            samples[file_identifier] = []
        # Direct read
        #image = io.imread(full_path)
        # Resize read
        image_=Image.open(full_path).resize((20, 20),Image.ANTIALIAS)
        image=np.asarray(image_)
        samples[file_identifier].append(image)
        
#plt.imshow(samples['1'][0].reshape(20,20))

# %%
data_arr_list=[]
label_arr_list=[]
for key_i in samples.keys():
    key_i_for_label=[int(key_i)-1]
    data_arr_list.append(np.array(samples[key_i]))
    label_arr_list.append(np.array(72*key_i_for_label))
    
data_arr=np.concatenate(data_arr_list).reshape(1440, 20*20).astype('float32') / 255.
label_arr_onehot=to_categorical(np.concatenate(label_arr_list))

# %%
sample_used=499

x_train_all,x_test,y_train_all,y_test_onehot= train_test_split(data_arr,label_arr_onehot,test_size=0.2,random_state=seed)

x_train=x_train_all[0:sample_used]
y_train_onehot=y_train_all[0:sample_used]

print('Shape of x_train: ' + str(x_train.shape)) 
print('Shape of x_test: ' + str(x_test.shape))
print('Shape of y_train: ' + str(y_train_onehot.shape))
print('Shape of y_test: ' + str(y_test_onehot.shape))

F.show_data_figures(x_train[0:40],20,20,40)
F.show_data_figures(x_test[0:40],20,20,40)
# Out:
# Shape of x_train: (499, 400)
# Shape of x_test: (288, 400)
# Shape of y_train: (499, 20)
# Shape of y_test: (288, 20)

# %%
key_feture_number=50

# %% [markdown]
# # 3.Model

# %%
np.random.seed(seed)

#--------------------------------------------------------------------------------------------------------------------------------
class Feature_Select_Layer(Layer):
    
    def __init__(self, output_dim, **kwargs):
        super(Feature_Select_Layer, self).__init__(**kwargs)
        self.output_dim = output_dim

    def build(self, input_shape):
        self.kernel = self.add_weight(name='kernel',  
                                      shape=(input_shape[1],),
                                      initializer=initializers.RandomUniform(minval=0.999999, maxval=0.9999999, seed=seed),
                                      trainable=True)
        super(Feature_Select_Layer, self).build(input_shape)
    
    def call(self, x, selection=False,k=key_feture_number):
        kernel=K.abs(self.kernel)      
        if selection:
            kernel_=K.transpose(kernel)
            kth_largest = tf.math.top_k(kernel_, k=k)[0][-1]
            kernel = tf.where(condition=K.less(kernel,kth_largest),x=K.zeros_like(kernel),y=kernel)        
        return K.dot(x, tf.linalg.tensor_diag(kernel))

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

#--------------------------------------------------------------------------------------------------------------------------------
def Fractal_Autoencoder(p_data_feature=x_train.shape[1],\
                        p_feture_number=key_feture_number,\
                        p_encoding_dim=key_feture_number,\
                        p_learning_rate=1E-3,\
                        p_loss_weight_1=1,\
                        p_loss_weight_2=2):
    
    input_img = Input(shape=(p_data_feature,), name='autoencoder_input')

    feature_selection = Feature_Select_Layer(output_dim=p_data_feature,\
                                             input_shape=(p_data_feature,),\
                                             name='feature_selection')

    feature_selection_score=feature_selection(input_img)
    feature_selection_choose=feature_selection(input_img,selection=True,k=p_feture_number)

    encoded = Dense(p_encoding_dim,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_hidden_layer')
    
    encoded_score=encoded(feature_selection_score)
    encoded_choose=encoded(feature_selection_choose)
    
    bottleneck_score=encoded_score
    bottleneck_choose=encoded_choose
    
    decoded = Dense(p_data_feature,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_output')
    
    decoded_score =decoded(bottleneck_score)
    decoded_choose =decoded(bottleneck_choose)

    latent_encoder_score = Model(input_img, bottleneck_score)
    latent_encoder_choose = Model(input_img, bottleneck_choose)
    feature_selection_output=Model(input_img,feature_selection_choose)
    autoencoder = Model(input_img, [decoded_score,decoded_choose])
    
    autoencoder.compile(loss=['mean_squared_error','mean_squared_error'],\
                        loss_weights=[p_loss_weight_1, p_loss_weight_2],\
                        optimizer=optimizers.Adam(lr=p_learning_rate))
    
    print('Autoencoder Structure-------------------------------------')
    autoencoder.summary()
    return autoencoder,feature_selection_output,latent_encoder_score,latent_encoder_choose

# %% [markdown]
# ## 3.1 Structure and paramter testing

# %%
epochs_number=200
batch_size_value=8

# %% [markdown]
# ---
# ### 3.1.1 Fractal Autoencoder
# ---

# %%
loss_weight_1=0.0078125
F_AE,\
feature_selection_output,\
latent_encoder_score_F_AE,\
latent_encoder_choose_F_AE=Fractal_Autoencoder(p_data_feature=x_train.shape[1],\
                                               p_feture_number=key_feture_number,\
                                               p_encoding_dim=key_feture_number,\
                                               p_learning_rate= 1E-3,\
                                               p_loss_weight_1=loss_weight_1,\
                                               p_loss_weight_2=1)
# Out:
# WARNING:tensorflow:From /home/xinxingwu/venv3.7.8/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From <ipython-input-7-84609d302082>:22: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Autoencoder Structure-------------------------------------
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# autoencoder_input (InputLayer)  (None, 400)          0
# __________________________________________________________________________________________________
# feature_selection (Feature_Sele (None, 400)          400         autoencoder_input[0][0]
#                                                                  autoencoder_input[0][0]
# __________________________________________________________________________________________________
# autoencoder_hidden_layer (Dense (None, 50)           20050       feature_selection[0][0]
#                                                                  feature_selection[1][0]
# __________________________________________________________________________________________________
# autoencoder_output (Dense)      (None, 400)          20400       autoencoder_hidden_layer[0][0]
#                                                                  autoencoder_hidden_layer[1][0]
# ==================================================================================================
# Total params: 40,850
# Trainable params: 40,850
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
F_AE_history = F_AE.fit(x_train, [x_train,x_train],\
                        epochs=epochs_number,\
                        batch_size=batch_size_value,\
                        shuffle=True)
# Out:
# WARNING:tensorflow:From /home/xinxingwu/venv3.7.8/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0847 - autoencoder_output_loss: 0.0835
# Epoch 2/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0420 - autoencoder_output_loss: 0.0415
# Epoch 3/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0329 - autoencoder_output_loss: 0.0326
# Epoch 4/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0278 - autoencoder_output_loss: 0.0276
# Epoch 5/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0250 - autoencoder_output_loss: 0.0249
# Epoch 6/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0231 - autoencoder_output_loss: 0.0230
# Epoch 7/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0217 - autoencoder_output_loss: 0.0215
# Epoch 8/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0207 - autoencoder_output_loss: 0.0204
# Epoch 9/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0195 - autoencoder_output_loss: 0.0193
# Epoch 10/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0187 - autoencoder_output_loss: 0.0185
# Epoch 11/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0180 - autoencoder_output_loss: 0.0180
# Epoch 12/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0175 - autoencoder_output_loss: 0.0174
# Epoch 13/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0171 - autoencoder_output_loss: 0.0169
# Epoch 14/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0168 - autoencoder_output_loss: 0.0167
# Epoch 15/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0165 - autoencoder_output_loss: 0.0163
# Epoch 16/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0162 - autoencoder_output_loss: 0.0161
# Epoch 17/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0159 - autoencoder_output_loss: 0.0158
# Epoch 18/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0157 - autoencoder_output_loss: 0.0156
# Epoch 19/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0155 - autoencoder_output_loss: 0.0153
# Epoch 20/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0152 - autoencoder_output_loss: 0.0151
# Epoch 21/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0151 - autoencoder_output_loss: 0.0151
# Epoch 22/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0149 - autoencoder_output_loss: 0.0148
# Epoch 23/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0148 - autoencoder_output_loss: 0.0146
# Epoch 24/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0146 - autoencoder_output_loss: 0.0146
# Epoch 25/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0145 - autoencoder_output_loss: 0.0144
# Epoch 26/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0145 - autoencoder_output_loss: 0.0144
# Epoch 27/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0142 - autoencoder_output_loss: 0.0142
# Epoch 28/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0141 - autoencoder_output_loss: 0.0140
# Epoch 29/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0140 - autoencoder_output_loss: 0.0139
# Epoch 30/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0148 - autoencoder_output_loss: 0.0147
# Epoch 31/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0142 - autoencoder_output_loss: 0.0141
# Epoch 32/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0138 - autoencoder_output_loss: 0.0137
# Epoch 33/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0138 - autoencoder_output_loss: 0.0137
# Epoch 34/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0137 - autoencoder_output_loss: 0.0136
# Epoch 35/200
# 499/499 [==============================] - 0s 902us/step - loss: 0.0136 - autoencoder_output_loss: 0.0135
# Epoch 36/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0137 - autoencoder_output_loss: 0.0136
# Epoch 37/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0135 - autoencoder_output_loss: 0.0134
# Epoch 38/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0134 - autoencoder_output_loss: 0.0133
# Epoch 39/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0134 - autoencoder_output_loss: 0.0133
# Epoch 40/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0134 - autoencoder_output_loss: 0.0133
# Epoch 41/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0132 - autoencoder_output_loss: 0.0132
# Epoch 42/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0133 - autoencoder_output_loss: 0.0132
# Epoch 43/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0131 - autoencoder_output_loss: 0.0130
# Epoch 44/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0131 - autoencoder_output_loss: 0.0130
# Epoch 45/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0130 - autoencoder_output_loss: 0.0130
# Epoch 46/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0130 - autoencoder_output_loss: 0.0129
# Epoch 47/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0130 - autoencoder_output_loss: 0.0130
# Epoch 48/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0130 - autoencoder_output_loss: 0.0129
# Epoch 49/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0129 - autoencoder_output_loss: 0.0128
# Epoch 50/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0129 - autoencoder_output_loss: 0.0128
# Epoch 51/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0128 - autoencoder_output_loss: 0.0127
# Epoch 52/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0128 - autoencoder_output_loss: 0.0127
# Epoch 53/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0128 - autoencoder_output_loss: 0.0127
# Epoch 54/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0128 - autoencoder_output_loss: 0.0127
# Epoch 55/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0127 - autoencoder_output_loss: 0.0126
# Epoch 56/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0127 - autoencoder_output_loss: 0.0126
# Epoch 57/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0127 - autoencoder_output_loss: 0.0126
# Epoch 58/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0127 - autoencoder_output_loss: 0.0126
# Epoch 59/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0127 - autoencoder_output_loss: 0.0126
# Epoch 60/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0126 - autoencoder_output_loss: 0.0125
# Epoch 61/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0126
# Epoch 62/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 63/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 64/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 65/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 66/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 67/200
# 499/499 [==============================] - 0s 984us/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 68/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 69/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 70/200
# 499/499 [==============================] - 0s 779us/step - loss: 0.0124 - autoencoder_output_loss: 0.0124
# Epoch 71/200
# 499/499 [==============================] - 0s 820us/step - loss: 0.0124 - autoencoder_output_loss: 0.0124
# Epoch 72/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 73/200
# 499/499 [==============================] - 0s 795us/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 74/200
# 499/499 [==============================] - 0s 789us/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 75/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 76/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 77/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 78/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 79/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 80/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 81/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 82/200
# 499/499 [==============================] - 0s 952us/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 83/200
# 499/499 [==============================] - 0s 978us/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 84/200
# 499/499 [==============================] - 0s 859us/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 85/200
# 499/499 [==============================] - 0s 838us/step - loss: 0.0125 - autoencoder_output_loss: 0.0125
# Epoch 86/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 87/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 88/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 89/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 90/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0124
# Epoch 91/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 92/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 93/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 94/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0122
# Epoch 95/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 96/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 97/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 98/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 99/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 100/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 101/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 102/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 103/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 104/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 105/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 106/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 107/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 108/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 109/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 110/200
# 499/499 [==============================] - 0s 843us/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 111/200
# 499/499 [==============================] - 0s 936us/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 112/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 113/200
# 499/499 [==============================] - 0s 890us/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 114/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 115/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 116/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 117/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0121 - autoencoder_output_loss: 0.0121
# Epoch 118/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0121 - autoencoder_output_loss: 0.0121
# Epoch 119/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 120/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 121/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 122/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 123/200
# 499/499 [==============================] - 0s 880us/step - loss: 0.0121 - autoencoder_output_loss: 0.0121
# Epoch 124/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0121 - autoencoder_output_loss: 0.0121
# Epoch 125/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 126/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0121 - autoencoder_output_loss: 0.0120
# Epoch 127/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0121 - autoencoder_output_loss: 0.0121
# Epoch 128/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 129/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 130/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0121 - autoencoder_output_loss: 0.0121
# Epoch 131/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0121 - autoencoder_output_loss: 0.0120
# Epoch 132/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0121 - autoencoder_output_loss: 0.0121
# Epoch 133/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0121 - autoencoder_output_loss: 0.0120
# Epoch 134/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0120 - autoencoder_output_loss: 0.0120
# Epoch 135/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0136 - autoencoder_output_loss: 0.0135
# Epoch 136/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0127 - autoencoder_output_loss: 0.0127
# Epoch 137/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 138/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0124
# Epoch 139/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0125
# Epoch 140/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 141/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 142/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0124
# Epoch 143/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 144/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0125 - autoencoder_output_loss: 0.0125
# Epoch 145/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 146/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 147/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0124
# Epoch 148/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0124
# Epoch 149/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 150/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 151/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 152/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0122
# Epoch 153/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 154/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 155/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0124 - autoencoder_output_loss: 0.0123
# Epoch 156/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0121
# Epoch 157/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 158/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 159/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 160/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 161/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0123
# Epoch 162/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 163/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 164/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 165/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 166/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 167/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 168/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 169/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 170/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 171/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 172/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 173/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 174/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 175/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 176/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 177/200
# 499/499 [==============================] - 0s 994us/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 178/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 179/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 180/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 181/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 182/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 183/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 184/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 185/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 186/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 187/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 188/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 189/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 190/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 191/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 192/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 193/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 194/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 195/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 196/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 197/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122
# Epoch 198/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0122
# Epoch 199/200
# 499/499 [==============================] - 1s 2ms/step - loss: 0.0122 - autoencoder_output_loss: 0.0121
# Epoch 200/200
# 499/499 [==============================] - 1s 1ms/step - loss: 0.0123 - autoencoder_output_loss: 0.0122

# %%
loss = F_AE_history.history['loss']

epochs = range(epochs_number)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
fina_results=np.array(F_AE.evaluate(x_test,[x_test,x_test]))
# Out:
# 288/288 [==============================] - 0s 533us/step

# %%
fina_results
# Out:
# array([0.01523842, 0.01085357, 0.01515363])

# %%
fina_results_single=np.array(F_AE.evaluate(x_test[0:1],[x_test[0:1],x_test[0:1]]))
# Out:
# 1/1 [==============================] - 0s 4ms/step

# %%
fina_results_single
# Out:
# array([0.02010868, 0.01242357, 0.02001162])

# %%
for i in np.arange(x_test.shape[0]):
    fina_results_i=np.array(F_AE.evaluate(x_test[i:i+1],[x_test[i:i+1],x_test[i:i+1]]))
    write_to_csv(fina_results_i.reshape(1,len(fina_results_i)),"./log/results_"+str(sample_used)+".csv")
# Out:
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 2ms/step
