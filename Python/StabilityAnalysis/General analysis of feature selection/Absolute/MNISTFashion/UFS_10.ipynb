# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K

#tf.set_random_seed(seed)
tf.compat.v1.set_random_seed(seed)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)

K.set_session(sess)
#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
from keras.datasets import fashion_mnist
from keras.models import Model
from keras.layers import Dense, Input, Flatten, Activation, Dropout, Layer
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical
from keras import optimizers,initializers,constraints,regularizers
from keras import backend as K
from keras.callbacks import LambdaCallback,ModelCheckpoint
from keras.utils import plot_model

from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

import h5py
import math
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"./Defined")
import Functions as F

from sklearn.model_selection import train_test_split
import random
import scipy.sparse as sparse
import pandas as pd
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
Training_samples=6000
Testing_samples=4000

(x_train_, y_train_), (x_test_, y_test_) = fashion_mnist.load_data()
x_train = x_train_.reshape(60000, 28*28).astype('float32')[0:Training_samples] / 255.
x_test__ = x_test_.reshape(10000, 28*28).astype('float32') / 255.

np.random.seed(seed)
x_test__num,_=x_test__.shape
index=np.arange(x_test__num)
np.random.shuffle(index)

x_test=x_test__[index][0:Testing_samples]

y_train=y_train_[0:Training_samples]
y_test=y_test_[index][0:Testing_samples]

features=np.r_[x_train,x_test]
labels=np.r_[y_train,y_test]

print(features.shape,labels.shape)
# Out:
# (10000, 784) (10000,)

# %% [markdown]
# # 3.Model

# %%
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
rn.seed(seed)
tf.compat.v1.set_random_seed(seed)

#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe


#--------------------------------------------------------------------------------------------------------------------------------
def top_k_keepWeights_1(p_arr_,p_top_k_,p_ignore_equal=True):
    top_k_idx=p_arr_.argsort()[::-1][0:p_top_k_]
    top_k_value=p_arr_[top_k_idx]
    if np.sum(p_arr_>0)>p_top_k_:
        if p_ignore_equal:
            p_arr_=np.where(p_arr_<top_k_value[-1],0,1)
        else:
            p_arr_=np.where(p_arr_<=top_k_value[-1],0,1)
    else:
        p_arr_=np.where(p_arr_<=0,0,1) 
    return p_arr_


#--------------------------------------------------------------------------------------------------------------------------------
class Feature_Select_Layer(Layer):
    
    def __init__(self, output_dim, **kwargs):
        super(Feature_Select_Layer, self).__init__(**kwargs)
        self.output_dim = output_dim

    def build(self, input_shape):
        self.kernel = self.add_weight(name='kernel',  
                                      shape=(input_shape[1],),
                                      initializer=initializers.RandomUniform(minval=0.999999, maxval=0.9999999, seed=seed),
                                      trainable=True)
        super(Feature_Select_Layer, self).build(input_shape)
    
    def call(self, x, selection=False,k=50):
        kernel=K.abs(self.kernel)        
        if selection:
            kernel_=K.transpose(kernel)
            kth_largest = tf.math.top_k(kernel_, k=k)[0][-1]
            kernel = tf.where(condition=K.less(kernel,kth_largest),x=K.zeros_like(kernel),y=kernel)        
        return K.dot(x, tf.linalg.tensor_diag(kernel))

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

#--------------------------------------------------------------------------------------------------------------------------------
def Fractal_Autoencoder(p_data_feature,\
                        p_feture_number,\
                        p_encoding_dim,\
                        p_learning_rate,\
                        p_loss_weight_1,\
                        p_loss_weight_2,\
                        p_batch_size,\
                        p_epochs,\
                        p_seed_i):
    
    input_img = Input(shape=(p_data_feature,), name='autoencoder_input')

    feature_selection = Feature_Select_Layer(output_dim=p_data_feature,\
                                             input_shape=(p_data_feature,),\
                                             name='feature_selection')

    feature_selection_score=feature_selection(input_img)
    feature_selection_choose=feature_selection(input_img,selection=True,k=p_feture_number)

    encoded = Dense(p_encoding_dim,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_hidden_layer')
    
    encoded_score=encoded(feature_selection_score)
    encoded_choose=encoded(feature_selection_choose)
    
    bottleneck_score=encoded_score
    bottleneck_choose=encoded_choose
    
    decoded = Dense(p_data_feature,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_output')
    
    decoded_score =decoded(bottleneck_score)
    decoded_choose =decoded(bottleneck_choose)

    latent_encoder_score = Model(input_img, bottleneck_score)
    latent_encoder_choose = Model(input_img, bottleneck_choose)
    feature_selection_output=Model(input_img,feature_selection_choose)
    autoencoder = Model(input_img, [decoded_score,decoded_choose])
    
    autoencoder.compile(loss=['mean_squared_error','mean_squared_error'],\
                        loss_weights=[p_loss_weight_1, p_loss_weight_2],\
                        optimizer=optimizers.Adam(lr=p_learning_rate))
    
    print('Autoencoder Structure-------------------------------------')
    autoencoder.summary()
    
    callback_ES = tf.keras.callbacks.EarlyStopping(monitor='autoencoder_output_loss', patience=20)
    
    x_train_s,x_test_s,_,_= train_test_split(features,labels,test_size=0.1,random_state=p_seed_i)

    print('Train', x_train_s.shape)
    print('Test', x_test_s.shape)
    
    model_history=autoencoder.fit(x_train_s,[x_train_s,x_train_s],batch_size=p_batch_size,epochs=p_epochs,verbose=1,callbacks=[callback_ES])

    #--------------------------Key features display--------------------------------------------------------------
    key_features=top_k_keepWeights_1(autoencoder.get_layer(index=1).get_weights()[0],p_feture_number)
    
    return key_features

# %% [markdown]
# ## 3.1 Structure and paramter testing

# %%
epochs_number=200
batch_size_value=256

# %% [markdown]
# ---
# ### 3.1.1 Fractal Autoencoder
# ---

# %%
loss_weight_1=0.0078125
key_feture_number=10
number_seed=50

for p_seed_i in np.arange(number_seed):
    key_features_vector=Fractal_Autoencoder(p_data_feature=784,\
                                            p_feture_number=key_feture_number,\
                                            p_encoding_dim=key_feture_number,\
                                            p_learning_rate= 1E-3,\
                                            p_loss_weight_1=loss_weight_1,\
                                            p_loss_weight_2=1,\
                                            p_batch_size=batch_size_value,\
                                            p_epochs=epochs_number,\
                                            p_seed_i=p_seed_i)
    
    write_to_csv(key_features_vector.reshape(1,len(key_features_vector)),"./log/key_features"+str(key_feture_number)+".csv")
# Out:
# WARNING:tensorflow:From /home/xinxingwu/venv3.7.8/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From <ipython-input-3-e479d7094945>:46: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Autoencoder Structure-------------------------------------
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# autoencoder_input (InputLayer)  (None, 784)          0
# __________________________________________________________________________________________________
# feature_selection (Feature_Sele (None, 784)          784         autoencoder_input[0][0]
#                                                                  autoencoder_input[0][0]
# __________________________________________________________________________________________________
# autoencoder_hidden_layer (Dense (None, 10)           7850        feature_selection[0][0]
#                                                                  feature_selection[1][0]
# __________________________________________________________________________________________________
# autoencoder_output (Dense)      (None, 784)          8624        autoencoder_hidden_layer[0][0]
#                                                                  autoencoder_hidden_layer[1][0]
# ==================================================================================================
# Total params: 17,258
# Trainable params: 17,258
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train (9000, 784)
# Test (1000, 784)
# WARNING:tensorflow:From /home/xinxingwu/venv3.7.8/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/200
# 9000/9000 [==============================] - 4s 429us/step - loss: 0.1825 - autoencoder_output_loss: 0.1804
# Epoch 2/200
# 9000/9000 [==============================] - 3s 287us/step - loss: 0.1062 - autoencoder_output_loss: 0.1047
# Epoch 3/200
# 9000/9000 [==============================] - 3s 285us/step - loss: 0.0719 - autoencoder_output_loss: 0.0714
# Epoch 4/200
# 9000/9000 [==============================] - 3s 299us/step - loss: 0.0686 - autoencoder_output_loss: 0.0682
# Epoch 5/200
# 9000/9000 [==============================] - 3s 294us/step - loss: 0.0671 - autoencoder_output_loss: 0.0666
# Epoch 6/200
# 9000/9000 [==============================] - 2s 267us/step - loss: 0.0652 - autoencoder_output_loss: 0.0647
# Epoch 7/200
# 9000/9000 [==============================] - 3s 375us/step - loss: 0.0625 - autoencoder_output_loss: 0.0620
# Epoch 8/200
# 9000/9000 [==============================] - 3s 297us/step - loss: 0.0594 - autoencoder_output_loss: 0.0589
# Epoch 9/200
# 9000/9000 [==============================] - 3s 300us/step - loss: 0.0566 - autoencoder_output_loss: 0.0563
# Epoch 10/200
# 9000/9000 [==============================] - 3s 306us/step - loss: 0.0545 - autoencoder_output_loss: 0.0543
# Epoch 11/200
# 9000/9000 [==============================] - 3s 294us/step - loss: 0.0530 - autoencoder_output_loss: 0.0526
# Epoch 12/200
# 9000/9000 [==============================] - 3s 325us/step - loss: 0.0517 - autoencoder_output_loss: 0.0513
# Epoch 13/200
# 9000/9000 [==============================] - 2s 258us/step - loss: 0.0507 - autoencoder_output_loss: 0.0502
# Epoch 14/200
# 9000/9000 [==============================] - 3s 300us/step - loss: 0.0499 - autoencoder_output_loss: 0.0496
# Epoch 15/200
# 9000/9000 [==============================] - 3s 298us/step - loss: 0.0492 - autoencoder_output_loss: 0.0489
# Epoch 16/200
# 9000/9000 [==============================] - 2s 267us/step - loss: 0.0487 - autoencoder_output_loss: 0.0484
# Epoch 17/200
# 9000/9000 [==============================] - 4s 391us/step - loss: 0.0483 - autoencoder_output_loss: 0.0479
# Epoch 18/200
/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 109/200
# 9000/9000 [==============================] - 3s 286us/step - loss: 0.0428 - autoencoder_output_loss: 0.0427
# Epoch 110/200
# 9000/9000 [==============================] - 3s 333us/step - loss: 0.0428 - autoencoder_output_loss: 0.0427
# Epoch 111/200
# 9000/9000 [==============================] - 3s 278us/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 112/200
# 9000/9000 [==============================] - 2s 277us/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 113/200
# 9000/9000 [==============================] - 2s 260us/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 114/200
# 9000/9000 [==============================] - 2s 240us/step - loss: 0.0428 - autoencoder_output_loss: 0.0424
# Epoch 115/200
# 9000/9000 [==============================] - 2s 228us/step - loss: 0.0428 - autoencoder_output_loss: 0.0424
# Epoch 116/200
# 9000/9000 [==============================] - 2s 223us/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 117/200
# 9000/9000 [==============================] - 2s 258us/step - loss: 0.0428 - autoencoder_output_loss: 0.0427
# Epoch 118/200
# 9000/9000 [==============================] - 3s 280us/step - loss: 0.0428 - autoencoder_output_loss: 0.0426
# Epoch 119/200
# 9000/9000 [==============================] - 3s 320us/step - loss: 0.0428 - autoencoder_output_loss: 0.0426
# Epoch 120/200
# 9000/9000 [==============================] - 3s 311us/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 121/200
# 9000/9000 [==============================] - 3s 295us/step - loss: 0.0428 - autoencoder_output_loss: 0.0426
# Epoch 122/200
# 9000/9000 [==============================] - 3s 282us/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 123/200
# 9000/9000 [==============================] - 3s 380us/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 124/200
# 9000/9000 [==============================] - 3s 348us/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 125/200
# 9000/9000 [==============================] - 3s 295us/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 126/200
# 9000/9000 [==============================] - 3s 301us/step - loss: 0.0428 - autoencoder_output_loss: 0.0426
# Epoch 127/200
# 9000/9000 [==============================] - 3s 309us/step - loss: 0.0428 - autoencoder_output_loss: 0.0426
# Epoch 128/200
# 9000/9000 [==============================] - 3s 325us/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 129/200
# 9000/9000 [==============================] - 3s 295us/step - loss: 0.0428 - autoencoder_output_loss: 0.0426
# Epoch 130/200
# 9000/9000 [==============================] - 3s 373us/step - loss: 0.0428 - autoencoder_output_loss: 0.0425
# Epoch 131/200
# 9000/9000 [==============================] - 3s 335us/step - loss: 0.0428 - autoencoder_output_loss: 0.0427
# Epoch 132/200
# 9000/9000 [==============================] - 3s 307us/step - loss: 0.0428 - autoencoder_output_loss: 0.0426
# Epoch 133/200
# 9000/9000 [==============================] - 3s 304us/step - loss: 0.0428 - autoencoder_output_loss: 0.0427
# Epoch 134/200
# 9000/9000 [==============================] - 3s 330us/step - loss: 0.0428 - autoencoder_output_loss: 0.0428
# Epoch 135/200
# 9000/9000 [==============================] - 3s 319us/step - loss: 0.0428 - autoencoder_output_loss: 0.0427
# Autoencoder Structure-------------------------------------
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# autoencoder_input (InputLayer)  (None, 784)          0
# __________________________________________________________________________________________________
# feature_selection (Feature_Sele (None, 784)          784         autoencoder_input[0][0]
#                                                                  autoencoder_input[0][0]
# __________________________________________________________________________________________________
# autoencoder_hidden_layer (Dense (None, 10)           7850        feature_selection[0][0]
#                                                                  feature_selection[1][0]
# __________________________________________________________________________________________________
# autoencoder_output (Dense)      (None, 784)          8624        autoencoder_hidden_layer[0][0]
#                                                                  autoencoder_hidden_layer[1][0]
# ==================================================================================================
# Total params: 17,258
# Trainable params: 17,258
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 107/200
# 9000/9000 [==============================] - 3s 314us/step - loss: 0.0434 - autoencoder_output_loss: 0.0430
# Epoch 108/200
# 9000/9000 [==============================] - 3s 316us/step - loss: 0.0434 - autoencoder_output_loss: 0.0431
# Epoch 109/200
# 9000/9000 [==============================] - 2s 255us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 110/200
# 9000/9000 [==============================] - 2s 245us/step - loss: 0.0433 - autoencoder_output_loss: 0.0433
# Epoch 111/200
# 9000/9000 [==============================] - 2s 242us/step - loss: 0.0433 - autoencoder_output_loss: 0.0433
# Epoch 112/200
# 9000/9000 [==============================] - 2s 274us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 113/200
# 9000/9000 [==============================] - 2s 249us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 114/200
# 9000/9000 [==============================] - 3s 305us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 115/200
# 9000/9000 [==============================] - 3s 327us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 116/200
# 9000/9000 [==============================] - 3s 297us/step - loss: 0.0434 - autoencoder_output_loss: 0.0430
# Epoch 117/200
# 9000/9000 [==============================] - 3s 291us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 118/200
# 9000/9000 [==============================] - 3s 302us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 119/200
# 9000/9000 [==============================] - 3s 309us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 120/200
# 9000/9000 [==============================] - 2s 272us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 121/200
# 9000/9000 [==============================] - 2s 259us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 122/200
# 9000/9000 [==============================] - 3s 294us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 123/200
# 9000/9000 [==============================] - 3s 367us/step - loss: 0.0434 - autoencoder_output_loss: 0.0430
# Epoch 124/200
# 9000/9000 [==============================] - 3s 289us/step - loss: 0.0433 - autoencoder_output_loss: 0.0432
# Epoch 125/200
# 9000/9000 [==============================] - 3s 356us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 126/200
# 9000/9000 [==============================] - 3s 319us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 127/200
# 9000/9000 [==============================] - 3s 320us/step - loss: 0.0433 - autoencoder_output_loss: 0.0432
# Epoch 128/200
# 9000/9000 [==============================] - 2s 270us/step - loss: 0.0433 - autoencoder_output_loss: 0.0429
# Epoch 129/200
# 9000/9000 [==============================] - 4s 407us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 130/200
# 9000/9000 [==============================] - 3s 373us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 131/200
# 9000/9000 [==============================] - 2s 275us/step - loss: 0.0434 - autoencoder_output_loss: 0.0432
# Epoch 132/200
# 9000/9000 [==============================] - 3s 297us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 133/200
# 9000/9000 [==============================] - 3s 302us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 134/200
# 9000/9000 [==============================] - 3s 312us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 135/200
# 9000/9000 [==============================] - 3s 348us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 136/200
# 9000/9000 [==============================] - 3s 317us/step - loss: 0.0433 - autoencoder_output_loss: 0.0432
# Epoch 137/200
# 9000/9000 [==============================] - 3s 321us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 138/200
# 9000/9000 [==============================] - 3s 354us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 139/200
# 9000/9000 [==============================] - 3s 337us/step - loss: 0.0433 - autoencoder_output_loss: 0.0432
# Epoch 140/200
# 9000/9000 [==============================] - 3s 312us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 141/200
# 9000/9000 [==============================] - 2s 269us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 142/200
# 9000/9000 [==============================] - 3s 310us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 143/200
# 9000/9000 [==============================] - 3s 309us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 144/200
# 9000/9000 [==============================] - 2s 272us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 145/200
# 9000/9000 [==============================] - 2s 216us/step - loss: 0.0433 - autoencoder_output_loss: 0.0432
# Epoch 146/200
# 9000/9000 [==============================] - 2s 234us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 147/200
# 9000/9000 [==============================] - 2s 259us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 148/200
# 9000/9000 [==============================] - 2s 242us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Autoencoder Structure-------------------------------------
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# autoencoder_input (InputLayer)  (None, 784)          0
# __________________________________________________________________________________________________
# feature_selection (Feature_Sele (None, 784)          784         autoencoder_input[0][0]
#                                                                  autoencoder_input[0][0]
# __________________________________________________________________________________________________
# autoencoder_hidden_layer (Dense (None, 10)           7850        feature_selection[0][0]
#                                                                  feature_selection[1][0]
# __________________________________________________________________________________________________
# autoencoder_output (Dense)      (None, 784)          8624        autoencoder_hidden_layer[0][0]
#                                                                  autoencoder_hidden_layer[1][0]
# ==================================================================================================
# Total params: 17,258
# Trainable params: 17,258
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train (9000, 784)
# Test (1000, 784)
# Epoch 1/200
# 9000/9000 [==============================] - 3s 370us/step - loss: 0.1826 - autoencoder_output_loss: 0.1812
# Epoch 2/200
# 9000/9000 [==============================] - 3s 319us/step - loss: 0.1063 - autoencoder_output_loss: 0.1050
# Epoch 3/200
# 9000/9000 [==============================] - 3s 290us/step - loss: 0.0721 - autoencoder_output_loss: 0.0716
# Epoch 4/200
# 9000/9000 [==============================] - 3s 299us/step - loss: 0.0689 - autoencoder_output_loss: 0.0684
# Epoch 5/200
# 9000/9000 [==============================] - 3s 302us/step - loss: 0.0673 - autoencoder_output_loss: 0.0667
# Epoch 6/200
# 9000/9000 [==============================] - 2s 266us/step - loss: 0.0653 - autoencoder_output_loss: 0.0648
# Epoch 7/200
# 9000/9000 [==============================] - 3s 310us/step - loss: 0.0626 - autoencoder_output_loss: 0.0621
# Epoch 8/200
# 9000/9000 [==============================] - 2s 257us/step - loss: 0.0595 - autoencoder_output_loss: 0.0589
# Epoch 9/200
# 9000/9000 [==============================] - 2s 277us/step - loss: 0.0567 - autoencoder_output_loss: 0.0563
# Epoch 10/200
# 9000/9000 [==============================] - 3s 292us/step - loss: 0.0546 - autoencoder_output_loss: 0.0541
# Epoch 11/200
# 9000/9000 [==============================] - 3s 344us/step - loss: 0.0531 - autoencoder_output_loss: 0.0528
# Epoch 12/200
# 9000/9000 [==============================] - 3s 320us/step - loss: 0.0518 - autoencoder_output_loss: 0.0514
# Epoch 13/200
# 9000/9000 [==============================] - 3s 295us/step - loss: 0.0508 - autoencoder_output_loss: 0.0504
# Epoch 14/200
# 9000/9000 [==============================] - 3s 284us/step - loss: 0.0500 - autoencoder_output_loss: 0.0497
# Epoch 15/200
# Epoch 41/200
# 9000/9000 [==============================] - 3s 309us/step - loss: 0.0439 - autoencoder_output_loss: 0.0436
# Epoch 42/200
# 9000/9000 [==============================] - 3s 314us/step - loss: 0.0438 - autoencoder_output_loss: 0.0435
# Epoch 43/200
# 9000/9000 [==============================] - 2s 265us/step - loss: 0.0438 - autoencoder_output_loss: 0.0435
# Epoch 44/200
# 9000/9000 [==============================] - 3s 299us/step - loss: 0.0437 - autoencoder_output_loss: 0.0434
# Epoch 45/200
# 9000/9000 [==============================] - 3s 281us/step - loss: 0.0437 - autoencoder_output_loss: 0.0435 2s - loss: 0.0441 -
# Epoch 46/200
# 9000/9000 [==============================] - 3s 283us/step - loss: 0.0437 - autoencoder_output_loss: 0.0435
# Epoch 47/200
# 9000/9000 [==============================] - 3s 315us/step - loss: 0.0436 - autoencoder_output_loss: 0.0433
# Epoch 48/200
# 9000/9000 [==============================] - 3s 379us/step - loss: 0.0436 - autoencoder_output_loss: 0.0433
# Epoch 49/200
# 9000/9000 [==============================] - 5s 524us/step - loss: 0.0436 - autoencoder_output_loss: 0.0434
# Epoch 50/200
# 9000/9000 [==============================] - 3s 282us/step - loss: 0.0435 - autoencoder_output_loss: 0.0430
# Epoch 51/200
# 9000/9000 [==============================] - 3s 321us/step - loss: 0.0435 - autoencoder_output_loss: 0.0431
# Epoch 52/200
# 9000/9000 [==============================] - 3s 303us/step - loss: 0.0435 - autoencoder_output_loss: 0.0433
# Epoch 53/200
# 9000/9000 [==============================] - 3s 314us/step - loss: 0.0434 - autoencoder_output_loss: 0.0432
# Epoch 54/200
# 9000/9000 [==============================] - 3s 330us/step - loss: 0.0434 - autoencoder_output_loss: 0.0431
# Epoch 55/200
# 9000/9000 [==============================] - 3s 286us/step - loss: 0.0434 - autoencoder_output_loss: 0.0432 0s - loss: 0.0431 - autoencoder_output_lo
# Epoch 56/200
# 9000/9000 [==============================] - 2s 243us/step - loss: 0.0433 - autoencoder_output_loss: 0.0431
# Epoch 57/200
# 9000/9000 [==============================] - 3s 346us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 58/200
# 9000/9000 [==============================] - 3s 331us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 59/200
# 9000/9000 [==============================] - 3s 287us/step - loss: 0.0433 - autoencoder_output_loss: 0.0430
# Epoch 60/200
# 9000/9000 [==============================] - 3s 340us/step - loss: 0.0432 - autoencoder_output_loss: 0.0429
# Epoch 61/200
# 9000/9000 [==============================] - 3s 281us/step - loss: 0.0432 - autoencoder_output_loss: 0.0431
# Epoch 62/200
# 9000/9000 [==============================] - 3s 298us/step - loss: 0.0432 - autoencoder_output_loss: 0.0431
# Epoch 63/200
# 9000/9000 [==============================] - 3s 284us/step - loss: 0.0432 - autoencoder_output_loss: 0.0430
# Epoch 64/200
# 9000/9000 [==============================] - 3s 297us/step - loss: 0.0432 - autoencoder_output_loss: 0.0429
# Epoch 65/200
# 4096/9000 [============>.................] - ETA: 1s - loss: 0.0438 - autoencoder_output_loss: 0.0436
