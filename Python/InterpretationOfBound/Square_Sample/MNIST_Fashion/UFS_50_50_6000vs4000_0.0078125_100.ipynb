# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K

#tf.set_random_seed(seed)
tf.compat.v1.set_random_seed(seed)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)

K.set_session(sess)
#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
from keras.datasets import fashion_mnist
from keras.models import Model
from keras.layers import Dense, Input, Flatten, Activation, Dropout, Layer
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical
from keras import optimizers,initializers,constraints,regularizers
from keras import backend as K
from keras.callbacks import LambdaCallback,ModelCheckpoint
from keras.utils import plot_model

from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

import h5py
import math
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"./Defined")
import Functions as F

# The following code should be added before the keras model
#np.random.seed(seed)
# Out:
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
percentage=10
Training_samples=540*percentage
Validating_samples=60*percentage
Testing_samples=4000

(x_train_, y_train_), (x_test_, y_test_) = fashion_mnist.load_data()
x_train = x_train_.reshape(60000, 28*28).astype('float32')[0:Training_samples] / 255.
x_validate = x_train_.reshape(60000, 28*28).astype('float32')[Training_samples:Training_samples+Validating_samples] / 255.
x_test__ = x_test_.reshape(10000, 28*28).astype('float32') / 255.

np.random.seed(seed)
x_test__num,_=x_test__.shape
index=np.arange(x_test__num)
np.random.shuffle(index)

x_test=x_test__[index][0:Testing_samples]

y_train=y_train_[0:Training_samples]
y_validate=y_train_[Training_samples:Training_samples+Validating_samples]
y_test=y_test_[index][0:Testing_samples]

y_train_onehot_ = np.array(y_train)
y_validate_onehot_ = np.array(y_validate)
y_test_onehot_ = np.array(y_test)

C_train_x=x_train_.reshape(60000, 28*28).astype('float32')[0:Training_samples+Validating_samples] / 255.
C_train_y=y_train_[0:Training_samples+Validating_samples]
C_test_x=x_test
C_test_y=np.array(y_test)

y_train_onehot = to_categorical(y_train_onehot_)
y_validate_onehot = to_categorical(y_validate_onehot_)
y_test_onehot = to_categorical(y_test_onehot_)

print('Shape of x_train: ' + str(x_train.shape)) 
print('Shape of x_validate: ' + str(x_validate.shape)) 
print('Shape of x_test: ' + str(x_test.shape))
print('Shape of y_train: ' + str(y_train_onehot.shape))
print('Shape of y_validate: ' + str(y_validate_onehot.shape))
print('Shape of y_test: ' + str(y_test_onehot.shape))

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape)) 
#F.show_data_figures(x_train_[0:120],28,28,40)
# Out:
# Shape of x_train: (5400, 784)
# Shape of x_validate: (600, 784)
# Shape of x_test: (4000, 784)
# Shape of y_train: (5400, 10)
# Shape of y_validate: (600, 10)
# Shape of y_test: (4000, 10)
# Shape of C_train_x: (6000, 784)
# Shape of C_train_y: (6000,)
# Shape of C_test_x: (4000, 784)
# Shape of C_test_y: (4000,)

# %%
key_feture_number=50

# %% [markdown]
# # 3.Model

# %%
np.random.seed(seed)

#--------------------------------------------------------------------------------------------------------------------------------
class Feature_Select_Layer(Layer):
    
    def __init__(self, output_dim, **kwargs):
        super(Feature_Select_Layer, self).__init__(**kwargs)
        self.output_dim = output_dim

    def build(self, input_shape):
        self.kernel = self.add_weight(name='kernel',  
                                      shape=(input_shape[1],),
                                      initializer=initializers.RandomUniform(minval=0.999999, maxval=0.9999999, seed=seed),
                                      trainable=True)
        super(Feature_Select_Layer, self).build(input_shape)
    
    def call(self, x, selection=False,k=key_feture_number):
        kernel=K.pow(self.kernel,2)         
        if selection:
            kernel_=K.transpose(kernel)
            kth_largest = tf.math.top_k(kernel_, k=k)[0][-1]
            kernel = tf.where(condition=K.less(kernel,kth_largest),x=K.zeros_like(kernel),y=kernel)        
        return K.dot(x, tf.linalg.tensor_diag(kernel))

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

#--------------------------------------------------------------------------------------------------------------------------------
def Autoencoder(p_data_feature=x_train.shape[1],\
                p_encoding_dim=key_feture_number,\
                p_learning_rate= 1E-3):
    input_img = Input(shape=(p_data_feature,), name='input_img')

    encoded = Dense(p_encoding_dim, activation='linear',kernel_initializer=initializers.glorot_uniform(seed))(input_img)
    bottleneck=encoded
    decoded = Dense(p_data_feature, activation='linear',kernel_initializer=initializers.glorot_uniform(seed))(encoded)

    latent_encoder = Model(input_img, bottleneck)
    autoencoder = Model(input_img, decoded)
    
    autoencoder.compile(loss='mean_squared_error', optimizer=optimizers.Adam(lr=p_learning_rate))
    
    print('Autoencoder Structure-------------------------------------')
    autoencoder.summary()
    #print('Latent Encoder Structure-------------------------------------')
    #latent_encoder.summary()
    return autoencoder,latent_encoder

#--------------------------------------------------------------------------------------------------------------------------------
def Identity_Autoencoder(p_data_feature=x_train.shape[1],\
                         p_encoding_dim=key_feture_number,\
                         p_learning_rate= 1E-3):
    
    input_img = Input(shape=(p_data_feature,), name='autoencoder_input')

    feature_selection = Feature_Select_Layer(output_dim=p_data_feature,\
                                             input_shape=(p_data_feature,),\
                                             name='feature_selection')

    feature_selection_score=feature_selection(input_img)

    encoded = Dense(p_encoding_dim,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_hidden_layer')
    
    encoded_score=encoded(feature_selection_score)
    
    bottleneck_score=encoded_score
    
    decoded = Dense(p_data_feature,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_output')
    
    decoded_score =decoded(bottleneck_score)

    latent_encoder_score = Model(input_img, bottleneck_score)
    autoencoder = Model(input_img, decoded_score)
    
    autoencoder.compile(loss='mean_squared_error',\
                        optimizer=optimizers.Adam(lr=p_learning_rate))
    
    print('Autoencoder Structure-------------------------------------')
    autoencoder.summary()
    return autoencoder,latent_encoder_score

#--------------------------------------------------------------------------------------------------------------------------------
def Fractal_Autoencoder(p_data_feature=x_train.shape[1],\
                        p_feture_number=key_feture_number,\
                        p_encoding_dim=key_feture_number,\
                        p_learning_rate=1E-3,\
                        p_loss_weight_1=1,\
                        p_loss_weight_2=2):
    
    input_img = Input(shape=(p_data_feature,), name='autoencoder_input')

    feature_selection = Feature_Select_Layer(output_dim=p_data_feature,\
                                             input_shape=(p_data_feature,),\
                                             name='feature_selection')

    feature_selection_score=feature_selection(input_img)
    feature_selection_choose=feature_selection(input_img,selection=True,k=p_feture_number)

    encoded = Dense(p_encoding_dim,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_hidden_layer')
    
    encoded_score=encoded(feature_selection_score)
    encoded_choose=encoded(feature_selection_choose)
    
    bottleneck_score=encoded_score
    bottleneck_choose=encoded_choose
    
    decoded = Dense(p_data_feature,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_output')
    
    decoded_score =decoded(bottleneck_score)
    decoded_choose =decoded(bottleneck_choose)

    latent_encoder_score = Model(input_img, bottleneck_score)
    latent_encoder_choose = Model(input_img, bottleneck_choose)
    feature_selection_output=Model(input_img,feature_selection_choose)
    autoencoder = Model(input_img, [decoded_score,decoded_choose])
    
    autoencoder.compile(loss=['mean_squared_error','mean_squared_error'],\
                        loss_weights=[p_loss_weight_1, p_loss_weight_2],\
                        optimizer=optimizers.Adam(lr=p_learning_rate))
    
    print('Autoencoder Structure-------------------------------------')
    autoencoder.summary()
    return autoencoder,feature_selection_output,latent_encoder_score,latent_encoder_choose

# %% [markdown]
# ## 3.1 Structure and paramter testing

# %%
epochs_number=200
batch_size_value=256

# %% [markdown]
# ---
# ### 3.1.1 Fractal Autoencoder
# ---

# %%
loss_weight_1=0.0078125
F_AE,\
feature_selection_output,\
latent_encoder_score_F_AE,\
latent_encoder_choose_F_AE=Fractal_Autoencoder(p_data_feature=x_train.shape[1],\
                                               p_feture_number=key_feture_number,\
                                               p_encoding_dim=key_feture_number,\
                                               p_learning_rate= 1E-3,\
                                               p_loss_weight_1=loss_weight_1,\
                                               p_loss_weight_2=1)

file_name="./log/F_AE_"+str(key_feture_number)+".png"
plot_model(F_AE, to_file=file_name,show_shapes=True)
# Out:
# WARNING:tensorflow:From <ipython-input-4-e40d19161955>:22: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Autoencoder Structure-------------------------------------
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# autoencoder_input (InputLayer)  (None, 784)          0
# __________________________________________________________________________________________________
# feature_selection (Feature_Sele (None, 784)          784         autoencoder_input[0][0]
#                                                                  autoencoder_input[0][0]
# __________________________________________________________________________________________________
# autoencoder_hidden_layer (Dense (None, 50)           39250       feature_selection[0][0]
#                                                                  feature_selection[1][0]
# __________________________________________________________________________________________________
# autoencoder_output (Dense)      (None, 784)          39984       autoencoder_hidden_layer[0][0]
#                                                                  autoencoder_hidden_layer[1][0]
# ==================================================================================================
# Total params: 80,018
# Trainable params: 80,018
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_checkpoint=ModelCheckpoint('./log_weights/F_AE_'+str(key_feture_number)+'_weights_'+str(loss_weight_1)+'.MNIST{epoch:04d}.hdf5',period=100,save_weights_only=True,verbose=1)
#print_weights = LambdaCallback(on_epoch_end=lambda batch, logs: print(F_AE.layers[1].get_weights()))

F_AE_history = F_AE.fit(x_train, [x_train,x_train],\
                        epochs=epochs_number,\
                        batch_size=batch_size_value,\
                        shuffle=True,\
                        validation_data=(x_validate, [x_validate,x_validate]),\
                        callbacks=[model_checkpoint])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 5400 samples, validate on 600 samples
# Epoch 1/200
# 5400/5400 [==============================] - 1s 246us/step - loss: 0.1531 - autoencoder_output_loss: 0.1489 - val_loss: 0.0776 - val_autoencoder_output_loss: 0.0773
# Epoch 2/200
# 5400/5400 [==============================] - 1s 172us/step - loss: 0.0713 - autoencoder_output_loss: 0.0699 - val_loss: 0.0615 - val_autoencoder_output_loss: 0.0612
# Epoch 3/200
# 5400/5400 [==============================] - 1s 177us/step - loss: 0.0597 - autoencoder_output_loss: 0.0589 - val_loss: 0.0515 - val_autoencoder_output_loss: 0.0513
# Epoch 4/200
# 5400/5400 [==============================] - 1s 170us/step - loss: 0.0506 - autoencoder_output_loss: 0.0499 - val_loss: 0.0454 - val_autoencoder_output_loss: 0.0453
# Epoch 5/200
# 5400/5400 [==============================] - 1s 169us/step - loss: 0.0461 - autoencoder_output_loss: 0.0456 - val_loss: 0.0420 - val_autoencoder_output_loss: 0.0419
# Epoch 6/200
# 5400/5400 [==============================] - 1s 169us/step - loss: 0.0427 - autoencoder_output_loss: 0.0421 - val_loss: 0.0391 - val_autoencoder_output_loss: 0.0391
# Epoch 7/200
# 5400/5400 [==============================] - 1s 177us/step - loss: 0.0398 - autoencoder_output_loss: 0.0396 - val_loss: 0.0367 - val_autoencoder_output_loss: 0.0367
# Epoch 8/200
# 5400/5400 [==============================] - 1s 165us/step - loss: 0.0375 - autoencoder_output_loss: 0.0370 - val_loss: 0.0347 - val_autoencoder_output_loss: 0.0347
# Epoch 9/200
# 5400/5400 [==============================] - 1s 184us/step - loss: 0.0354 - autoencoder_output_loss: 0.0348 - val_loss: 0.0330 - val_autoencoder_output_loss: 0.0330
# Epoch 10/200
# 5400/5400 [==============================] - 1s 172us/step - loss: 0.0337 - autoencoder_output_loss: 0.0334 - val_loss: 0.0316 - val_autoencoder_output_loss: 0.0316
# Epoch 11/200
# 5400/5400 [==============================] - 1s 172us/step - loss: 0.0323 - autoencoder_output_loss: 0.0321 - val_loss: 0.0306 - val_autoencoder_output_loss: 0.0305
# Epoch 12/200
# 5400/5400 [==============================] - 1s 176us/step - loss: 0.0313 - autoencoder_output_loss: 0.0308 - val_loss: 0.0298 - val_autoencoder_output_loss: 0.0297
# Epoch 13/200
# 5400/5400 [==============================] - 1s 179us/step - loss: 0.0305 - autoencoder_output_loss: 0.0306 - val_loss: 0.0292 - val_autoencoder_output_loss: 0.0291
# Epoch 14/200
# 5400/5400 [==============================] - 1s 170us/step - loss: 0.0300 - autoencoder_output_loss: 0.0296 - val_loss: 0.0286 - val_autoencoder_output_loss: 0.0286
# Epoch 15/200
# 5400/5400 [==============================] - 1s 178us/step - loss: 0.0293 - autoencoder_output_loss: 0.0290 - val_loss: 0.0282 - val_autoencoder_output_loss: 0.0281
# Epoch 16/200
# 5400/5400 [==============================] - 1s 183us/step - loss: 0.0289 - autoencoder_output_loss: 0.0286 - val_loss: 0.0278 - val_autoencoder_output_loss: 0.0277
# Epoch 17/200
# 5400/5400 [==============================] - 1s 175us/step - loss: 0.0285 - autoencoder_output_loss: 0.0282 - val_loss: 0.0275 - val_autoencoder_output_loss: 0.0274
# Epoch 18/200
# 5400/5400 [==============================] - 1s 169us/step - loss: 0.0281 - autoencoder_output_loss: 0.0277 - val_loss: 0.0272 - val_autoencoder_output_loss: 0.0270
# Epoch 19/200
# 5400/5400 [==============================] - 1s 178us/step - loss: 0.0277 - autoencoder_output_loss: 0.0275 - val_loss: 0.0269 - val_autoencoder_output_loss: 0.0267
# Epoch 20/200
# 5400/5400 [==============================] - 1s 188us/step - loss: 0.0274 - autoencoder_output_loss: 0.0273 - val_loss: 0.0266 - val_autoencoder_output_loss: 0.0265
# Epoch 21/200
# 5400/5400 [==============================] - 1s 186us/step - loss: 0.0271 - autoencoder_output_loss: 0.0267 - val_loss: 0.0263 - val_autoencoder_output_loss: 0.0262
# Epoch 22/200
# 5400/5400 [==============================] - 1s 180us/step - loss: 0.0268 - autoencoder_output_loss: 0.0268 - val_loss: 0.0261 - val_autoencoder_output_loss: 0.0259
# Epoch 23/200
# 5400/5400 [==============================] - 1s 179us/step - loss: 0.0265 - autoencoder_output_loss: 0.0263 - val_loss: 0.0259 - val_autoencoder_output_loss: 0.0257
# Epoch 24/200
# 5400/5400 [==============================] - 1s 174us/step - loss: 0.0263 - autoencoder_output_loss: 0.0260 - val_loss: 0.0257 - val_autoencoder_output_loss: 0.0256
# Epoch 25/200
# 5400/5400 [==============================] - 1s 170us/step - loss: 0.0262 - autoencoder_output_loss: 0.0261 - val_loss: 0.0255 - val_autoencoder_output_loss: 0.0254
# Epoch 26/200
# 5400/5400 [==============================] - 1s 178us/step - loss: 0.0259 - autoencoder_output_loss: 0.0256 - val_loss: 0.0253 - val_autoencoder_output_loss: 0.0252
# Epoch 27/200
# 5400/5400 [==============================] - 1s 172us/step - loss: 0.0257 - autoencoder_output_loss: 0.0252 - val_loss: 0.0251 - val_autoencoder_output_loss: 0.0250
# Epoch 28/200
# 5400/5400 [==============================] - 1s 178us/step - loss: 0.0255 - autoencoder_output_loss: 0.0252 - val_loss: 0.0249 - val_autoencoder_output_loss: 0.0249
# Epoch 29/200
# 5400/5400 [==============================] - 1s 173us/step - loss: 0.0253 - autoencoder_output_loss: 0.0252 - val_loss: 0.0248 - val_autoencoder_output_loss: 0.0248
# Epoch 30/200
# 5400/5400 [==============================] - 1s 177us/step - loss: 0.0252 - autoencoder_output_loss: 0.0250 - val_loss: 0.0247 - val_autoencoder_output_loss: 0.0246
# Epoch 31/200
# 5400/5400 [==============================] - 1s 172us/step - loss: 0.0250 - autoencoder_output_loss: 0.0248 - val_loss: 0.0245 - val_autoencoder_output_loss: 0.0245
# Epoch 32/200
# 5400/5400 [==============================] - 1s 173us/step - loss: 0.0249 - autoencoder_output_loss: 0.0246 - val_loss: 0.0245 - val_autoencoder_output_loss: 0.0244
# Epoch 33/200
# 5400/5400 [==============================] - 1s 180us/step - loss: 0.0247 - autoencoder_output_loss: 0.0246 - val_loss: 0.0243 - val_autoencoder_output_loss: 0.0242
# Epoch 34/200
# 5400/5400 [==============================] - 1s 176us/step - loss: 0.0247 - autoencoder_output_loss: 0.0245 - val_loss: 0.0242 - val_autoencoder_output_loss: 0.0241
# Epoch 35/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0245 - autoencoder_output_loss: 0.0244 - val_loss: 0.0241 - val_autoencoder_output_loss: 0.0240
# Epoch 36/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0243 - autoencoder_output_loss: 0.0241 - val_loss: 0.0240 - val_autoencoder_output_loss: 0.0239
# Epoch 37/200
# 5400/5400 [==============================] - 1s 173us/step - loss: 0.0242 - autoencoder_output_loss: 0.0240 - val_loss: 0.0239 - val_autoencoder_output_loss: 0.0238
# Epoch 38/200
# 5400/5400 [==============================] - 1s 179us/step - loss: 0.0242 - autoencoder_output_loss: 0.0241 - val_loss: 0.0238 - val_autoencoder_output_loss: 0.0238
# Epoch 39/200
# 5400/5400 [==============================] - 1s 178us/step - loss: 0.0242 - autoencoder_output_loss: 0.0241 - val_loss: 0.0238 - val_autoencoder_output_loss: 0.0237
# Epoch 40/200
# 5400/5400 [==============================] - 1s 177us/step - loss: 0.0240 - autoencoder_output_loss: 0.0239 - val_loss: 0.0237 - val_autoencoder_output_loss: 0.0236
# Epoch 41/200
# 5400/5400 [==============================] - 1s 174us/step - loss: 0.0239 - autoencoder_output_loss: 0.0237 - val_loss: 0.0235 - val_autoencoder_output_loss: 0.0234
# Epoch 42/200
# 5400/5400 [==============================] - 1s 171us/step - loss: 0.0238 - autoencoder_output_loss: 0.0236 - val_loss: 0.0235 - val_autoencoder_output_loss: 0.0234
# Epoch 43/200
# 5400/5400 [==============================] - 1s 176us/step - loss: 0.0237 - autoencoder_output_loss: 0.0235 - val_loss: 0.0234 - val_autoencoder_output_loss: 0.0233
# Epoch 44/200
# 5400/5400 [==============================] - 1s 178us/step - loss: 0.0236 - autoencoder_output_loss: 0.0235 - val_loss: 0.0234 - val_autoencoder_output_loss: 0.0233
# Epoch 45/200
# 5400/5400 [==============================] - 1s 171us/step - loss: 0.0236 - autoencoder_output_loss: 0.0235 - val_loss: 0.0233 - val_autoencoder_output_loss: 0.0232
# Epoch 46/200
# 5400/5400 [==============================] - 1s 175us/step - loss: 0.0235 - autoencoder_output_loss: 0.0233 - val_loss: 0.0232 - val_autoencoder_output_loss: 0.0231
# Epoch 47/200
# 5400/5400 [==============================] - 1s 166us/step - loss: 0.0234 - autoencoder_output_loss: 0.0233 - val_loss: 0.0232 - val_autoencoder_output_loss: 0.0231
# Epoch 48/200
# 5400/5400 [==============================] - 1s 172us/step - loss: 0.0233 - autoencoder_output_loss: 0.0231 - val_loss: 0.0231 - val_autoencoder_output_loss: 0.0230
# Epoch 49/200
# 5400/5400 [==============================] - 1s 169us/step - loss: 0.0233 - autoencoder_output_loss: 0.0231 - val_loss: 0.0230 - val_autoencoder_output_loss: 0.0229
# Epoch 50/200
# 5400/5400 [==============================] - 1s 176us/step - loss: 0.0232 - autoencoder_output_loss: 0.0231 - val_loss: 0.0230 - val_autoencoder_output_loss: 0.0229
# Epoch 51/200
# 5400/5400 [==============================] - 1s 180us/step - loss: 0.0231 - autoencoder_output_loss: 0.0229 - val_loss: 0.0229 - val_autoencoder_output_loss: 0.0228
# Epoch 52/200
# 5400/5400 [==============================] - 1s 177us/step - loss: 0.0231 - autoencoder_output_loss: 0.0229 - val_loss: 0.0229 - val_autoencoder_output_loss: 0.0228
# Epoch 53/200
# 5400/5400 [==============================] - 1s 172us/step - loss: 0.0230 - autoencoder_output_loss: 0.0230 - val_loss: 0.0229 - val_autoencoder_output_loss: 0.0228
# Epoch 54/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0230 - autoencoder_output_loss: 0.0228 - val_loss: 0.0228 - val_autoencoder_output_loss: 0.0227
# Epoch 55/200
# 5400/5400 [==============================] - 1s 167us/step - loss: 0.0229 - autoencoder_output_loss: 0.0228 - val_loss: 0.0228 - val_autoencoder_output_loss: 0.0227
# Epoch 56/200
# 5400/5400 [==============================] - 1s 165us/step - loss: 0.0229 - autoencoder_output_loss: 0.0228 - val_loss: 0.0227 - val_autoencoder_output_loss: 0.0226
# Epoch 57/200
# 5400/5400 [==============================] - 1s 183us/step - loss: 0.0228 - autoencoder_output_loss: 0.0228 - val_loss: 0.0227 - val_autoencoder_output_loss: 0.0226
# Epoch 58/200
# 5400/5400 [==============================] - 1s 176us/step - loss: 0.0228 - autoencoder_output_loss: 0.0227 - val_loss: 0.0227 - val_autoencoder_output_loss: 0.0226
# Epoch 59/200
# 5400/5400 [==============================] - 1s 173us/step - loss: 0.0228 - autoencoder_output_loss: 0.0226 - val_loss: 0.0226 - val_autoencoder_output_loss: 0.0225
# Epoch 60/200
# 5400/5400 [==============================] - 1s 170us/step - loss: 0.0227 - autoencoder_output_loss: 0.0226 - val_loss: 0.0226 - val_autoencoder_output_loss: 0.0225
# Epoch 61/200
# 5400/5400 [==============================] - 1s 178us/step - loss: 0.0227 - autoencoder_output_loss: 0.0226 - val_loss: 0.0226 - val_autoencoder_output_loss: 0.0225
# Epoch 62/200
# 5400/5400 [==============================] - 1s 175us/step - loss: 0.0226 - autoencoder_output_loss: 0.0226 - val_loss: 0.0225 - val_autoencoder_output_loss: 0.0224
# Epoch 63/200
# 5400/5400 [==============================] - 1s 187us/step - loss: 0.0226 - autoencoder_output_loss: 0.0226 - val_loss: 0.0225 - val_autoencoder_output_loss: 0.0224
# Epoch 64/200
# 5400/5400 [==============================] - 1s 183us/step - loss: 0.0226 - autoencoder_output_loss: 0.0224 - val_loss: 0.0225 - val_autoencoder_output_loss: 0.0224
# Epoch 65/200
# 5400/5400 [==============================] - 1s 189us/step - loss: 0.0226 - autoencoder_output_loss: 0.0223 - val_loss: 0.0225 - val_autoencoder_output_loss: 0.0224
# Epoch 66/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0225 - autoencoder_output_loss: 0.0224 - val_loss: 0.0224 - val_autoencoder_output_loss: 0.0223
# Epoch 67/200
# 5400/5400 [==============================] - 1s 171us/step - loss: 0.0225 - autoencoder_output_loss: 0.0224 - val_loss: 0.0224 - val_autoencoder_output_loss: 0.0224
# Epoch 68/200
# 5400/5400 [==============================] - 1s 180us/step - loss: 0.0225 - autoencoder_output_loss: 0.0225 - val_loss: 0.0224 - val_autoencoder_output_loss: 0.0223
# Epoch 69/200
# 5400/5400 [==============================] - 1s 177us/step - loss: 0.0224 - autoencoder_output_loss: 0.0223 - val_loss: 0.0223 - val_autoencoder_output_loss: 0.0222
# Epoch 70/200
# 5400/5400 [==============================] - 1s 172us/step - loss: 0.0224 - autoencoder_output_loss: 0.0222 - val_loss: 0.0223 - val_autoencoder_output_loss: 0.0222
# Epoch 71/200
# 5400/5400 [==============================] - 1s 180us/step - loss: 0.0224 - autoencoder_output_loss: 0.0224 - val_loss: 0.0223 - val_autoencoder_output_loss: 0.0222
# Epoch 72/200
# 5400/5400 [==============================] - 1s 178us/step - loss: 0.0224 - autoencoder_output_loss: 0.0221 - val_loss: 0.0223 - val_autoencoder_output_loss: 0.0222
# Epoch 73/200
# 5400/5400 [==============================] - 1s 171us/step - loss: 0.0223 - autoencoder_output_loss: 0.0220 - val_loss: 0.0223 - val_autoencoder_output_loss: 0.0222
# Epoch 74/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0223 - autoencoder_output_loss: 0.0221 - val_loss: 0.0223 - val_autoencoder_output_loss: 0.0221
# Epoch 75/200
# 5400/5400 [==============================] - 1s 179us/step - loss: 0.0223 - autoencoder_output_loss: 0.0221 - val_loss: 0.0223 - val_autoencoder_output_loss: 0.0222
# Epoch 76/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0223 - autoencoder_output_loss: 0.0222 - val_loss: 0.0222 - val_autoencoder_output_loss: 0.0221
# Epoch 77/200
# 5400/5400 [==============================] - 1s 179us/step - loss: 0.0223 - autoencoder_output_loss: 0.0220 - val_loss: 0.0222 - val_autoencoder_output_loss: 0.0221
# Epoch 78/200
# 5400/5400 [==============================] - 1s 166us/step - loss: 0.0222 - autoencoder_output_loss: 0.0222 - val_loss: 0.0222 - val_autoencoder_output_loss: 0.0221
# Epoch 79/200
# 5400/5400 [==============================] - 1s 179us/step - loss: 0.0222 - autoencoder_output_loss: 0.0221 - val_loss: 0.0222 - val_autoencoder_output_loss: 0.0221
# Epoch 80/200
# 5400/5400 [==============================] - 1s 176us/step - loss: 0.0222 - autoencoder_output_loss: 0.0220 - val_loss: 0.0221 - val_autoencoder_output_loss: 0.0220
# Epoch 81/200
# 5400/5400 [==============================] - 1s 174us/step - loss: 0.0222 - autoencoder_output_loss: 0.0221 - val_loss: 0.0221 - val_autoencoder_output_loss: 0.0220
# Epoch 82/200
# 5400/5400 [==============================] - 1s 169us/step - loss: 0.0222 - autoencoder_output_loss: 0.0221 - val_loss: 0.0221 - val_autoencoder_output_loss: 0.0220
# Epoch 83/200
# 5400/5400 [==============================] - 1s 185us/step - loss: 0.0222 - autoencoder_output_loss: 0.0220 - val_loss: 0.0221 - val_autoencoder_output_loss: 0.0220
# Epoch 84/200
# 5400/5400 [==============================] - 1s 173us/step - loss: 0.0221 - autoencoder_output_loss: 0.0221 - val_loss: 0.0221 - val_autoencoder_output_loss: 0.0220
# Epoch 85/200
# 5400/5400 [==============================] - 1s 167us/step - loss: 0.0221 - autoencoder_output_loss: 0.0221 - val_loss: 0.0221 - val_autoencoder_output_loss: 0.0220
# Epoch 86/200
# 5400/5400 [==============================] - 1s 180us/step - loss: 0.0221 - autoencoder_output_loss: 0.0221 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 87/200
# 5400/5400 [==============================] - 1s 172us/step - loss: 0.0221 - autoencoder_output_loss: 0.0219 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0220
# Epoch 88/200
# 5400/5400 [==============================] - 1s 177us/step - loss: 0.0221 - autoencoder_output_loss: 0.0220 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 89/200
# 5400/5400 [==============================] - 1s 170us/step - loss: 0.0220 - autoencoder_output_loss: 0.0219 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 90/200
# 5400/5400 [==============================] - 1s 179us/step - loss: 0.0220 - autoencoder_output_loss: 0.0217 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 91/200
# 5400/5400 [==============================] - 1s 175us/step - loss: 0.0220 - autoencoder_output_loss: 0.0219 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 92/200
# 5400/5400 [==============================] - 1s 172us/step - loss: 0.0220 - autoencoder_output_loss: 0.0219 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 93/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0220 - autoencoder_output_loss: 0.0217 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0219
# Epoch 94/200
# 5400/5400 [==============================] - 1s 178us/step - loss: 0.0220 - autoencoder_output_loss: 0.0217 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 95/200
# 5400/5400 [==============================] - 1s 174us/step - loss: 0.0220 - autoencoder_output_loss: 0.0220 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 96/200
# 5400/5400 [==============================] - 1s 187us/step - loss: 0.0220 - autoencoder_output_loss: 0.0218 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 97/200
# 5400/5400 [==============================] - 1s 183us/step - loss: 0.0220 - autoencoder_output_loss: 0.0218 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 98/200
# 5400/5400 [==============================] - 1s 179us/step - loss: 0.0220 - autoencoder_output_loss: 0.0221 - val_loss: 0.0223 - val_autoencoder_output_loss: 0.0222
# Epoch 99/200
# 5400/5400 [==============================] - 1s 192us/step - loss: 0.0228 - autoencoder_output_loss: 0.0228 - val_loss: 0.0224 - val_autoencoder_output_loss: 0.0223
# Epoch 100/200
# 5400/5400 [==============================] - 1s 180us/step - loss: 0.0223 - autoencoder_output_loss: 0.0221 - val_loss: 0.0221 - val_autoencoder_output_loss: 0.0220
#
# Epoch 00100: saving model to ./log_weights/F_AE_50_weights_0.0078125.MNIST0100.hdf5
# Epoch 101/200
# 5400/5400 [==============================] - 1s 193us/step - loss: 0.0221 - autoencoder_output_loss: 0.0220 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 102/200
# 5400/5400 [==============================] - 1s 185us/step - loss: 0.0220 - autoencoder_output_loss: 0.0218 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 103/200
# 5400/5400 [==============================] - 1s 173us/step - loss: 0.0220 - autoencoder_output_loss: 0.0219 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 104/200
# 5400/5400 [==============================] - 1s 196us/step - loss: 0.0220 - autoencoder_output_loss: 0.0220 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 105/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0220 - autoencoder_output_loss: 0.0219 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 106/200
# 5400/5400 [==============================] - 1s 194us/step - loss: 0.0220 - autoencoder_output_loss: 0.0218 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 107/200
# 5400/5400 [==============================] - 1s 197us/step - loss: 0.0220 - autoencoder_output_loss: 0.0217 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 108/200
# 5400/5400 [==============================] - 1s 186us/step - loss: 0.0219 - autoencoder_output_loss: 0.0217 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0219
# Epoch 109/200
# 5400/5400 [==============================] - 1s 169us/step - loss: 0.0219 - autoencoder_output_loss: 0.0217 - val_loss: 0.0220 - val_autoencoder_output_loss: 0.0219
# Epoch 110/200
# 5400/5400 [==============================] - 1s 178us/step - loss: 0.0219 - autoencoder_output_loss: 0.0219 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 111/200
# 5400/5400 [==============================] - 1s 172us/step - loss: 0.0219 - autoencoder_output_loss: 0.0217 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 112/200
# 5400/5400 [==============================] - 1s 175us/step - loss: 0.0219 - autoencoder_output_loss: 0.0219 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 113/200
# 5400/5400 [==============================] - 1s 167us/step - loss: 0.0219 - autoencoder_output_loss: 0.0218 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 114/200
# 5400/5400 [==============================] - 1s 176us/step - loss: 0.0219 - autoencoder_output_loss: 0.0216 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 115/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0219 - autoencoder_output_loss: 0.0217 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 116/200
# 5400/5400 [==============================] - 1s 188us/step - loss: 0.0219 - autoencoder_output_loss: 0.0217 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 117/200
# 5400/5400 [==============================] - 1s 184us/step - loss: 0.0219 - autoencoder_output_loss: 0.0217 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 118/200
# 5400/5400 [==============================] - 1s 186us/step - loss: 0.0219 - autoencoder_output_loss: 0.0218 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 119/200
# 5400/5400 [==============================] - 1s 184us/step - loss: 0.0219 - autoencoder_output_loss: 0.0218 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 120/200
# 5400/5400 [==============================] - 1s 179us/step - loss: 0.0218 - autoencoder_output_loss: 0.0217 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 121/200
# 5400/5400 [==============================] - 1s 181us/step - loss: 0.0219 - autoencoder_output_loss: 0.0217 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 122/200
# 5400/5400 [==============================] - 1s 185us/step - loss: 0.0218 - autoencoder_output_loss: 0.0217 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 123/200
# 5400/5400 [==============================] - 1s 186us/step - loss: 0.0218 - autoencoder_output_loss: 0.0217 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 124/200
# 5400/5400 [==============================] - 1s 188us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0218
# Epoch 125/200
# 5400/5400 [==============================] - 1s 181us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 126/200
# 5400/5400 [==============================] - 1s 184us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 127/200
# 5400/5400 [==============================] - 1s 174us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 128/200
# 5400/5400 [==============================] - 1s 167us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 129/200
# 5400/5400 [==============================] - 1s 188us/step - loss: 0.0218 - autoencoder_output_loss: 0.0217 - val_loss: 0.0219 - val_autoencoder_output_loss: 0.0218
# Epoch 130/200
# 5400/5400 [==============================] - 1s 169us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 131/200
# 5400/5400 [==============================] - 1s 177us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 132/200
# 5400/5400 [==============================] - 1s 178us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 133/200
# 5400/5400 [==============================] - 1s 187us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 134/200
# 5400/5400 [==============================] - 1s 185us/step - loss: 0.0218 - autoencoder_output_loss: 0.0219 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 135/200
# 5400/5400 [==============================] - 1s 177us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 136/200
# 5400/5400 [==============================] - 1s 191us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 137/200
# 5400/5400 [==============================] - 1s 181us/step - loss: 0.0218 - autoencoder_output_loss: 0.0215 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 138/200
# 5400/5400 [==============================] - 1s 176us/step - loss: 0.0218 - autoencoder_output_loss: 0.0217 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 139/200
# 5400/5400 [==============================] - 1s 187us/step - loss: 0.0218 - autoencoder_output_loss: 0.0217 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0218
# Epoch 140/200
# 5400/5400 [==============================] - 1s 189us/step - loss: 0.0218 - autoencoder_output_loss: 0.0215 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 141/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0218 - autoencoder_output_loss: 0.0217 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 142/200
# 5400/5400 [==============================] - 1s 175us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 143/200
# 5400/5400 [==============================] - 1s 175us/step - loss: 0.0217 - autoencoder_output_loss: 0.0218 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 144/200
# 5400/5400 [==============================] - 1s 174us/step - loss: 0.0218 - autoencoder_output_loss: 0.0218 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 145/200
# 5400/5400 [==============================] - 1s 188us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 146/200
# 5400/5400 [==============================] - 1s 184us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 147/200
# 5400/5400 [==============================] - 1s 183us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 148/200
# 5400/5400 [==============================] - 1s 192us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 149/200
# 5400/5400 [==============================] - 1s 185us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 150/200
# 5400/5400 [==============================] - 1s 199us/step - loss: 0.0218 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 151/200
# 5400/5400 [==============================] - 1s 187us/step - loss: 0.0217 - autoencoder_output_loss: 0.0218 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 152/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 153/200
# 5400/5400 [==============================] - 1s 180us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 154/200
# 5400/5400 [==============================] - 1s 183us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 155/200
# 5400/5400 [==============================] - 1s 184us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 156/200
# 5400/5400 [==============================] - 1s 185us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0217
# Epoch 157/200
# 5400/5400 [==============================] - 1s 191us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 158/200
# 5400/5400 [==============================] - 1s 176us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 159/200
# 5400/5400 [==============================] - 1s 191us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 160/200
# 5400/5400 [==============================] - 1s 176us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0217
# Epoch 161/200
# 5400/5400 [==============================] - 1s 185us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0217
# Epoch 162/200
# 5400/5400 [==============================] - 1s 184us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0217
# Epoch 163/200
# 5400/5400 [==============================] - 1s 181us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0217
# Epoch 164/200
# 5400/5400 [==============================] - 1s 183us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 165/200
# 5400/5400 [==============================] - 1s 179us/step - loss: 0.0217 - autoencoder_output_loss: 0.0214 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 166/200
# 5400/5400 [==============================] - 1s 181us/step - loss: 0.0217 - autoencoder_output_loss: 0.0217 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0217
# Epoch 167/200
# 5400/5400 [==============================] - 1s 184us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0217
# Epoch 168/200
# 5400/5400 [==============================] - 1s 187us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0217
# Epoch 169/200
# 5400/5400 [==============================] - 1s 186us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 170/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 171/200
# 5400/5400 [==============================] - 1s 170us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 172/200
# 5400/5400 [==============================] - 1s 193us/step - loss: 0.0217 - autoencoder_output_loss: 0.0214 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0217
# Epoch 173/200
# 5400/5400 [==============================] - 1s 193us/step - loss: 0.0217 - autoencoder_output_loss: 0.0214 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 174/200
# 5400/5400 [==============================] - 1s 180us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0217
# Epoch 175/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 176/200
# 5400/5400 [==============================] - 1s 189us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 177/200
# 5400/5400 [==============================] - 1s 191us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 178/200
# 5400/5400 [==============================] - 1s 185us/step - loss: 0.0217 - autoencoder_output_loss: 0.0217 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 179/200
# 5400/5400 [==============================] - 1s 186us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 180/200
# 5400/5400 [==============================] - 1s 188us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 181/200
# 5400/5400 [==============================] - 1s 188us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 182/200
# 5400/5400 [==============================] - 1s 196us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 183/200
# 5400/5400 [==============================] - 1s 167us/step - loss: 0.0217 - autoencoder_output_loss: 0.0213 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 184/200
# 5400/5400 [==============================] - 1s 190us/step - loss: 0.0216 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 185/200
# 5400/5400 [==============================] - 1s 186us/step - loss: 0.0216 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 186/200
# 5400/5400 [==============================] - 1s 186us/step - loss: 0.0217 - autoencoder_output_loss: 0.0216 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 187/200
# 5400/5400 [==============================] - 1s 190us/step - loss: 0.0216 - autoencoder_output_loss: 0.0214 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 188/200
# 5400/5400 [==============================] - 1s 189us/step - loss: 0.0216 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 189/200
# 5400/5400 [==============================] - 1s 177us/step - loss: 0.0216 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 190/200
# 5400/5400 [==============================] - 1s 187us/step - loss: 0.0217 - autoencoder_output_loss: 0.0214 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 191/200
# 5400/5400 [==============================] - 1s 187us/step - loss: 0.0216 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 192/200
# 5400/5400 [==============================] - 1s 184us/step - loss: 0.0216 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 193/200
# 5400/5400 [==============================] - 1s 182us/step - loss: 0.0216 - autoencoder_output_loss: 0.0213 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 194/200
# 5400/5400 [==============================] - 1s 189us/step - loss: 0.0216 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 195/200
# 5400/5400 [==============================] - 1s 177us/step - loss: 0.0216 - autoencoder_output_loss: 0.0216 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 196/200
# 5400/5400 [==============================] - 1s 187us/step - loss: 0.0216 - autoencoder_output_loss: 0.0217 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 197/200
# 5400/5400 [==============================] - 1s 189us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 198/200
# 5400/5400 [==============================] - 1s 189us/step - loss: 0.0216 - autoencoder_output_loss: 0.0216 - val_loss: 0.0218 - val_autoencoder_output_loss: 0.0217
# Epoch 199/200
# 5400/5400 [==============================] - 1s 185us/step - loss: 0.0217 - autoencoder_output_loss: 0.0215 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
# Epoch 200/200
# 5400/5400 [==============================] - 1s 190us/step - loss: 0.0216 - autoencoder_output_loss: 0.0214 - val_loss: 0.0217 - val_autoencoder_output_loss: 0.0216
#
# Epoch 00200: saving model to ./log_weights/F_AE_50_weights_0.0078125.MNIST0200.hdf5

# %%
loss = F_AE_history.history['loss']
val_loss = F_AE_history.history['val_loss']

epochs = range(epochs_number)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
p_data=F_AE.predict(x_train)
numbers=x_train.shape[0]*x_train.shape[1]

print("Training: MSE for one-to-one map layer",np.sum(np.power(np.array(p_data)[0]-x_train,2))/numbers)
print("Training: MSE for feature selection layer",np.sum(np.power(np.array(p_data)[1]-x_train,2))/numbers)
# Out:
# Training: MSE for one-to-one map layer 0.016606268158304988
# Training: MSE for feature selection layer 0.021444587275014172

# %%
p_data=F_AE.predict(x_test)
numbers=x_test.shape[0]*x_test.shape[1]

print("Testing: MSE for one-to-one map layer",np.sum(np.power(np.array(p_data)[0]-x_test,2))/numbers)
print("Testing: MSE for feature selection layer",np.sum(np.power(np.array(p_data)[1]-x_test,2))/numbers)
# Out:
# Testing: MSE for one-to-one map layer 0.017783290318080357
# Testing: MSE for feature selection layer 0.022264050542091837

# %%
F.show_data_figures(p_data[0][0:160],w=28,h=28,columns = 20)

# %%
F.show_data_figures(p_data[1][0:160],w=28,h=28,columns = 20)

# %%
F.show_feature_selection('./log_weights/F_AE_'+str(key_feture_number)+'_weights_'+str(loss_weight_1)+'.MNIST0200.hdf5',x_test,p_sample_number=160,p_key_number=key_feture_number)

# %% [markdown]
# ---
# ### 3.1.2 Feature selection layer output
# ---

# %%
FS_layer_output=feature_selection_output.predict(x_test)
F.show_data_figures(FS_layer_output[0:160],w=28,h=28,columns = 20)

print(np.sum(FS_layer_output[0]>0))
# Out:
# 16

# %% [markdown]
# ---
# ### 3.1.3 Key features show
# ---

# %%
# Gray
'''
key_features=F.top_k_keepWeights_1(F_AE.get_layer(index=1).get_weights()[0],key_feture_number)
plt.axis('off')
plt.imshow(key_features.reshape((28, 28)),plt.cm.gray)
print(np.sum(F_AE.get_layer(index=1).get_weights()[0]>0))
'''

# Red
key_features=F.top_k_keepWeights_1(F_AE.get_layer(index=1).get_weights()[0],key_feture_number)
key_features_=key_features.reshape((28, 28))

plt.axis('off')
canvas=np.zeros((28,28))
plt.imshow(canvas,plt.cm.gray)

for index_i in np.arange(key_features_.shape[0]):
    for index_j in np.arange(key_features_.shape[1]): 
        if key_features_[index_i,index_j]==1:
            plt.scatter(index_j,index_i,s=100,color='r',marker="s")
plt.tight_layout()
plt.show()
print(np.sum(F_AE.get_layer(index=1).get_weights()[0]>0))
print(np.sum(key_features>0))
# Out:
# 784
# 50

# %% [markdown]
# # 4 Classifying

# %% [markdown]
# ### 4.1. Extra Trees

# %%
train_feature=C_train_x
train_label=C_train_y
test_feature=C_test_x
test_label=C_test_y
p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.83725
# Testing accuracy： 0.83725

# %%
F.show_data_figures(C_test_x[0:160],w=28,h=28,columns = 20)

# %%
C_test_y[0:160]
# Out:
# array([7, 5, 4, 5, 8, 4, 7, 9, 6, 6, 3, 5, 0, 8, 6, 9, 4, 9, 9, 0, 1, 7,
#        9, 5, 5, 8, 2, 2, 6, 5, 4, 4, 0, 5, 4, 0, 5, 6, 7, 8, 3, 9, 1, 8,
#        3, 4, 2, 3, 8, 5, 2, 7, 3, 3, 7, 5, 2, 4, 9, 5, 6, 0, 0, 6, 6, 2,
#        5, 3, 0, 8, 9, 5, 2, 7, 1, 6, 8, 8, 8, 7, 8, 0, 2, 9, 3, 8, 1, 0,
#        6, 6, 8, 3, 9, 8, 2, 6, 8, 1, 0, 1, 8, 1, 0, 3, 6, 3, 9, 4, 9, 2,
#        2, 4, 9, 8, 2, 7, 5, 3, 1, 6, 5, 4, 3, 7, 6, 7, 4, 5, 3, 6, 3, 4,
#        9, 9, 3, 2, 0, 2, 4, 5, 1, 3, 9, 4, 5, 5, 4, 3, 4, 2, 8, 6, 6, 0,
#        8, 6, 6, 9, 7, 8], dtype=uint8)

# %%
print(np.sum(FS_layer_output[0]>0))
# Out:
# 16

# %%
row=np.where(key_features_>0)[0]
column=np.where(key_features_>0)[1]

selected_position_list=[]
for i in np.arange(key_feture_number):
    selected_position_list.append((row[i],column[i]))

# %% [markdown]
# ---
# #### 4.1.1. On Identity Selection layer
# ---
#
# a) with zeros

# %%
train_feature=feature_selection_output.predict(C_train_x)
print("train_feature>0: ",np.sum(train_feature[0]>0))
print(train_feature.shape)
train_label=C_train_y

test_feature=feature_selection_output.predict(C_test_x)
print("test_feature>0: ",np.sum(test_feature[0]>0))
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# train_feature>0:  31
# (6000, 784)
# test_feature>0:  16
# (4000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.7915
# Testing accuracy： 0.7915

# %%
F.show_data_figures(test_feature[0:160],w=28,h=28,columns = 20)

# %% [markdown]
# ---
#
# b) Sparse matrix

# %%
train_feature=feature_selection_output.predict(C_train_x)
print(train_feature.shape)
train_label=C_train_y

test_feature=feature_selection_output.predict(C_test_x)
print(test_feature.shape)
test_label=C_test_y

train_feature_sparse=sparse.coo_matrix(train_feature)
test_feature_sparse=sparse.coo_matrix(test_feature)

p_seed=seed
F.ETree(train_feature_sparse,train_label,test_feature_sparse,test_label,p_seed)
# Out:
# (6000, 784)
# (4000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.7915
# Testing accuracy： 0.7915

# %% [markdown]
# ---
#
# c) Compression

# %%
train_feature_=feature_selection_output.predict(C_train_x)
train_feature=F.compress_zero(train_feature_,key_feture_number)
print(train_feature.shape)
train_label=C_train_y

test_feature_=feature_selection_output.predict(C_test_x)
test_feature=F.compress_zero(test_feature_,key_feture_number)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.563
# Testing accuracy： 0.563

# %% [markdown]
# ---
#
# d) Compression with structure

# %%
train_feature_=feature_selection_output.predict(C_train_x)
train_feature=F.compress_zero_withkeystructure(train_feature_,selected_position_list,w=28,h=28)
print(train_feature.shape)
train_label=C_train_y

test_feature_=feature_selection_output.predict(C_test_x)
test_feature=F.compress_zero_withkeystructure(test_feature_,selected_position_list,w=28,h=28)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.80525
# Testing accuracy： 0.80525

# %% [markdown]
# ---
# #### 4.1.2. On Original Selection
# ---
#
# a) with zeros

# %%
train_feature=np.multiply(C_train_x, key_features)
print("train_feature>0: ",np.sum(train_feature[0]>0))
print(train_feature.shape)
train_label=C_train_y

test_feature=np.multiply(C_test_x, key_features)
print("test_feature>0: ",np.sum(test_feature[0]>0))
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# train_feature>0:  31
# (6000, 784)
# test_feature>0:  16
# (4000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.7915
# Testing accuracy： 0.7915

# %%
F.show_data_figures(test_feature[0:160],w=28,h=28,columns = 20)

# %% [markdown]
# ---
#
# b) Sparse matrix

# %%
train_feature=np.multiply(C_train_x, key_features)
print(train_feature.shape)
train_label=C_train_y

test_feature=np.multiply(C_test_x, key_features)
print(test_feature.shape)
test_label=C_test_y

train_feature_sparse=sparse.coo_matrix(train_feature)
test_feature_sparse=sparse.coo_matrix(test_feature)

p_seed=seed
F.ETree(train_feature_sparse,train_label,test_feature_sparse,test_label,p_seed)
# Out:
# (6000, 784)
# (4000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.7915
# Testing accuracy： 0.7915

# %% [markdown]
# ---
#
# c) Compression

# %%
train_feature_=np.multiply(C_train_x, key_features)
train_feature=F.compress_zero(train_feature_,key_feture_number)
print(train_feature.shape)
train_label=C_train_y

test_feature_=np.multiply(C_test_x, key_features)
test_feature=F.compress_zero(test_feature_,key_feture_number)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.54575
# Testing accuracy： 0.54575

# %% [markdown]
# ---
#
# d) Compression with structure

# %%
train_feature_=np.multiply(C_train_x, key_features)
train_feature=F.compress_zero_withkeystructure(train_feature_,selected_position_list,w=28,h=28)
print(train_feature.shape)
train_label=C_train_y

test_feature_=np.multiply(C_test_x, key_features)
test_feature=F.compress_zero_withkeystructure(test_feature_,selected_position_list,w=28,h=28)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.80525
# Testing accuracy： 0.80525

# %% [markdown]
# ---
# #### 4.1.3. Latent space
# ---

# %%
train_feature=latent_encoder_score_F_AE.predict(C_train_x)
print(train_feature.shape)
train_label=C_train_y
test_feature=latent_encoder_score_F_AE.predict(C_test_x)
print(test_feature.shape)
test_label=C_test_y
p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.80775
# Testing accuracy： 0.80775

# %%
train_feature=latent_encoder_choose_F_AE.predict(C_train_x)
print(train_feature.shape)
train_label=C_train_y
test_feature=latent_encoder_choose_F_AE.predict(C_test_x)
print(test_feature.shape)
test_label=C_test_y
p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.78125
# Testing accuracy： 0.78125

# %% [markdown]
# ---
# # 5 Merge features
# ---

# %%
key_feature_catch_index=[]
for key_feature_catch_i in FS_layer_output[0:160]:
    key_feature_catch_i_=key_feature_catch_i.reshape(28,28)
    key_feature_catch_i_nonzeros_index=np.where(key_feature_catch_i_>0)
    key_feature_catch_i_nonzeros_index_pair=[]
    for i in np.arange(len(key_feature_catch_i_nonzeros_index[0])):
        key_feature_catch_i_nonzeros_index_pair.append([key_feature_catch_i_nonzeros_index[0][i],key_feature_catch_i_nonzeros_index[1][i]])
    key_feature_catch_index.append(key_feature_catch_i_nonzeros_index_pair)

# %%
F.show_data_figures_with_hierarchy_keyfeature(x_test[0:160],key_feature_catch_index,w=28,h=28,columns = 20)

# %% [markdown]
# ---
# # 6 Feature group compare
#
# ---

# %%
Selected_Weights=F.top_k_keep(F_AE.get_layer(index=1).get_weights()[0],key_feture_number)

# %%
print(np.sum(Selected_Weights>0))

Selected_Weights_=Selected_Weights.reshape((28, 28))

print(len(np.unique(Selected_Weights_)))

selected_position_for_group=F.k_index_argsort(Selected_Weights_,key_feture_number)
selected_position_group=[tuple(i) for i in selected_position_for_group]
# Out:
# 50
# 51

# %%
train_feature_=np.multiply(C_train_x, key_features)
train_feature=F.compress_zero_withkeystructure(train_feature_,selected_position_group,w=28,h=28)
print(train_feature.shape)
train_label=C_train_y

test_feature_=np.multiply(C_test_x, key_features)
test_feature=F.compress_zero_withkeystructure(test_feature_,selected_position_group,w=28,h=28)
print(test_feature.shape)
test_label=C_test_y
# Out:
# (6000, 50)
# (4000, 50)

# %%
p_seed=seed
F.ETree(train_feature[:,0:25],train_label,test_feature[:,0:25],test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.74125
# Testing accuracy： 0.74125

# %%
p_seed=seed
F.ETree(train_feature[:,25:],train_label,test_feature[:,25:],test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.755
# Testing accuracy： 0.755

# %%
p_seed=seed
F.ETree(train_feature[:,0:30],train_label,test_feature[:,0:30],test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.77525
# Testing accuracy： 0.77525

# %%
p_seed=seed
F.ETree(train_feature[:,30:],train_label,test_feature[:,30:],test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.72475
# Testing accuracy： 0.72475
